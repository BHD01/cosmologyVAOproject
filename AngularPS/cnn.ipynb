# %%
import torch
print(f'PyTorch Version: {torch.__version__}')
print(f'CUDA Available: {torch.cuda.is_available()}')
print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# PyTorch Version: 2.9.1+cu128
# CUDA Available: True
# GPU: NVIDIA GeForce RTX 5080

# %% [markdown]
# 检查路径

# %%
import os
print(os.listdir('AngularPS/processed_tensors/202509'))
# Out:
# ['valid_data.pt', 'label_stats.pt', 'train_data.pt', 'test_data.pt']

# %% [markdown]
# 导入其余包

# %%
import torch.nn as nn
import torch.optim as optim
from torchmetrics import MeanAbsoluteError
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# 导入数据

# %%
def load_data():
    # 加载训练数据
    train_data = torch.load('AngularPS/processed_tensors/202509/train_data.pt')
    train_dataset = TensorDataset(train_data['images'], train_data['labels'])
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    valid_data = torch.load('AngularPS/processed_tensors/202509/valid_data.pt')
    valid_dataset = TensorDataset(valid_data['images'], valid_data['labels'])
    valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=True)

    test_data = torch.load('AngularPS/processed_tensors/202509/test_data.pt')
    test_dataset = TensorDataset(test_data['images'], test_data['labels'])
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

    # 验证样本数量
    expected_sizes = {'train': 7200, 'valid': 900, 'test': 990}
    for dataset_type, dataset, data in [
        ('train', train_dataset, train_data),
        ('valid', valid_dataset, valid_data),
        ('test', test_dataset, test_data)
    ]:
        actual_size = len(dataset)
        expected_size = expected_sizes[dataset_type]
        if actual_size != expected_size:
            print(f"警告：{dataset_type} 数据集样本数量 ({actual_size}) 与预期 ({expected_size}) 不符！")

    print(train_data['images'].shape)  # 预期：(7200, 1, 20, 39)
    print(train_data['labels'].shape)  # 预期：(7200,)
    print(f"训练集: {len(train_dataset)} 样本, 数据形状 {train_dataset[0][0].shape}")
    print(f"验证集: {len(valid_dataset)} 样本, 数据形状 {valid_dataset[0][0].shape}")
    print(f"测试集: {len(test_dataset)} 样本, 数据形状 {test_dataset[0][0].shape}")
    return train_loader, valid_loader, test_loader

if __name__ == "__main__":
    train_loader, valid_loader, test_loader = load_data()
# Out:
# 警告：test 数据集样本数量 (1332) 与预期 (990) 不符！
# torch.Size([7200, 1, 20, 40])
# torch.Size([7200, 2])
# 训练集: 7200 样本, 数据形状 torch.Size([1, 20, 40])
# 验证集: 900 样本, 数据形状 torch.Size([1, 20, 40])
# 测试集: 1332 样本, 数据形状 torch.Size([1, 20, 40])

# %% [markdown]
# 定义CNN模型

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        # 输入形状 (1, 20, 40)
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)  # 输出 (32, 20, 40)
        self.bn1 = nn.BatchNorm2d(32)  # 批归一化
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)  # 输出 (32, 10, 20)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # 输出 (64, 10, 20)
        self.bn2 = nn.BatchNorm2d(64)  # 批归一化
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)  # 输出 (64, 5, 10)
        self.flatten = nn.Flatten()
        # 计算全连接层输入维度：5 * 10 * 64 = 3200
        self.fc1 = nn.Linear(5 * 10 * 64, 256)  # 更新为3200
        self.relu3 = nn.ReLU()
        self.dropout = nn.Dropout(0.2)  # 可根据验证集性能调整到0.1-0.4
        self.fc2 = nn.Linear(256, 2)  # 双输出，回归任务 (klw, mcool)

    def forward(self, x):
        x = self.pool1(self.relu1(self.bn1(self.conv1(x))))
        x = self.pool2(self.relu2(self.bn2(self.conv2(x))))
        x = self.flatten(x)
        x = self.relu3(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# 定义训练函数

# %%
def r2_score(y_true, y_pred):
    ss_res = torch.sum((y_true - y_pred) ** 2)
    ss_tot = torch.sum((y_true - torch.mean(y_true)) ** 2)
    return 1 - (ss_res / ss_tot)

def train_model(model, train_loader, valid_loader, epochs=100, patience=30, w_klw=1.0, w_mcool=1):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    criterion = nn.MSELoss()  # 均方误差损失，适用于多输出回归
    mae = MeanAbsoluteError().to(device)  # MAE指标
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)  # 增加weight_decay

    best_valid_loss = float('inf')
    early_stop_counter = 0

    for epoch in range(epochs):
        model.train()
        train_loss, train_mae_klw, train_mae_mcool = 0.0, 0.0, 0.0
        valid_r2_klw, valid_mae_mcool = 0.0, 0.0
        train_samples = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)  # x: (batch_size, 1, 20, 40), y: (batch_size, 2)
            optimizer.zero_grad()
            output = model(x)  # output: (batch_size, 2)
            
            # 计算加权损失
            loss_klw = criterion(output[:, 0], y[:, 0]) * w_klw  # klw的损失
            loss_mcool = criterion(output[:, 1], y[:, 1]) * w_mcool  # mcool的损失
            loss = loss_klw + loss_mcool

            
            loss.backward()
            optimizer.step()
            
            # 累积损失和MAE
            train_loss += loss.item() * x.size(0)
            train_mae_klw += mae(output[:, 0], y[:, 0]).item() * x.size(0)
            train_mae_mcool += mae(output[:, 1], y[:, 1]).item() * x.size(0)
            train_samples += x.size(0)
        
        train_loss /= train_samples
        train_mae_klw /= train_samples
        train_mae_mcool /= train_samples

        # 验证阶段
        model.eval()
        valid_loss, valid_mae_klw, valid_mae_mcool = 0.0, 0.0, 0.0
        valid_samples = 0
        predictions = []
        trues = []
        with torch.no_grad():
            for x, y in valid_loader:
                x, y = x.to(device), y.to(device)
                output = model(x)  # output: (batch_size, 2)
                
                # 计算加权验证损失
                loss_klw = criterion(output[:, 0], y[:, 0]) * w_klw
                loss_mcool = criterion(output[:, 1], y[:, 1]) * w_mcool
                loss = loss_klw + loss_mcool
                
                valid_loss += loss.item() * x.size(0)
                valid_mae_klw += mae(output[:, 0], y[:, 0]).item() * x.size(0)
                valid_mae_mcool += mae(output[:, 1], y[:, 1]).item() * x.size(0)
                valid_samples += x.size(0)
                predictions.append(model(x.to(device)).cpu())
                trues.append(y.cpu())
        
        valid_loss /= valid_samples
        valid_mae_klw /= valid_samples
        valid_mae_mcool /= valid_samples
        all_pred = torch.cat(predictions, dim=0)
        all_true = torch.cat(trues, dim=0)
        valid_r2_klw = r2_score(all_true[:, 0], all_pred[:, 0])
        valid_r2_mcool = r2_score(all_true[:, 1], all_pred[:, 1])

        print(f'Epoch {epoch+1}/{epochs}, '
              f'Train Loss: {train_loss:.4f}, Train MAE klw: {train_mae_klw:.4f}, Train MAE mcool: {train_mae_mcool:.4f}, '
              f'Valid Loss: {valid_loss:.4f}, Valid MAE klw: {valid_mae_klw:.4f}, Valid MAE mcool: {valid_mae_mcool:.4f}, '
              f'Valid R2 klw: {valid_r2_klw:.4f}, Valid R2 mcool: {valid_r2_mcool:.4f}')

        # 保存最佳模型和早停
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), 'best_model100.pt')
            early_stop_counter = 0
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    # 加载最佳模型
    model.load_state_dict(torch.load('best_model100.pt'))
    return model

# %% [markdown]
# 定义测试函数

# %%
import numpy as np
np.random.seed(100000)

def test_model(model, test_loader, w_klw=1.0, w_mcool=1):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.eval()
    criterion = nn.MSELoss()  # 均方误差损失，适用于多输出回归
    mae = MeanAbsoluteError().to(device)  # MAE指标
    test_loss, test_mae_klw, test_mae_mcool = 0.0, 0.0, 0.0
    test_samples = 0
    predictions, trues = [], []

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)  # x: (batch_size, 1, 20, 40), y: (batch_size, 2)
            output = model(x)  # output: (batch_size, 2)
            
            # 计算加权损失
            loss_klw = criterion(output[:, 0], y[:, 0]) * w_klw  # klw的损失
            loss_mcool = criterion(output[:, 1], y[:, 1]) * w_mcool  # mcool的损失
            loss = loss_klw + loss_mcool
            
            # 累积损失和MAE
            test_loss += loss.item() * x.size(0)
            test_mae_klw += mae(output[:, 0], y[:, 0]).item() * x.size(0)
            test_mae_mcool += mae(output[:, 1], y[:, 1]).item() * x.size(0)
            test_samples += x.size(0)
            
            # 存储预测和真实值
            predictions.append(model(x.to(device)).cpu())  # (batch_size, 2)
            trues.append(y.cpu())  # (batch_size, 2)
        all_pred = torch.cat(predictions, dim=0)
        all_true = torch.cat(trues, dim=0)
        test_r2_klw = r2_score(all_true[:, 0], all_pred[:, 0])
        test_r2_mcool = r2_score(all_true[:, 1], all_pred[:, 1])

    test_loss /= test_samples
    test_mae_klw /= test_samples
    test_mae_mcool /= test_samples
    predictions = np.concatenate(predictions, axis=0)  # 形状：(N, 2)
    trues = np.concatenate(trues, axis=0)  # 形状：(N, 2)

    print(f'Test Loss: {test_loss:.4f}, Test MAE klw: {test_mae_klw:.4f}, Test MAE mcool: {test_mae_mcool:.4f}, Test R2 klw: {test_r2_klw:.4f}, Test R2 mcool: {test_r2_mcool:.4f}')
    return test_loss, test_mae_klw, test_mae_mcool, predictions, trues

# %% [markdown]
# 生成模型的流程图

# %%
from torchviz import make_dot

model = CNN()

model.eval()

# 创建一个示例输入（根据你的模型输入大小改）
x = torch.randn(1, 1, 20, 40)

# 前向传播
y = model(x)

# 生成结构图
dot = make_dot(y, params=dict(model.named_parameters()))
dot.format = "png"  # 或 "pdf"
dot.render("model_structure")
print("✅ 网络结构图已保存为 model_structure.png")
# Out:
# ✅ 网络结构图已保存为 model_structure.png

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch

def draw_box(ax, xy, text, width=2.5, height=0.8, color="#AED6F1"):
    x, y = xy
    box = FancyBboxPatch(
        (x, y - height / 2), width, height,
        boxstyle="round,pad=0.02",
        edgecolor="black",
        facecolor=color,
        linewidth=1.5
    )
    ax.add_patch(box)
    ax.text(x + width / 2, y, text, ha="center", va="center", fontsize=10)

def draw_arrow(ax, start, end):
    ax.annotate("",
                xy=end, xycoords='data',
                xytext=start, textcoords='data',
                arrowprops=dict(arrowstyle="->", lw=1.5))

def plot_cnn_architecture():
    fig, ax = plt.subplots(figsize=(7, 8))
    
    # --- Step 1: 扩大顶部空间，防止标题或坐标裁剪 ---
    ax.set_xlim(0, 6)
    ax.set_ylim(-1, 13)   # 原来是9，往上扩展一些
    ax.axis("off")

    # --- Step 2: 定义每一层（包括 Input 和 Conv2D） ---
    layers = [
        ("Input: MAPS map\n(1×20×40)", "#D5F5E3"),
        ("Conv2D\n1→32, 3×3", "#AED6F1"),
        ("BatchNorm + ReLU", "#AED6F1"),
        ("MaxPool2D\n2×2", "#AED6F1"),
        ("Conv2D\n32→64, 3×3", "#AED6F1"),
        ("BatchNorm + ReLU", "#AED6F1"),
        ("MaxPool2D\n2×2", "#AED6F1"),
        ("Flatten", "#FAD7A0"),
        ("Linear\n3200→256", "#F5B7B1"),
        ("ReLU + Dropout(0.2)", "#F5B7B1"),
        ("Linear\n256→2", "#F5B7B1"),
        ("Output: $\\alpha_{{\\mathrm{{LW}}}}$ & $M_{{\\mathrm{{cool}}}}$\n(2)", "#D5F5E3")
    ]

    # --- Step 3: 调整层的垂直布局，让最上层不被遮挡 ---
    y_positions = list(range(len(layers)))[::-1]
    y_positions = [y + 1 for y in y_positions]  # 整体往上移一点
    
    for i, ((text, color), y) in enumerate(zip(layers, y_positions)):
        draw_box(ax, (1.5, y), text, color=color)
        if i < len(layers) - 1:
            draw_arrow(ax, (2.75, y - 0.4), (2.75, y_positions[i+1] + 0.4))

    # 标题稍微下移一点，不遮盖 Input 框
    ax.text(0.2, y_positions[0] + 0.7, "CNN Model", fontsize=13, fontweight="bold", va="center")

    plt.tight_layout()
    plt.savefig("CNN_architecture_diagram.pdf", dpi=300, bbox_inches="tight")
    plt.show()
    print("✅ 已生成修正版结构图：CNN_architecture_diagram_fixed.png")

plot_cnn_architecture()
# Out:
# ✅ 已生成修正版结构图：CNN_architecture_diagram_fixed.png

# %% [markdown]
# 主程序：加载数据、训练和测试

# %%
# 加载数据
train_loader, valid_loader, test_loader = load_data()

# 初始化模型
model = CNN()

# 训练（使用归一化标签，权重设为1.0）
model = train_model(model, train_loader, valid_loader, epochs=100, patience=20, w_klw=1.0, w_mcool=1.0)

# 加载最佳模型
model.load_state_dict(torch.load('best_model100.pt'))

# 测试
test_loss, test_mae_klw, test_mae_mcool, predictions, trues = test_model(model, test_loader, w_klw=1.0, w_mcool=1.0)

# 反归一化
label_stats = torch.load('AngularPS/processed_tensors/202509/label_stats.pt')
mean, std = label_stats['mean'], label_stats['std']
predictions = predictions * std.numpy() + mean.numpy()
trues = trues * std.numpy() + mean.numpy()

# 打印结果
print("部分测试集预测值与真实值（klw, mcool）：")
for i in range(min(5, len(predictions))):
    print(f"样本 {i+1}: 预测值=[{predictions[i, 0]:.4f}, {predictions[i, 1]:.4e}], "
          f"真实值=[{trues[i, 0]:.4f}, {trues[i, 1]:.4e}]")
# Out:
# 警告：test 数据集样本数量 (1080) 与预期 (990) 不符！
# torch.Size([7200, 1, 20, 40])
# torch.Size([7200, 2])
# 训练集: 7200 样本, 数据形状 torch.Size([1, 20, 40])
# 验证集: 900 样本, 数据形状 torch.Size([1, 20, 40])
# 测试集: 1080 样本, 数据形状 torch.Size([1, 20, 40])
# Epoch 1/100, Train Loss: 1.2834, Train MAE klw: 0.5883, Train MAE mcool: 0.6961, Valid Loss: 1.2597, Valid MAE klw: 0.6062, Valid MAE mcool: 0.7218, Valid R2 klw: 0.4878, Valid R2 mcool: 0.3042
# Epoch 2/100, Train Loss: 1.0836, Train MAE klw: 0.5390, Train MAE mcool: 0.6663, Valid Loss: 1.2013, Valid MAE klw: 0.5889, Valid MAE mcool: 0.6610, Valid R2 klw: 0.4986, Valid R2 mcool: 0.3489
# Epoch 3/100, Train Loss: 1.0644, Train MAE klw: 0.5392, Train MAE mcool: 0.6527, Valid Loss: 1.1580, Valid MAE klw: 0.5756, Valid MAE mcool: 0.6821, Valid R2 klw: 0.5159, Valid R2 mcool: 0.3731
# Epoch 4/100, Train Loss: 1.0372, Train MAE klw: 0.5316, Train MAE mcool: 0.6448, Valid Loss: 1.1368, Valid MAE klw: 0.5897, Valid MAE mcool: 0.6670, Valid R2 klw: 0.5153, Valid R2 mcool: 0.3937
# Epoch 5/100, Train Loss: 0.9831, Train MAE klw: 0.5204, Train MAE mcool: 0.6208, Valid Loss: 1.0093, Valid MAE klw: 0.5593, Valid MAE mcool: 0.5979, Valid R2 klw: 0.5593, Valid R2 mcool: 0.4717
# Epoch 6/100, Train Loss: 0.9409, Train MAE klw: 0.5124, Train MAE mcool: 0.5987, Valid Loss: 1.0448, Valid MAE klw: 0.5501, Valid MAE mcool: 0.6407, Valid R2 klw: 0.5466, Valid R2 mcool: 0.4504
# Epoch 7/100, Train Loss: 0.8830, Train MAE klw: 0.5036, Train MAE mcool: 0.5737, Valid Loss: 0.8816, Valid MAE klw: 0.5081, Valid MAE mcool: 0.5522, Valid R2 klw: 0.5949, Valid R2 mcool: 0.5578
# Epoch 8/100, Train Loss: 0.8371, Train MAE klw: 0.4889, Train MAE mcool: 0.5530, Valid Loss: 0.8058, Valid MAE klw: 0.5066, Valid MAE mcool: 0.5150, Valid R2 klw: 0.6192, Valid R2 mcool: 0.6060
# Epoch 9/100, Train Loss: 0.7574, Train MAE klw: 0.4667, Train MAE mcool: 0.5174, Valid Loss: 0.8491, Valid MAE klw: 0.4771, Valid MAE mcool: 0.5759, Valid R2 klw: 0.6398, Valid R2 mcool: 0.5455
# Epoch 10/100, Train Loss: 0.7556, Train MAE klw: 0.4675, Train MAE mcool: 0.5196, Valid Loss: 0.7580, Valid MAE klw: 0.4935, Valid MAE mcool: 0.5062, Valid R2 klw: 0.6442, Valid R2 mcool: 0.6271
# Epoch 11/100, Train Loss: 0.7027, Train MAE klw: 0.4485, Train MAE mcool: 0.4950, Valid Loss: 0.7021, Valid MAE klw: 0.4819, Valid MAE mcool: 0.4704, Valid R2 klw: 0.6579, Valid R2 mcool: 0.6666
# Epoch 12/100, Train Loss: 0.6801, Train MAE klw: 0.4472, Train MAE mcool: 0.4819, Valid Loss: 0.7202, Valid MAE klw: 0.4972, Valid MAE mcool: 0.4923, Valid R2 klw: 0.6435, Valid R2 mcool: 0.6633
# Epoch 13/100, Train Loss: 0.6426, Train MAE klw: 0.4371, Train MAE mcool: 0.4649, Valid Loss: 0.6195, Valid MAE klw: 0.4342, Valid MAE mcool: 0.4633, Valid R2 klw: 0.7070, Valid R2 mcool: 0.6973
# Epoch 14/100, Train Loss: 0.5993, Train MAE klw: 0.4223, Train MAE mcool: 0.4456, Valid Loss: 0.5831, Valid MAE klw: 0.4267, Valid MAE mcool: 0.4221, Valid R2 klw: 0.7270, Valid R2 mcool: 0.7125
# Epoch 15/100, Train Loss: 0.5983, Train MAE klw: 0.4198, Train MAE mcool: 0.4510, Valid Loss: 0.6098, Valid MAE klw: 0.4033, Valid MAE mcool: 0.4333, Valid R2 klw: 0.7034, Valid R2 mcool: 0.7100
# Epoch 16/100, Train Loss: 0.5813, Train MAE klw: 0.4160, Train MAE mcool: 0.4408, Valid Loss: 0.5290, Valid MAE klw: 0.4148, Valid MAE mcool: 0.3954, Valid R2 klw: 0.7279, Valid R2 mcool: 0.7626
# Epoch 17/100, Train Loss: 0.5508, Train MAE klw: 0.4067, Train MAE mcool: 0.4245, Valid Loss: 0.4835, Valid MAE klw: 0.3787, Valid MAE mcool: 0.3767, Valid R2 klw: 0.7575, Valid R2 mcool: 0.7770
# Epoch 18/100, Train Loss: 0.5417, Train MAE klw: 0.3998, Train MAE mcool: 0.4242, Valid Loss: 0.5019, Valid MAE klw: 0.3825, Valid MAE mcool: 0.4139, Valid R2 klw: 0.7576, Valid R2 mcool: 0.7596
# Epoch 19/100, Train Loss: 0.5434, Train MAE klw: 0.4002, Train MAE mcool: 0.4217, Valid Loss: 0.4702, Valid MAE klw: 0.3864, Valid MAE mcool: 0.3664, Valid R2 klw: 0.7578, Valid R2 mcool: 0.7893
# Epoch 20/100, Train Loss: 0.5348, Train MAE klw: 0.3984, Train MAE mcool: 0.4197, Valid Loss: 0.5310, Valid MAE klw: 0.3932, Valid MAE mcool: 0.4137, Valid R2 klw: 0.7295, Valid R2 mcool: 0.7592
# Epoch 21/100, Train Loss: 0.4982, Train MAE klw: 0.3908, Train MAE mcool: 0.3986, Valid Loss: 0.4964, Valid MAE klw: 0.3895, Valid MAE mcool: 0.3826, Valid R2 klw: 0.7349, Valid R2 mcool: 0.7866
# Epoch 22/100, Train Loss: 0.4883, Train MAE klw: 0.3822, Train MAE mcool: 0.3974, Valid Loss: 0.4563, Valid MAE klw: 0.3589, Valid MAE mcool: 0.3585, Valid R2 klw: 0.7547, Valid R2 mcool: 0.8054
# Epoch 23/100, Train Loss: 0.4942, Train MAE klw: 0.3819, Train MAE mcool: 0.4009, Valid Loss: 0.4488, Valid MAE klw: 0.3794, Valid MAE mcool: 0.3682, Valid R2 klw: 0.7733, Valid R2 mcool: 0.7946
# Epoch 24/100, Train Loss: 0.4722, Train MAE klw: 0.3754, Train MAE mcool: 0.3908, Valid Loss: 0.6434, Valid MAE klw: 0.4014, Valid MAE mcool: 0.4875, Valid R2 klw: 0.7045, Valid R2 mcool: 0.6773
# Epoch 25/100, Train Loss: 0.4415, Train MAE klw: 0.3600, Train MAE mcool: 0.3760, Valid Loss: 0.4542, Valid MAE klw: 0.3906, Valid MAE mcool: 0.3761, Valid R2 klw: 0.7711, Valid R2 mcool: 0.7917
# Epoch 26/100, Train Loss: 0.4259, Train MAE klw: 0.3538, Train MAE mcool: 0.3706, Valid Loss: 0.6204, Valid MAE klw: 0.4289, Valid MAE mcool: 0.4735, Valid R2 klw: 0.7031, Valid R2 mcool: 0.7002
# Epoch 27/100, Train Loss: 0.4372, Train MAE klw: 0.3588, Train MAE mcool: 0.3720, Valid Loss: 0.4264, Valid MAE klw: 0.3909, Valid MAE mcool: 0.3315, Valid R2 klw: 0.7544, Valid R2 mcool: 0.8339
# Epoch 28/100, Train Loss: 0.4021, Train MAE klw: 0.3432, Train MAE mcool: 0.3619, Valid Loss: 0.5088, Valid MAE klw: 0.3662, Valid MAE mcool: 0.3931, Valid R2 klw: 0.7380, Valid R2 mcool: 0.7719
# Epoch 29/100, Train Loss: 0.4036, Train MAE klw: 0.3435, Train MAE mcool: 0.3572, Valid Loss: 0.3990, Valid MAE klw: 0.3452, Valid MAE mcool: 0.3343, Valid R2 klw: 0.7842, Valid R2 mcool: 0.8311
# Epoch 30/100, Train Loss: 0.4064, Train MAE klw: 0.3480, Train MAE mcool: 0.3604, Valid Loss: 0.4261, Valid MAE klw: 0.3806, Valid MAE mcool: 0.3551, Valid R2 klw: 0.7859, Valid R2 mcool: 0.8040
# Epoch 31/100, Train Loss: 0.4052, Train MAE klw: 0.3426, Train MAE mcool: 0.3633, Valid Loss: 0.3507, Valid MAE klw: 0.3210, Valid MAE mcool: 0.3144, Valid R2 klw: 0.8188, Valid R2 mcool: 0.8434
# Epoch 32/100, Train Loss: 0.3779, Train MAE klw: 0.3313, Train MAE mcool: 0.3431, Valid Loss: 0.3935, Valid MAE klw: 0.3503, Valid MAE mcool: 0.3402, Valid R2 klw: 0.8066, Valid R2 mcool: 0.8148
# Epoch 33/100, Train Loss: 0.3878, Train MAE klw: 0.3366, Train MAE mcool: 0.3500, Valid Loss: 0.3810, Valid MAE klw: 0.3425, Valid MAE mcool: 0.2920, Valid R2 klw: 0.7742, Valid R2 mcool: 0.8576
# Epoch 34/100, Train Loss: 0.3833, Train MAE klw: 0.3338, Train MAE mcool: 0.3508, Valid Loss: 0.3394, Valid MAE klw: 0.3268, Valid MAE mcool: 0.3182, Valid R2 klw: 0.8257, Valid R2 mcool: 0.8474
# Epoch 35/100, Train Loss: 0.3733, Train MAE klw: 0.3262, Train MAE mcool: 0.3461, Valid Loss: 0.3327, Valid MAE klw: 0.3079, Valid MAE mcool: 0.3066, Valid R2 klw: 0.8278, Valid R2 mcool: 0.8517
# Epoch 36/100, Train Loss: 0.3538, Train MAE klw: 0.3186, Train MAE mcool: 0.3374, Valid Loss: 0.3719, Valid MAE klw: 0.3327, Valid MAE mcool: 0.3201, Valid R2 klw: 0.8021, Valid R2 mcool: 0.8394
# Epoch 37/100, Train Loss: 0.3569, Train MAE klw: 0.3210, Train MAE mcool: 0.3345, Valid Loss: 0.3576, Valid MAE klw: 0.3349, Valid MAE mcool: 0.3081, Valid R2 klw: 0.7982, Valid R2 mcool: 0.8566
# Epoch 38/100, Train Loss: 0.3514, Train MAE klw: 0.3190, Train MAE mcool: 0.3332, Valid Loss: 0.3721, Valid MAE klw: 0.3455, Valid MAE mcool: 0.3233, Valid R2 klw: 0.8104, Valid R2 mcool: 0.8313
# Epoch 39/100, Train Loss: 0.3893, Train MAE klw: 0.3330, Train MAE mcool: 0.3556, Valid Loss: 0.4067, Valid MAE klw: 0.3437, Valid MAE mcool: 0.3639, Valid R2 klw: 0.8005, Valid R2 mcool: 0.8081
# Epoch 40/100, Train Loss: 0.3464, Train MAE klw: 0.3172, Train MAE mcool: 0.3262, Valid Loss: 0.3603, Valid MAE klw: 0.3412, Valid MAE mcool: 0.3215, Valid R2 klw: 0.8135, Valid R2 mcool: 0.8394
# Epoch 41/100, Train Loss: 0.3414, Train MAE klw: 0.3155, Train MAE mcool: 0.3262, Valid Loss: 0.3462, Valid MAE klw: 0.3324, Valid MAE mcool: 0.2906, Valid R2 klw: 0.8043, Valid R2 mcool: 0.8616
# Epoch 42/100, Train Loss: 0.3553, Train MAE klw: 0.3209, Train MAE mcool: 0.3359, Valid Loss: 0.5195, Valid MAE klw: 0.3648, Valid MAE mcool: 0.4098, Valid R2 klw: 0.7514, Valid R2 mcool: 0.7489
# Epoch 43/100, Train Loss: 0.3549, Train MAE klw: 0.3213, Train MAE mcool: 0.3340, Valid Loss: 0.3311, Valid MAE klw: 0.3133, Valid MAE mcool: 0.3045, Valid R2 klw: 0.8272, Valid R2 mcool: 0.8538
# Epoch 44/100, Train Loss: 0.3332, Train MAE klw: 0.3096, Train MAE mcool: 0.3261, Valid Loss: 0.3456, Valid MAE klw: 0.3448, Valid MAE mcool: 0.3138, Valid R2 klw: 0.8203, Valid R2 mcool: 0.8468
# Epoch 45/100, Train Loss: 0.3535, Train MAE klw: 0.3224, Train MAE mcool: 0.3328, Valid Loss: 0.3138, Valid MAE klw: 0.3161, Valid MAE mcool: 0.2970, Valid R2 klw: 0.8373, Valid R2 mcool: 0.8603
# Epoch 46/100, Train Loss: 0.3455, Train MAE klw: 0.3172, Train MAE mcool: 0.3279, Valid Loss: 0.3260, Valid MAE klw: 0.3263, Valid MAE mcool: 0.3058, Valid R2 klw: 0.8277, Valid R2 mcool: 0.8582
# Epoch 47/100, Train Loss: 0.3311, Train MAE klw: 0.3111, Train MAE mcool: 0.3223, Valid Loss: 0.4003, Valid MAE klw: 0.3415, Valid MAE mcool: 0.3307, Valid R2 klw: 0.7798, Valid R2 mcool: 0.8341
# Epoch 48/100, Train Loss: 0.3404, Train MAE klw: 0.3192, Train MAE mcool: 0.3221, Valid Loss: 0.4435, Valid MAE klw: 0.3681, Valid MAE mcool: 0.3821, Valid R2 klw: 0.7680, Valid R2 mcool: 0.8047
# Epoch 49/100, Train Loss: 0.3375, Train MAE klw: 0.3104, Train MAE mcool: 0.3291, Valid Loss: 0.3209, Valid MAE klw: 0.3151, Valid MAE mcool: 0.2871, Valid R2 klw: 0.8194, Valid R2 mcool: 0.8709
# Epoch 50/100, Train Loss: 0.3105, Train MAE klw: 0.3019, Train MAE mcool: 0.3102, Valid Loss: 0.3388, Valid MAE klw: 0.3136, Valid MAE mcool: 0.3056, Valid R2 klw: 0.8194, Valid R2 mcool: 0.8541
# Epoch 51/100, Train Loss: 0.3190, Train MAE klw: 0.3058, Train MAE mcool: 0.3133, Valid Loss: 0.5561, Valid MAE klw: 0.3977, Valid MAE mcool: 0.3820, Valid R2 klw: 0.6832, Valid R2 mcool: 0.7800
# Epoch 52/100, Train Loss: 0.3047, Train MAE klw: 0.2975, Train MAE mcool: 0.3061, Valid Loss: 0.3343, Valid MAE klw: 0.3440, Valid MAE mcool: 0.3000, Valid R2 klw: 0.8182, Valid R2 mcool: 0.8594
# Epoch 53/100, Train Loss: 0.3279, Train MAE klw: 0.3062, Train MAE mcool: 0.3228, Valid Loss: 0.3279, Valid MAE klw: 0.3269, Valid MAE mcool: 0.2952, Valid R2 klw: 0.8179, Valid R2 mcool: 0.8657
# Epoch 54/100, Train Loss: 0.3115, Train MAE klw: 0.3023, Train MAE mcool: 0.3125, Valid Loss: 0.4151, Valid MAE klw: 0.3536, Valid MAE mcool: 0.3287, Valid R2 klw: 0.7606, Valid R2 mcool: 0.8386
# Epoch 55/100, Train Loss: 0.3102, Train MAE klw: 0.2992, Train MAE mcool: 0.3096, Valid Loss: 0.2911, Valid MAE klw: 0.3081, Valid MAE mcool: 0.2834, Valid R2 klw: 0.8408, Valid R2 mcool: 0.8785
# Epoch 56/100, Train Loss: 0.3012, Train MAE klw: 0.2985, Train MAE mcool: 0.3034, Valid Loss: 0.2880, Valid MAE klw: 0.3051, Valid MAE mcool: 0.2595, Valid R2 klw: 0.8364, Valid R2 mcool: 0.8856
# Epoch 57/100, Train Loss: 0.2911, Train MAE klw: 0.2899, Train MAE mcool: 0.2980, Valid Loss: 0.3726, Valid MAE klw: 0.3508, Valid MAE mcool: 0.3398, Valid R2 klw: 0.8188, Valid R2 mcool: 0.8228
# Epoch 58/100, Train Loss: 0.3156, Train MAE klw: 0.3075, Train MAE mcool: 0.3088, Valid Loss: 0.2935, Valid MAE klw: 0.3009, Valid MAE mcool: 0.2773, Valid R2 klw: 0.8394, Valid R2 mcool: 0.8775
# Epoch 59/100, Train Loss: 0.2894, Train MAE klw: 0.2889, Train MAE mcool: 0.3000, Valid Loss: 0.2903, Valid MAE klw: 0.3049, Valid MAE mcool: 0.2735, Valid R2 klw: 0.8374, Valid R2 mcool: 0.8825
# Epoch 60/100, Train Loss: 0.2761, Train MAE klw: 0.2780, Train MAE mcool: 0.2944, Valid Loss: 0.2972, Valid MAE klw: 0.3071, Valid MAE mcool: 0.2898, Valid R2 klw: 0.8419, Valid R2 mcool: 0.8716
# Epoch 61/100, Train Loss: 0.2754, Train MAE klw: 0.2813, Train MAE mcool: 0.2902, Valid Loss: 0.3158, Valid MAE klw: 0.3246, Valid MAE mcool: 0.3157, Valid R2 klw: 0.8430, Valid R2 mcool: 0.8531
# Epoch 62/100, Train Loss: 0.2920, Train MAE klw: 0.2901, Train MAE mcool: 0.3026, Valid Loss: 0.3321, Valid MAE klw: 0.3468, Valid MAE mcool: 0.2929, Valid R2 klw: 0.8104, Valid R2 mcool: 0.8691
# Epoch 63/100, Train Loss: 0.2865, Train MAE klw: 0.2839, Train MAE mcool: 0.2996, Valid Loss: 0.3141, Valid MAE klw: 0.3161, Valid MAE mcool: 0.2804, Valid R2 klw: 0.8172, Valid R2 mcool: 0.8795
# Epoch 64/100, Train Loss: 0.2741, Train MAE klw: 0.2817, Train MAE mcool: 0.2907, Valid Loss: 0.2853, Valid MAE klw: 0.2958, Valid MAE mcool: 0.2685, Valid R2 klw: 0.8382, Valid R2 mcool: 0.8865
# Epoch 65/100, Train Loss: 0.2748, Train MAE klw: 0.2818, Train MAE mcool: 0.2890, Valid Loss: 0.2992, Valid MAE klw: 0.2995, Valid MAE mcool: 0.2803, Valid R2 klw: 0.8332, Valid R2 mcool: 0.8781
# Epoch 66/100, Train Loss: 0.2686, Train MAE klw: 0.2773, Train MAE mcool: 0.2888, Valid Loss: 0.3242, Valid MAE klw: 0.3161, Valid MAE mcool: 0.2932, Valid R2 klw: 0.8219, Valid R2 mcool: 0.8653
# Epoch 67/100, Train Loss: 0.2773, Train MAE klw: 0.2767, Train MAE mcool: 0.2956, Valid Loss: 0.3070, Valid MAE klw: 0.3086, Valid MAE mcool: 0.2833, Valid R2 klw: 0.8333, Valid R2 mcool: 0.8706
# Epoch 68/100, Train Loss: 0.2844, Train MAE klw: 0.2883, Train MAE mcool: 0.2926, Valid Loss: 0.2956, Valid MAE klw: 0.3019, Valid MAE mcool: 0.2838, Valid R2 klw: 0.8370, Valid R2 mcool: 0.8778
# Epoch 69/100, Train Loss: 0.2773, Train MAE klw: 0.2817, Train MAE mcool: 0.2920, Valid Loss: 0.2759, Valid MAE klw: 0.3026, Valid MAE mcool: 0.2601, Valid R2 klw: 0.8383, Valid R2 mcool: 0.8952
# Epoch 70/100, Train Loss: 0.2655, Train MAE klw: 0.2735, Train MAE mcool: 0.2895, Valid Loss: 0.2681, Valid MAE klw: 0.2844, Valid MAE mcool: 0.2746, Valid R2 klw: 0.8585, Valid R2 mcool: 0.8832
# Epoch 71/100, Train Loss: 0.2866, Train MAE klw: 0.2822, Train MAE mcool: 0.3011, Valid Loss: 0.3581, Valid MAE klw: 0.3201, Valid MAE mcool: 0.3306, Valid R2 klw: 0.8087, Valid R2 mcool: 0.8461
# Epoch 72/100, Train Loss: 0.2702, Train MAE klw: 0.2766, Train MAE mcool: 0.2898, Valid Loss: 0.3211, Valid MAE klw: 0.3025, Valid MAE mcool: 0.2921, Valid R2 klw: 0.8200, Valid R2 mcool: 0.8701
# Epoch 73/100, Train Loss: 0.2589, Train MAE klw: 0.2745, Train MAE mcool: 0.2775, Valid Loss: 0.2701, Valid MAE klw: 0.3022, Valid MAE mcool: 0.2708, Valid R2 klw: 0.8535, Valid R2 mcool: 0.8860
# Epoch 74/100, Train Loss: 0.2767, Train MAE klw: 0.2827, Train MAE mcool: 0.2935, Valid Loss: 0.2976, Valid MAE klw: 0.3182, Valid MAE mcool: 0.2813, Valid R2 klw: 0.8382, Valid R2 mcool: 0.8748
# Epoch 75/100, Train Loss: 0.2803, Train MAE klw: 0.2819, Train MAE mcool: 0.2948, Valid Loss: 0.3315, Valid MAE klw: 0.3099, Valid MAE mcool: 0.3139, Valid R2 klw: 0.8332, Valid R2 mcool: 0.8476
# Epoch 76/100, Train Loss: 0.2742, Train MAE klw: 0.2792, Train MAE mcool: 0.2898, Valid Loss: 0.3007, Valid MAE klw: 0.2762, Valid MAE mcool: 0.3089, Valid R2 klw: 0.8548, Valid R2 mcool: 0.8559
# Epoch 77/100, Train Loss: 0.2623, Train MAE klw: 0.2691, Train MAE mcool: 0.2895, Valid Loss: 0.2818, Valid MAE klw: 0.2859, Valid MAE mcool: 0.2831, Valid R2 klw: 0.8537, Valid R2 mcool: 0.8748
# Epoch 78/100, Train Loss: 0.2669, Train MAE klw: 0.2782, Train MAE mcool: 0.2885, Valid Loss: 0.2504, Valid MAE klw: 0.2757, Valid MAE mcool: 0.2562, Valid R2 klw: 0.8652, Valid R2 mcool: 0.8933
# Epoch 79/100, Train Loss: 0.2506, Train MAE klw: 0.2690, Train MAE mcool: 0.2761, Valid Loss: 0.2925, Valid MAE klw: 0.2960, Valid MAE mcool: 0.2665, Valid R2 klw: 0.8367, Valid R2 mcool: 0.8810
# Epoch 80/100, Train Loss: 0.2555, Train MAE klw: 0.2691, Train MAE mcool: 0.2839, Valid Loss: 0.2756, Valid MAE klw: 0.2901, Valid MAE mcool: 0.2564, Valid R2 klw: 0.8430, Valid R2 mcool: 0.8909
# Epoch 81/100, Train Loss: 0.2499, Train MAE klw: 0.2664, Train MAE mcool: 0.2756, Valid Loss: 0.4436, Valid MAE klw: 0.3719, Valid MAE mcool: 0.3273, Valid R2 klw: 0.7327, Valid R2 mcool: 0.8385
# Epoch 82/100, Train Loss: 0.2521, Train MAE klw: 0.2675, Train MAE mcool: 0.2772, Valid Loss: 0.2995, Valid MAE klw: 0.3077, Valid MAE mcool: 0.2679, Valid R2 klw: 0.8218, Valid R2 mcool: 0.8887
# Epoch 83/100, Train Loss: 0.2437, Train MAE klw: 0.2620, Train MAE mcool: 0.2757, Valid Loss: 0.4489, Valid MAE klw: 0.3759, Valid MAE mcool: 0.3310, Valid R2 klw: 0.7281, Valid R2 mcool: 0.8379
# Epoch 84/100, Train Loss: 0.2523, Train MAE klw: 0.2673, Train MAE mcool: 0.2791, Valid Loss: 0.2833, Valid MAE klw: 0.3191, Valid MAE mcool: 0.2715, Valid R2 klw: 0.8444, Valid R2 mcool: 0.8824
# Epoch 85/100, Train Loss: 0.2531, Train MAE klw: 0.2715, Train MAE mcool: 0.2769, Valid Loss: 0.2622, Valid MAE klw: 0.2907, Valid MAE mcool: 0.2586, Valid R2 klw: 0.8558, Valid R2 mcool: 0.8913
# Epoch 86/100, Train Loss: 0.2421, Train MAE klw: 0.2609, Train MAE mcool: 0.2711, Valid Loss: 0.2875, Valid MAE klw: 0.3026, Valid MAE mcool: 0.2668, Valid R2 klw: 0.8321, Valid R2 mcool: 0.8903
# Epoch 87/100, Train Loss: 0.2347, Train MAE klw: 0.2564, Train MAE mcool: 0.2703, Valid Loss: 0.2933, Valid MAE klw: 0.2992, Valid MAE mcool: 0.2542, Valid R2 klw: 0.8217, Valid R2 mcool: 0.8947
# Epoch 88/100, Train Loss: 0.2420, Train MAE klw: 0.2620, Train MAE mcool: 0.2762, Valid Loss: 0.4431, Valid MAE klw: 0.3406, Valid MAE mcool: 0.3644, Valid R2 klw: 0.7695, Valid R2 mcool: 0.8036
# Epoch 89/100, Train Loss: 0.2525, Train MAE klw: 0.2686, Train MAE mcool: 0.2797, Valid Loss: 0.2391, Valid MAE klw: 0.2774, Valid MAE mcool: 0.2450, Valid R2 klw: 0.8656, Valid R2 mcool: 0.9037
# Epoch 90/100, Train Loss: 0.2463, Train MAE klw: 0.2661, Train MAE mcool: 0.2748, Valid Loss: 0.2598, Valid MAE klw: 0.2862, Valid MAE mcool: 0.2642, Valid R2 klw: 0.8627, Valid R2 mcool: 0.8870
# Epoch 91/100, Train Loss: 0.2467, Train MAE klw: 0.2669, Train MAE mcool: 0.2739, Valid Loss: 0.3146, Valid MAE klw: 0.3214, Valid MAE mcool: 0.3050, Valid R2 klw: 0.8326, Valid R2 mcool: 0.8642
# Epoch 92/100, Train Loss: 0.2400, Train MAE klw: 0.2580, Train MAE mcool: 0.2701, Valid Loss: 0.2856, Valid MAE klw: 0.3139, Valid MAE mcool: 0.2574, Valid R2 klw: 0.8276, Valid R2 mcool: 0.8963
# Epoch 93/100, Train Loss: 0.2350, Train MAE klw: 0.2580, Train MAE mcool: 0.2697, Valid Loss: 0.2577, Valid MAE klw: 0.2845, Valid MAE mcool: 0.2588, Valid R2 klw: 0.8562, Valid R2 mcool: 0.8951
# Epoch 94/100, Train Loss: 0.2521, Train MAE klw: 0.2667, Train MAE mcool: 0.2782, Valid Loss: 0.2693, Valid MAE klw: 0.2925, Valid MAE mcool: 0.2476, Valid R2 klw: 0.8402, Valid R2 mcool: 0.8995
# Epoch 95/100, Train Loss: 0.2420, Train MAE klw: 0.2634, Train MAE mcool: 0.2719, Valid Loss: 0.2660, Valid MAE klw: 0.2946, Valid MAE mcool: 0.2670, Valid R2 klw: 0.8553, Valid R2 mcool: 0.8882
# Epoch 96/100, Train Loss: 0.2342, Train MAE klw: 0.2577, Train MAE mcool: 0.2674, Valid Loss: 0.2914, Valid MAE klw: 0.2958, Valid MAE mcool: 0.2758, Valid R2 klw: 0.8374, Valid R2 mcool: 0.8815
# Epoch 97/100, Train Loss: 0.2372, Train MAE klw: 0.2593, Train MAE mcool: 0.2717, Valid Loss: 0.2664, Valid MAE klw: 0.2938, Valid MAE mcool: 0.2540, Valid R2 klw: 0.8436, Valid R2 mcool: 0.8991
# Epoch 98/100, Train Loss: 0.2314, Train MAE klw: 0.2585, Train MAE mcool: 0.2673, Valid Loss: 0.2989, Valid MAE klw: 0.2992, Valid MAE mcool: 0.2850, Valid R2 klw: 0.8362, Valid R2 mcool: 0.8755
# Epoch 99/100, Train Loss: 0.2324, Train MAE klw: 0.2557, Train MAE mcool: 0.2674, Valid Loss: 0.3495, Valid MAE klw: 0.3097, Valid MAE mcool: 0.3140, Valid R2 klw: 0.8191, Valid R2 mcool: 0.8443
# Epoch 100/100, Train Loss: 0.2225, Train MAE klw: 0.2500, Train MAE mcool: 0.2598, Valid Loss: 0.3413, Valid MAE klw: 0.3136, Valid MAE mcool: 0.2996, Valid R2 klw: 0.8035, Valid R2 mcool: 0.8670
# Test Loss: 0.2624, Test MAE klw: 0.2864, Test MAE mcool: 0.2700, Test R2 klw: 0.8249, Test R2 mcool: 0.8295
# 部分测试集预测值与真实值（klw, mcool）：
# 样本 1: 预测值=[3.7251, 3.1517e+05], 真实值=[3.3300, 3.1800e+05]
# 样本 2: 预测值=[3.8019, 6.2324e+04], 真实值=[3.0700, 7.7900e+04]
# 样本 3: 预测值=[3.3531, 2.1958e+05], 真实值=[2.8200, 1.9400e+05]
# 样本 4: 预测值=[4.1593, 1.5748e+05], 真实值=[2.8200, 1.9400e+05]
# 样本 5: 预测值=[2.6225, 3.3283e+05], 真实值=[2.5200, 3.1500e+05]

# %% [markdown]
# 测试集参数估计可视化

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# MODIFIED: 设置学术论文字体和样式（全局配置）
plt.rcParams['font.size'] = 10  # 默认字体大小10pt
plt.rcParams['axes.titlesize'] = 12  # 标题12pt
plt.rcParams['axes.labelsize'] = 10  # 轴标签10pt
plt.rcParams['xtick.labelsize'] = 10  # x轴刻度10pt
plt.rcParams['ytick.labelsize'] = 10  # y轴刻度10pt
plt.rcParams['legend.fontsize'] = 10  # 图例10pt
plt.rcParams['lines.linewidth'] = 1.5  # 线宽1.5pt
plt.rcParams['lines.markersize'] = 6  # 标记大小6pt

# 加载数据（仅测试集）
_, _, test_loader = load_data()

# 初始化模型并加载最佳权重
model = CNN()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
model.load_state_dict(torch.load('best_model100.pt'))
model.eval()

# 测试模型，获取预测和真实值
test_loss, test_mae_klw, test_mae_mcool, predictions, trues = test_model(model, test_loader, w_klw=1.0, w_mcool=1.0)

# 反归一化
label_stats = torch.load('AngularPS/processed_tensors/202509/label_stats.pt')
mean = label_stats['mean']  # [klw_mean, mcool_mean]
std = label_stats['std']    # [klw_std, mcool_std]
predictions = predictions * std.numpy() + mean.numpy()  # 形状: (900, 2)
trues = trues * std.numpy() + mean.numpy()             # 形状: (900, 2)

# 1. 可视化预测结果：散点图比较预测值 vs 真实值（保持原样，但受益于全局字体）
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# k_LW的散点图
axes[0].scatter(trues[:, 0], predictions[:, 0], alpha=0.6, color='blue')
axes[0].plot([trues[:, 0].min(), trues[:, 0].max()], [trues[:, 0].min(), trues[:, 0].max()], 'r--', lw=1.5)
axes[0].set_xlabel('Real $k_{\mathrm{LW}}$')
axes[0].set_ylabel('Predicted $k_{\mathrm{LW}}$')
axes[0].set_title('$k_{\mathrm{LW}}$ Predicted vs Real')
axes[0].grid(True, alpha=0.3)
# M_cool的散点图（使用科学计数法）
axes[1].scatter(trues[:, 1], predictions[:, 1], alpha=0.6, color='green')
axes[1].plot([trues[:, 1].min(), trues[:, 1].max()], [trues[:, 1].min(), trues[:, 1].max()], 'r--', lw=1.5)
axes[1].set_xlabel('Real $M_{\mathrm{cool}}$')
axes[1].set_ylabel('Predicted $M_{\mathrm{cool}}$')
axes[1].set_title('$M_{\mathrm{cool}}$ Predicted vs Real')
axes[1].ticklabel_format(style='sci', axis='both', scilimits=(0,0))  # 科学计数法
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('prediction_scatter_10000.png', dpi=300, bbox_inches='tight')
plt.show()

# 2. 误差棒图：按真实值分组，计算对应预测值的范围（MODIFIED: 添加1sigma std范围）
# 第一张：按真实 k_LW 分组，计算预测 k_LW 的均值、std、max和min
unique_klw_real = np.unique(trues[:, 0])
unique_klw_real.sort()
mean_klw_pred = []  # MODIFIED: 新增均值
std_klw_pred = []   # MODIFIED: 新增标准差
max_klw_pred = []
min_klw_pred = []
sample_counts_klw = []
for klw_real in unique_klw_real:
    mask = np.isclose(trues[:, 0], klw_real, atol=1e-4)
    group_klw_preds = predictions[mask, 0]
    
    if len(group_klw_preds) > 1:  # MODIFIED: 至少2个样本才能计算std
        mean_klw_pred.append(np.mean(group_klw_preds))
        std_klw_pred.append(np.std(group_klw_preds))  # 1sigma = std
        max_klw_pred.append(np.max(group_klw_preds))
        min_klw_pred.append(np.min(group_klw_preds))
        sample_counts_klw.append(np.sum(mask))
    else:
        mean_klw_pred.append(np.nan)
        std_klw_pred.append(0)  # MODIFIED: std设为0，避免NaN
        max_klw_pred.append(np.nan)
        min_klw_pred.append(np.nan)
        sample_counts_klw.append(len(group_klw_preds))
mean_klw_pred = np.array(mean_klw_pred)
std_klw_pred = np.array(std_klw_pred)
max_klw_pred = np.array(max_klw_pred)
min_klw_pred = np.array(min_klw_pred)
sample_counts_klw = np.array(sample_counts_klw)

# 第二张：按真实 M_cool 分组，计算预测 M_cool 的均值、std、max和min
unique_mcool_real = np.unique(trues[:, 1])
unique_mcool_real.sort()
mean_mcool_pred = []  # MODIFIED: 新增均值
std_mcool_pred = []   # MODIFIED: 新增标准差
max_mcool_pred = []
min_mcool_pred = []
sample_counts_mcool = []
for mcool_real in unique_mcool_real:
    mask = np.isclose(trues[:, 1], mcool_real, atol=1e-4)
    group_mcool_preds = predictions[mask, 1]
    
    if len(group_mcool_preds) > 1:
        mean_mcool_pred.append(np.mean(group_mcool_preds))
        std_mcool_pred.append(np.std(group_mcool_preds))  # 1sigma = std
        max_mcool_pred.append(np.max(group_mcool_preds))
        min_mcool_pred.append(np.min(group_mcool_preds))
        sample_counts_mcool.append(np.sum(mask))
    else:
        mean_mcool_pred.append(np.nan)
        std_mcool_pred.append(0)
        max_mcool_pred.append(np.nan)
        min_mcool_pred.append(np.nan)
        sample_counts_mcool.append(len(group_mcool_preds))
mean_mcool_pred = np.array(mean_mcool_pred)
std_mcool_pred = np.array(std_mcool_pred)
max_mcool_pred = np.array(max_mcool_pred)
min_mcool_pred = np.array(min_mcool_pred)
sample_counts_mcool = np.array(sample_counts_mcool)

# 绘制误差棒图（MODIFIED: 双误差棒 + 学术样式）
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# 第一张：k_LW 误差棒图
# MODIFIED: 添加1sigma (std) 误差棒（蓝色，细线）
valid_idx_klw = ~np.isnan(mean_klw_pred)  # 只绘制有效组
axes[0].errorbar(unique_klw_real[valid_idx_klw], mean_klw_pred[valid_idx_klw], 
                 yerr=std_klw_pred[valid_idx_klw], fmt='o', capsize=3, color='blue', 
                 linewidth=1, elinewidth=1, markersize=6, label='1σ Prediction Range')
# 原max-min范围（绿色，粗线）
axes[0].errorbar(unique_klw_real[valid_idx_klw], (max_klw_pred[valid_idx_klw] + min_klw_pred[valid_idx_klw]) / 2, 
                 yerr=[(max_klw_pred[valid_idx_klw] - min_klw_pred[valid_idx_klw]) / 2], 
                 fmt='s', capsize=5, color='green', markerfacecolor='none', 
                 linewidth=1.5, elinewidth=1.5, markersize=6, label='Max-Min Prediction Range')
axes[0].plot(unique_klw_real, unique_klw_real, 'r--', lw=1.5, label='Ideal Line (y=x)')
axes[0].set_xlabel('Real $k_{\mathrm{LW}}$')
axes[0].set_ylabel('Predicted $k_{\mathrm{LW}}$')
axes[0].set_title('$k_{\mathrm{LW}}$ Prediction Ranges by Real $k_{\mathrm{LW}}$')
axes[0].legend(frameon=False)  # 无边框图例
axes[0].grid(True, alpha=0.3)

# 第二张：M_cool 误差棒图
# MODIFIED: 添加1sigma (std) 误差棒（蓝色，细线）
valid_idx_mcool = ~np.isnan(mean_mcool_pred)
axes[1].errorbar(unique_mcool_real[valid_idx_mcool], mean_mcool_pred[valid_idx_mcool], 
                 yerr=std_mcool_pred[valid_idx_mcool], fmt='o', capsize=3, color='blue', 
                 linewidth=1, elinewidth=1, markersize=6, label='1σ Prediction Range')
# 原max-min范围（绿色，粗线）
axes[1].errorbar(unique_mcool_real[valid_idx_mcool], (max_mcool_pred[valid_idx_mcool] + min_mcool_pred[valid_idx_mcool]) / 2, 
                 yerr=[(max_mcool_pred[valid_idx_mcool] - min_mcool_pred[valid_idx_mcool]) / 2], 
                 fmt='s', capsize=5, color='green', markerfacecolor='none', 
                 linewidth=1.5, elinewidth=1.5, markersize=6, label='Max-Min Prediction Range')
axes[1].plot(unique_mcool_real, unique_mcool_real, 'r--', lw=1.5, label='Ideal Line (y=x)')
axes[1].set_xlabel('Real $M_{\mathrm{cool}}$')
axes[1].set_ylabel('Predicted $M_{\mathrm{cool}}$')
axes[1].set_title('$M_{\mathrm{cool}}$ Prediction Ranges by Real $M_{\mathrm{cool}}$')
axes[1].ticklabel_format(style='sci', axis='both', scilimits=(0,0))  # 科学计数法
axes[1].legend(frameon=False)  # 无边框图例
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('error_bar_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# 打印分组统计（MODIFIED: 添加std信息）
print("k_LW 分组统计（真实 k_LW -> 预测 k_LW 范围）：")
for i, klw_real in enumerate(unique_klw_real):
    if not np.isnan(mean_klw_pred[i]):
        print(f"k_LW_real={klw_real:.2f}: mean={mean_klw_pred[i]:.4f}, 1σ=[{mean_klw_pred[i]-std_klw_pred[i]:.4f}, {mean_klw_pred[i]+std_klw_pred[i]:.4f}], "
              f"max-min=[{min_klw_pred[i]:.4f}, {max_klw_pred[i]:.4f}] (样本数: {sample_counts_klw[i]})")
print("\nM_cool 分组统计（真实 M_cool -> 预测 M_cool 范围）：")
for i, mcool_real in enumerate(unique_mcool_real):
    if not np.isnan(mean_mcool_pred[i]):
        print(f"M_cool_real={mcool_real:.4e}: mean={mean_mcool_pred[i]:.4e}, 1σ=[{mean_mcool_pred[i]-std_mcool_pred[i]:.4e}, {mean_mcool_pred[i]+std_mcool_pred[i]:.4e}], "
              f"max-min=[{min_mcool_pred[i]:.4e}, {max_mcool_pred[i]:.4e}] (样本数: {sample_counts_mcool[i]})")
# Out:
# 警告：test 数据集样本数量 (1332) 与预期 (990) 不符！
# torch.Size([7200, 1, 20, 40])
# torch.Size([7200, 2])
# 训练集: 7200 样本, 数据形状 torch.Size([1, 20, 40])
# 验证集: 900 样本, 数据形状 torch.Size([1, 20, 40])
# 测试集: 1332 样本, 数据形状 torch.Size([1, 20, 40])
# Test Loss: 0.2592, Test MAE klw: 0.2817, Test MAE mcool: 0.2727, Test R2 klw: 0.7951, Test R2 mcool: 0.7913
# k_LW 分组统计（真实 k_LW -> 预测 k_LW 范围）：
# k_LW_real=0.12: mean=0.4885, 1σ=[0.3114, 0.6657], max-min=[0.1722, 0.7083] (样本数: 18)
# k_LW_real=0.23: mean=0.5881, 1σ=[0.4407, 0.7356], max-min=[0.3521, 0.9268] (样本数: 18)
# k_LW_real=0.32: mean=0.6874, 1σ=[0.5207, 0.8542], max-min=[0.2707, 0.9050] (样本数: 18)
# k_LW_real=0.40: mean=0.8052, 1σ=[0.6602, 0.9501], max-min=[0.5456, 1.1938] (样本数: 18)
# k_LW_real=0.71: mean=1.1949, 1σ=[0.9849, 1.4050], max-min=[0.9495, 1.8214] (样本数: 18)
# k_LW_real=0.79: mean=0.8486, 1σ=[0.6621, 1.0351], max-min=[0.6184, 1.2841] (样本数: 18)
# k_LW_real=0.89: mean=1.3630, 1σ=[1.1295, 1.5965], max-min=[0.9475, 1.7325] (样本数: 18)
# k_LW_real=0.92: mean=1.4175, 1σ=[1.1917, 1.6433], max-min=[0.9485, 1.8465] (样本数: 18)
# k_LW_real=1.00: mean=1.0765, 1σ=[0.8185, 1.3346], max-min=[0.6621, 1.5414] (样本数: 18)
# k_LW_real=1.02: mean=1.3824, 1σ=[1.1305, 1.6343], max-min=[1.0050, 2.0173] (样本数: 18)
# k_LW_real=1.51: mean=2.2512, 1σ=[1.5910, 2.9114], max-min=[1.3993, 4.0011] (样本数: 18)
# k_LW_real=1.70: mean=1.8360, 1σ=[1.4988, 2.1731], max-min=[1.1339, 2.4625] (样本数: 18)
# k_LW_real=1.81: mean=2.2442, 1σ=[1.8697, 2.6188], max-min=[1.5631, 2.9071] (样本数: 36)
# k_LW_real=1.93: mean=2.0440, 1σ=[1.6839, 2.4041], max-min=[1.5217, 2.8419] (样本数: 18)
# k_LW_real=2.13: mean=2.7679, 1σ=[2.3886, 3.1473], max-min=[1.9508, 3.4512] (样本数: 18)
# k_LW_real=2.24: mean=2.6852, 1σ=[2.1393, 3.2311], max-min=[1.8832, 3.9006] (样本数: 18)
# k_LW_real=2.41: mean=2.8661, 1σ=[2.2808, 3.4515], max-min=[2.0356, 4.3840] (样本数: 18)
# k_LW_real=2.47: mean=2.8253, 1σ=[2.3609, 3.2896], max-min=[2.0875, 3.6260] (样本数: 18)
# k_LW_real=2.52: mean=3.1077, 1σ=[2.6911, 3.5244], max-min=[2.2928, 3.7041] (样本数: 18)
# k_LW_real=2.69: mean=3.1662, 1σ=[2.7195, 3.6128], max-min=[2.4269, 4.1424] (样本数: 18)
# k_LW_real=2.73: mean=3.2630, 1σ=[2.7648, 3.7613], max-min=[2.5112, 4.4205] (样本数: 18)
# k_LW_real=2.75: mean=3.3552, 1σ=[2.8482, 3.8623], max-min=[2.4467, 4.7828] (样本数: 18)
# k_LW_real=2.82: mean=3.2563, 1σ=[2.7622, 3.7505], max-min=[2.5221, 4.2440] (样本数: 18)
# k_LW_real=2.90: mean=3.4999, 1σ=[2.9504, 4.0495], max-min=[2.7480, 5.1125] (样本数: 18)
# k_LW_real=2.95: mean=3.3441, 1σ=[2.7054, 3.9829], max-min=[2.8500, 5.3183] (样本数: 18)
# k_LW_real=3.00: mean=3.4312, 1σ=[3.0301, 3.8323], max-min=[2.5334, 3.9656] (样本数: 18)
# k_LW_real=3.03: mean=3.4691, 1σ=[2.9584, 3.9798], max-min=[2.7009, 4.8321] (样本数: 18)
# k_LW_real=3.07: mean=3.4583, 1σ=[2.7720, 4.1445], max-min=[1.7962, 4.6524] (样本数: 18)
# k_LW_real=3.18: mean=3.8998, 1σ=[3.3875, 4.4121], max-min=[3.2424, 4.8435] (样本数: 18)
# k_LW_real=3.32: mean=4.3843, 1σ=[4.0015, 4.7672], max-min=[3.7856, 5.3518] (样本数: 18)
# k_LW_real=3.33: mean=3.8778, 1σ=[3.2957, 4.4598], max-min=[2.9353, 5.0800] (样本数: 18)
# k_LW_real=3.56: mean=4.0810, 1σ=[3.4196, 4.7424], max-min=[3.2329, 5.4926] (样本数: 18)
# k_LW_real=3.59: mean=4.1160, 1σ=[3.3739, 4.8581], max-min=[2.2674, 5.5206] (样本数: 18)
# k_LW_real=3.67: mean=3.8891, 1σ=[3.1862, 4.5920], max-min=[2.9599, 5.5571] (样本数: 18)
# k_LW_real=3.83: mean=3.9870, 1σ=[3.2109, 4.7631], max-min=[2.2053, 5.3601] (样本数: 18)
# k_LW_real=3.85: mean=4.0244, 1σ=[3.4061, 4.6428], max-min=[2.9621, 5.2618] (样本数: 18)
# k_LW_real=3.92: mean=4.0727, 1σ=[3.4437, 4.7016], max-min=[2.9527, 5.2323] (样本数: 18)
# k_LW_real=3.96: mean=4.2434, 1σ=[3.5873, 4.8995], max-min=[2.6742, 6.1874] (样本数: 360)
# k_LW_real=4.45: mean=5.1182, 1σ=[4.7284, 5.5079], max-min=[4.5031, 5.9138] (样本数: 18)
# k_LW_real=4.48: mean=4.5205, 1σ=[4.0690, 4.9719], max-min=[3.8060, 5.7100] (样本数: 18)
# k_LW_real=4.52: mean=4.3552, 1σ=[3.8070, 4.9034], max-min=[3.3402, 5.5773] (样本数: 18)
# k_LW_real=4.64: mean=4.8519, 1σ=[4.5767, 5.1271], max-min=[4.3968, 5.3984] (样本数: 18)
# k_LW_real=5.20: mean=4.9430, 1σ=[4.1689, 5.7171], max-min=[3.5459, 6.2359] (样本数: 18)
# k_LW_real=5.32: mean=5.1619, 1σ=[4.4941, 5.8297], max-min=[3.7083, 6.3895] (样本数: 18)
# k_LW_real=5.37: mean=4.6423, 1σ=[4.0033, 5.2814], max-min=[3.7714, 6.0146] (样本数: 18)
# k_LW_real=5.68: mean=4.9752, 1σ=[4.7209, 5.2294], max-min=[4.4051, 5.4678] (样本数: 18)
# k_LW_real=5.84: mean=6.1381, 1σ=[5.9491, 6.3271], max-min=[5.7645, 6.4481] (样本数: 18)
# k_LW_real=5.96: mean=5.1236, 1σ=[4.5111, 5.7361], max-min=[3.8564, 6.1209] (样本数: 18)
# k_LW_real=6.14: mean=6.0448, 1σ=[5.7851, 6.3046], max-min=[5.6331, 6.5988] (样本数: 18)
# k_LW_real=6.52: mean=5.7984, 1σ=[5.4956, 6.1012], max-min=[5.2689, 6.8527] (样本数: 36)
# k_LW_real=6.59: mean=5.0294, 1σ=[4.0346, 6.0242], max-min=[3.1088, 7.1740] (样本数: 18)
# k_LW_real=6.76: mean=5.1750, 1σ=[4.5066, 5.8434], max-min=[4.2390, 6.7588] (样本数: 18)
# k_LW_real=6.85: mean=5.9634, 1σ=[5.6816, 6.2451], max-min=[5.6491, 6.8681] (样本数: 18)
#
# M_cool 分组统计（真实 M_cool -> 预测 M_cool 范围）：
# M_cool_real=7.7900e+04: mean=7.8651e+04, 1σ=[5.3396e+04, 1.0391e+05], max-min=[3.5070e+04, 1.4320e+05] (样本数: 18)
# M_cool_real=8.5000e+04: mean=9.3354e+04, 1σ=[6.6637e+04, 1.2007e+05], max-min=[4.9798e+04, 1.4068e+05] (样本数: 18)
# M_cool_real=1.1700e+05: mean=1.3561e+05, 1σ=[1.1539e+05, 1.5583e+05], max-min=[8.8847e+04, 1.6477e+05] (样本数: 18)
# M_cool_real=1.1900e+05: mean=1.0463e+05, 1σ=[7.9634e+04, 1.2962e+05], max-min=[6.1173e+04, 1.5831e+05] (样本数: 18)
# M_cool_real=1.2100e+05: mean=1.4135e+05, 1σ=[1.1135e+05, 1.7135e+05], max-min=[7.3935e+04, 1.8638e+05] (样本数: 18)
# M_cool_real=1.2700e+05: mean=1.3612e+05, 1σ=[1.1571e+05, 1.5652e+05], max-min=[9.5769e+04, 1.8494e+05] (样本数: 36)
# M_cool_real=1.3300e+05: mean=1.3652e+05, 1σ=[1.0568e+05, 1.6736e+05], max-min=[5.6779e+04, 1.7447e+05] (样本数: 18)
# M_cool_real=1.4100e+05: mean=1.5819e+05, 1σ=[1.3795e+05, 1.7843e+05], max-min=[1.2472e+05, 1.8590e+05] (样本数: 18)
# M_cool_real=1.7800e+05: mean=1.8522e+05, 1σ=[1.6069e+05, 2.0975e+05], max-min=[1.4388e+05, 2.3214e+05] (样本数: 18)
# M_cool_real=1.8200e+05: mean=1.6572e+05, 1σ=[1.3877e+05, 1.9267e+05], max-min=[1.1955e+05, 2.2009e+05] (样本数: 18)
# M_cool_real=1.8700e+05: mean=2.5899e+05, 1σ=[2.0513e+05, 3.1284e+05], max-min=[1.4947e+05, 3.6359e+05] (样本数: 18)
# M_cool_real=1.9000e+05: mean=2.1112e+05, 1σ=[1.7702e+05, 2.4523e+05], max-min=[1.4817e+05, 2.8828e+05] (样本数: 18)
# M_cool_real=1.9400e+05: mean=1.9979e+05, 1σ=[1.7188e+05, 2.2770e+05], max-min=[1.4010e+05, 2.4711e+05] (样本数: 18)
# M_cool_real=2.1800e+05: mean=2.9209e+05, 1σ=[2.5657e+05, 3.2760e+05], max-min=[2.1754e+05, 3.5856e+05] (样本数: 18)
# M_cool_real=2.2000e+05: mean=2.2307e+05, 1σ=[1.9971e+05, 2.4644e+05], max-min=[1.8101e+05, 2.8414e+05] (样本数: 18)
# M_cool_real=2.2900e+05: mean=2.3288e+05, 1σ=[2.1021e+05, 2.5555e+05], max-min=[2.0147e+05, 2.9498e+05] (样本数: 18)
# M_cool_real=2.3200e+05: mean=2.3867e+05, 1σ=[2.1298e+05, 2.6435e+05], max-min=[1.8898e+05, 2.9364e+05] (样本数: 18)
# M_cool_real=2.4800e+05: mean=2.5697e+05, 1σ=[2.3432e+05, 2.7963e+05], max-min=[2.1472e+05, 2.9516e+05] (样本数: 18)
# M_cool_real=2.4900e+05: mean=2.5581e+05, 1σ=[2.1628e+05, 2.9534e+05], max-min=[1.5389e+05, 2.9946e+05] (样本数: 18)
# M_cool_real=2.5500e+05: mean=3.0245e+05, 1σ=[2.6947e+05, 3.3544e+05], max-min=[2.5232e+05, 3.5693e+05] (样本数: 18)
# M_cool_real=2.5800e+05: mean=2.8716e+05, 1σ=[2.3706e+05, 3.3725e+05], max-min=[1.9834e+05, 3.6540e+05] (样本数: 18)
# M_cool_real=2.6200e+05: mean=2.5466e+05, 1σ=[2.2918e+05, 2.8014e+05], max-min=[2.0347e+05, 3.1317e+05] (样本数: 18)
# M_cool_real=2.7600e+05: mean=2.7732e+05, 1σ=[2.3697e+05, 3.1767e+05], max-min=[1.8818e+05, 3.3290e+05] (样本数: 18)
# M_cool_real=2.7700e+05: mean=3.0511e+05, 1σ=[2.5393e+05, 3.5629e+05], max-min=[2.1717e+05, 4.3808e+05] (样本数: 18)
# M_cool_real=2.8100e+05: mean=2.8362e+05, 1σ=[2.3694e+05, 3.3031e+05], max-min=[2.1557e+05, 4.0665e+05] (样本数: 18)
# M_cool_real=3.0200e+05: mean=2.9064e+05, 1σ=[2.5806e+05, 3.2322e+05], max-min=[2.3313e+05, 3.5490e+05] (样本数: 18)
# M_cool_real=3.1300e+05: mean=3.3108e+05, 1σ=[2.9025e+05, 3.7192e+05], max-min=[2.6383e+05, 4.0270e+05] (样本数: 18)
# M_cool_real=3.1500e+05: mean=2.9788e+05, 1σ=[2.6846e+05, 3.2729e+05], max-min=[2.5268e+05, 3.4980e+05] (样本数: 18)
# M_cool_real=3.1800e+05: mean=3.1025e+05, 1σ=[2.7042e+05, 3.5008e+05], max-min=[2.1128e+05, 3.5873e+05] (样本数: 18)
# M_cool_real=3.2500e+05: mean=3.3844e+05, 1σ=[2.9309e+05, 3.8379e+05], max-min=[2.2514e+05, 4.1231e+05] (样本数: 18)
# M_cool_real=3.2800e+05: mean=3.3441e+05, 1σ=[2.8913e+05, 3.7969e+05], max-min=[1.9731e+05, 4.6093e+05] (样本数: 360)
# M_cool_real=3.2900e+05: mean=3.3145e+05, 1σ=[2.9562e+05, 3.6728e+05], max-min=[2.2022e+05, 3.8383e+05] (样本数: 18)
# M_cool_real=3.3200e+05: mean=3.7526e+05, 1σ=[3.5319e+05, 3.9733e+05], max-min=[3.2529e+05, 4.2939e+05] (样本数: 18)
# M_cool_real=3.3500e+05: mean=3.4455e+05, 1σ=[3.1652e+05, 3.7259e+05], max-min=[2.8091e+05, 3.9717e+05] (样本数: 18)
# M_cool_real=3.4700e+05: mean=3.4004e+05, 1σ=[3.0046e+05, 3.7961e+05], max-min=[2.7160e+05, 4.3992e+05] (样本数: 36)
# M_cool_real=3.6700e+05: mean=3.7340e+05, 1σ=[3.3564e+05, 4.1116e+05], max-min=[2.9576e+05, 4.3952e+05] (样本数: 18)
# M_cool_real=3.7000e+05: mean=4.1876e+05, 1σ=[3.9696e+05, 4.4055e+05], max-min=[3.6606e+05, 4.5204e+05] (样本数: 18)
# M_cool_real=3.8200e+05: mean=4.0181e+05, 1σ=[3.6111e+05, 4.4251e+05], max-min=[3.0988e+05, 4.7030e+05] (样本数: 36)
# M_cool_real=3.9800e+05: mean=3.7915e+05, 1σ=[3.4428e+05, 4.1403e+05], max-min=[3.2001e+05, 4.3886e+05] (样本数: 18)
# M_cool_real=4.0000e+05: mean=3.7784e+05, 1σ=[3.4065e+05, 4.1502e+05], max-min=[2.5197e+05, 4.4977e+05] (样本数: 36)
# M_cool_real=4.0200e+05: mean=3.7606e+05, 1σ=[3.3596e+05, 4.1617e+05], max-min=[2.7326e+05, 4.2744e+05] (样本数: 18)
# M_cool_real=4.1000e+05: mean=3.9938e+05, 1σ=[3.7474e+05, 4.2402e+05], max-min=[3.4718e+05, 4.2951e+05] (样本数: 18)
# M_cool_real=4.1400e+05: mean=4.4282e+05, 1σ=[4.2216e+05, 4.6348e+05], max-min=[3.9619e+05, 4.7633e+05] (样本数: 18)
# M_cool_real=4.2000e+05: mean=3.8267e+05, 1σ=[3.4470e+05, 4.2065e+05], max-min=[2.6694e+05, 4.4317e+05] (样本数: 18)
# M_cool_real=4.3600e+05: mean=3.8275e+05, 1σ=[3.6048e+05, 4.0503e+05], max-min=[3.4097e+05, 4.2625e+05] (样本数: 18)
# M_cool_real=4.4200e+05: mean=3.9288e+05, 1σ=[3.5293e+05, 4.3284e+05], max-min=[3.0947e+05, 4.4664e+05] (样本数: 18)
# M_cool_real=4.4300e+05: mean=4.3795e+05, 1σ=[4.2415e+05, 4.5175e+05], max-min=[4.0528e+05, 4.5983e+05] (样本数: 18)
# M_cool_real=4.7200e+05: mean=4.1705e+05, 1σ=[3.6673e+05, 4.6736e+05], max-min=[2.9712e+05, 5.0647e+05] (样本数: 18)
# M_cool_real=4.8400e+05: mean=4.4911e+05, 1σ=[4.3174e+05, 4.6648e+05], max-min=[4.0443e+05, 4.7274e+05] (样本数: 18)
# M_cool_real=4.9400e+05: mean=4.3990e+05, 1σ=[4.0631e+05, 4.7348e+05], max-min=[3.6838e+05, 5.0341e+05] (样本数: 18)
# M_cool_real=4.9600e+05: mean=3.9583e+05, 1σ=[3.6833e+05, 4.2332e+05], max-min=[3.4342e+05, 4.6364e+05] (样本数: 18)

# %%
# ====================== 灰度版：低密度纯白色 + 高密度深黑 + 轴对齐 + 完整3σ ======================

from scipy.stats import gaussian_kde
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# 选取样本组（保持不变）
tol = 1e-6
trues_rounded = np.round(trues, decimals=8)
unique_combinations = np.unique(trues_rounded, axis=0)
unique_combinations = unique_combinations[np.lexsort((unique_combinations[:, 1], unique_combinations[:, 0]))]

selected_real_pair = unique_combinations[36]  # 可修改索引切换组
print(f"\n选中的样本组：")
print(f"真实 k_LW = {selected_real_pair[0]:.4f}")
print(f"真实 M_cool = {selected_real_pair[1]:.4e} M_⊙")

mask = np.all(np.isclose(trues, selected_real_pair, atol=tol), axis=1)
selected_predictions = predictions[mask]
sample_count = len(selected_predictions)
print(f"该组样本数量：{sample_count}")

pred_klw = selected_predictions[:, 0]
pred_mcool = selected_predictions[:, 1]

# ==================== 绘图 ====================
fig = plt.figure(figsize=(9.5, 7.5))
gs = gridspec.GridSpec(2, 2, width_ratios=[4, 1], height_ratios=[1, 4],
                       wspace=0.08, hspace=0.08)

# 主图 + 共享轴
ax_main = fig.add_subplot(gs[1, 0])
ax_top = fig.add_subplot(gs[0, 0], sharex=ax_main)
ax_right = fig.add_subplot(gs[1, 1], sharey=ax_main)

# 计算 3.5σ 范围，确保完整显示分布
mean_klw, std_klw = np.mean(pred_klw), np.std(pred_klw)
mean_mcool, std_mcool = np.mean(pred_mcool), np.std(pred_mcool)

pad_sigma = 3.5
xmin = mean_klw - pad_sigma * std_klw
xmax = mean_klw + pad_sigma * std_klw
ymin = mean_mcool - pad_sigma * std_mcool
ymax = mean_mcool + pad_sigma * std_mcool

# 轻微额外边距
margin_x = 0.03 * (xmax - xmin)
margin_y = 0.03 * (ymax - ymin)
xmin -= margin_x
xmax += margin_x
ymin -= margin_y
ymax += margin_y

ax_main.set_xlim(xmin, xmax)
ax_main.set_ylim(ymin, ymax)

# 二维 KDE
kde = gaussian_kde(np.vstack([pred_klw, pred_mcool]))
X, Y = np.mgrid[xmin:xmax:400j, ymin:ymax:400j]
positions = np.vstack([X.ravel(), Y.ravel()])
Z = np.reshape(kde(positions).T, X.shape)

# 自定义灰度 colormap：低密度纯白 → 高密度深黑
base_cmap = plt.cm.gray_r  # 反转灰度（原gray_r是低值黑，高值白）
cmap_colors = base_cmap(np.linspace(0, 1, 256))
cmap_colors[0] = [1, 1, 1, 1]  # 强制最低密度为纯白
white_to_black = ListedColormap(cmap_colors)

levels = np.linspace(Z.min(), Z.max(), 60)
cf = ax_main.contourf(X, Y, Z, levels=levels, cmap=white_to_black, extend='min')

# 无等高线，只保留平滑填充

# 红色真实值线（在灰度图中红色仍很醒目）
ax_main.axvline(selected_real_pair[0], color='red', linestyle='--', linewidth=1.8)
ax_main.axhline(selected_real_pair[1], color='red', linestyle='--', linewidth=1.8)

ax_main.set_xlabel('Predicted $k_{\\mathrm{LW}}$')
ax_main.set_ylabel('Predicted $M_{\\mathrm{cool}}$ ($M_{\\odot}$)')
ax_main.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax_main.tick_params(axis='y', pad=8)
ax_main.grid(True, alpha=0.3, color='lightgray')

# 上方一维 KDE（深灰色与主图协调）
kde_klw = gaussian_kde(pred_klw)
x_klw = np.linspace(xmin, xmax, 400)
ax_top.plot(x_klw, kde_klw(x_klw), color='black', lw=2.2)
ax_top.axvline(selected_real_pair[0], color='red', linestyle='--', linewidth=1.8)
ax_top.set_ylabel('Density')
ax_top.set_title(f'Real: $k_{{\\mathrm{{LW}}}} = {selected_real_pair[0]:.3f}$, '
                 f'$M_{{\\mathrm{{cool}}}} = {selected_real_pair[1]:.2e}$ $M_{{\\odot}}$')
ax_top.grid(True, alpha=0.3)
ax_top.tick_params(labelbottom=False)

# 右侧一维 KDE
kde_mcool = gaussian_kde(pred_mcool)
y_mcool = np.linspace(ymin, ymax, 400)
ax_right.plot(kde_mcool(y_mcool), y_mcool, color='black', lw=2.2)
ax_right.axhline(selected_real_pair[1], color='red', linestyle='--', linewidth=1.8)
ax_right.set_xlabel('Density')
ax_right.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax_right.tick_params(axis='x', pad=8)
ax_right.tick_params(labelleft=False)
ax_right.grid(True, alpha=0.3)

# 颜色条
cbar_ax = fig.add_axes([0.93, 0.15, 0.02, 0.7])
cbar = fig.colorbar(cf, cax=cbar_ax)
cbar.set_label('Probability Density')

plt.tight_layout(rect=[0, 0, 0.91, 1])
plt.savefig('2d_prediction_density_nonoise.png', dpi=300, bbox_inches='tight')
plt.show()

# 输出统计
print(f"\n该组预测统计：")
print(f"预测 k_LW:  mean = {np.mean(pred_klw):.6f} ± {np.std(pred_klw):.6f}")
print(f"预测 M_cool: mean = {np.mean(pred_mcool):.8e} ± {np.std(pred_mcool):.8e}")
# Out:
# 选中的样本组：
# 真实 k_LW = 3.8500
# 真实 M_cool = 3.1300e+05 M_⊙
# 该组样本数量：18
# /tmp/ipykernel_2493574/2985090649.py:113: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.91, 1])
# 该组预测统计：
# 预测 k_LW:  mean = 3.998195 ± 0.633133
# 预测 M_cool: mean = 3.26545219e+05 ± 4.34110508e+04

# %%
import pandas as pd
import numpy as np

# --- k_LW 分组：收集所有预测值 ---
klw_groups = []  # 存储每组的信息

for klw_real in unique_klw_real:
    mask = np.isclose(trues[:, 0], klw_real, atol=1e-4)
    group_preds = predictions[mask, 0]  # 该组所有预测的 k_LW 值
    
    if len(group_preds) > 0:  # 只保存有样本的组
        klw_groups.append({
            "k_LW_real": round(klw_real, 4),
            "sample_count": len(group_preds),
            "k_LW_pred_mean": np.mean(group_preds),
            "k_LW_pred_std": np.std(group_preds),
            "k_LW_pred_min": np.min(group_preds),
            "k_LW_pred_max": np.max(group_preds),
            "all_k_LW_predictions": group_preds.tolist()  # 保存所有单个预测值（列表）
        })

df_klw_full = pd.DataFrame(klw_groups)

# 保存为 CSV（pandas 会自动将列表转为字符串显示，但内容完整保留）
df_klw_full.to_csv("k_LW_group_stats_nonoise_new.csv", index=False)
print("已保存：k_LW_group_all_predictions.csv")
print(f"一共 {len(df_klw_full)} 个 k_LW 分组，每组所有预测值已完整保存。")
print(df_klw_full[['k_LW_real', 'sample_count', 'k_LW_pred_mean', 'k_LW_pred_std', 'k_LW_pred_min', 'k_LW_pred_max']])  # 预览统计列


# --- M_cool 分组：收集所有预测值 ---
mcool_groups = []

for mcool_real in unique_mcool_real:
    mask = np.isclose(trues[:, 1], mcool_real, atol=1e-4)
    group_preds = predictions[mask, 1]  # 该组所有预测的 M_cool 值
    
    if len(group_preds) > 0:
        mcool_groups.append({
            "M_cool_real": mcool_real,  # 科学计数法，保持原样
            "sample_count": len(group_preds),
            "M_cool_pred_mean": np.mean(group_preds),
            "M_cool_pred_std": np.std(group_preds),
            "M_cool_pred_min": np.min(group_preds),
            "M_cool_pred_max": np.max(group_preds),
            "all_M_cool_predictions": group_preds.tolist()  # 所有单个预测值
        })

df_mcool_full = pd.DataFrame(mcool_groups)

df_mcool_full.to_csv("M_cool_group_stats_nonoise_new.csv", index=False)
print("\n已保存：M_cool_group_all_predictions.csv")
print(f"一共 {len(df_mcool_full)} 个 M_cool 分组，每组所有预测值已完整保存。")
print(df_mcool_full[['M_cool_real', 'sample_count', 'M_cool_pred_mean', 'M_cool_pred_std', 'M_cool_pred_min', 'M_cool_pred_max']])
# Out:
# 已保存：k_LW_group_all_predictions.csv
# 一共 53 个 k_LW 分组，每组所有预测值已完整保存。
#     k_LW_real  sample_count  k_LW_pred_mean  k_LW_pred_std  k_LW_pred_min  \
# 0        0.12            18        0.605963       0.374484      -0.455717
# 1        0.23            18        0.724456       0.177738       0.100595
# 2        0.32            18        0.739854       0.223415       0.441018
# 3        0.40            18        0.750707       0.322843       0.184206
# 4        0.71            18        1.269025       0.236872       0.836106
# 5        0.79            18        0.789284       0.212734       0.435923
# 6        0.89            18        1.265379       0.237177       0.809461
# 7        0.92            18        1.474686       0.330527       0.882885
# 8        1.00            18        1.126307       0.162817       0.703244
# 9        1.02            18        1.385215       0.310606       0.667950
# 10       1.51            18        2.235673       0.402350       1.468411
# 11       1.70            18        1.978109       0.437490       1.332016
# 12       1.81            36        2.462197       0.515815       1.680278
# 13       1.93            18        2.377307       0.635151       1.523559
# 14       2.13            18        2.811986       0.473020       2.083969
# 15       2.24            18        2.773426       0.504695       1.972301
# 16       2.41            18        3.248906       0.523706       2.304727
# 17       2.47            18        3.265728       0.654150       2.274800
# 18       2.52            18        3.149845       0.631675       2.270310
# 19       2.69            18        2.603268       0.668537       1.771098
# 20       2.73            18        3.205715       0.520773       2.472960
# 21       2.75            18        3.693477       0.525972       2.702505
# 22       2.82            18        3.117588       0.488963       2.192677
# 23       2.90            18        4.044661       0.733171       3.176859
# 24       2.95            18        3.457647       0.672015       2.390588
# 25       3.00            18        3.218386       0.553017       2.297887
# 26       3.03            18        3.633978       0.678565       2.442731
# 27       3.07            18        2.992545       0.852004       1.343490
# 28       3.18            18        4.286412       0.436138       3.650859
# 29       3.32            18        4.706316       0.438266       3.988362
# 30       3.33            18        3.980515       0.610016       2.835238
# 31       3.56            18        3.741869       0.480312       2.810549
# 32       3.59            18        4.066502       0.807959       2.117136
# 33       3.67            18        4.145688       0.705731       2.866484
# 34       3.83            18        3.768559       0.836847       2.166563
# 35       3.85            18        3.999076       0.752608       2.798702
# 36       3.92            18        3.670215       0.735416       2.526462
# 37       3.96           108        4.361857       0.721238       3.148967
# 38       4.45            18        5.230880       0.405296       4.511874
# 39       4.48            18        4.552092       0.460614       3.639002
# 40       4.52            18        4.425007       0.741279       3.166265
# 41       4.64            18        5.089720       0.324862       4.366519
# 42       5.20            18        4.697034       0.576912       3.478761
# 43       5.32            18        4.685800       0.863842       3.025594
# 44       5.37            18        4.269942       0.577919       3.303613
# 45       5.68            18        4.979515       0.396278       4.156993
# 46       5.84            18        6.474190       0.176445       6.045167
# 47       5.96            18        4.790462       0.618843       3.953773
# 48       6.14            18        6.284289       0.259299       5.670510
# 49       6.52            36        6.105008       0.301773       5.464691
# 50       6.59            18        4.508020       1.084942       2.839835
# 51       6.76            18        4.942202       0.551164       3.867903
# 52       6.85            18        6.147944       0.213071       5.839067
#
#     k_LW_pred_max
# 0        1.086370
# 1        0.953433
# 2        1.184900
# 3        1.417725
# 4        1.840717
# 5        1.318775
# 6        1.736617
# 7        2.346569
# 8        1.448607
# 9        2.117528
# 10       3.002537
# 11       2.897999
# 12       4.250922
# 13       3.808600
# 14       3.889811
# 15       3.923796
# 16       4.537957
# 17       4.461953
# 18       4.505216
# 19       4.036993
# 20       4.269613
# 21       4.644377
# 22       4.011340
# 23       5.853246
# 24       4.891233
# 25       4.385897
# 26       5.176739
# 27       4.384242
# 28       5.410836
# 29       5.596187
# 30       5.248477
# 31       4.417838
# 32       5.451981
# 33       5.620342
# 34       5.482931
# 35       5.338857
# 36       4.864347
# 37       6.284186
# 38       6.094761
# 39       5.441626
# 40       5.800224
# 41       5.776196
# 42       5.448674
# 43       6.015396
# 44       5.376122
# 45       5.635810
# 46       6.784643
# 47       5.741329
# 48       6.968712
# 49       6.940897
# 50       6.852792
# 51       5.947244
# 52       6.490139
#
# 已保存：M_cool_group_all_predictions.csv
# 一共 51 个 M_cool 分组，每组所有预测值已完整保存。
#     M_cool_real  sample_count  M_cool_pred_mean  M_cool_pred_std  \
# 0       77900.0            18      98324.312500     41738.171875
# 1       85000.0            18     105273.460938     32938.406250
# 2      117000.0            18     156157.890625     34439.253906
# 3      119000.0            18     111782.421875     27890.296875
# 4      121000.0            18     164803.093750     34481.234375
# 5      127000.0            36     136011.000000     30454.289062
# 6      133000.0            18     130548.281250     21975.070312
# 7      141000.0            18     159103.937500     32446.951172
# 8      178000.0            18     178045.609375     25760.277344
# 9      182000.0            18     172924.250000     53979.425781
# 10     187000.0            18     305773.812500     74418.835938
# 11     190000.0            18     242020.062500     51883.859375
# 12     194000.0            18     215054.687500     32947.289062
# 13     218000.0            18     310930.562500     37704.644531
# 14     220000.0            18     218635.875000     32836.203125
# 15     229000.0            18     227538.546875     30406.238281
# 16     232000.0            18     259099.687500     41775.378906
# 17     248000.0            18     250700.687500     32233.994141
# 18     249000.0            18     259489.031250     47972.601562
# 19     255000.0            18     329928.000000     38429.187500
# 20     258000.0            18     315929.500000     47214.742188
# 21     262000.0            18     262207.937500     36674.148438
# 22     276000.0            18     301152.593750     39331.945312
# 23     277000.0            18     332128.625000     63841.855469
# 24     281000.0            18     298959.125000     63343.250000
# 25     302000.0            18     301559.687500     27373.960938
# 26     313000.0            18     344693.875000     55685.695312
# 27     315000.0            18     301527.093750     38119.058594
# 28     318000.0            18     309156.562500     48999.441406
# 29     325000.0            18     329125.218750     47523.609375
# 30     328000.0           108     333780.937500     47664.074219
# 31     329000.0            18     327670.593750     45363.511719
# 32     332000.0            18     389267.125000     39496.578125
# 33     335000.0            18     328811.718750     49808.464844
# 34     347000.0            36     342764.812500     43160.656250
# 35     367000.0            18     383046.125000     43618.015625
# 36     370000.0            18     400858.562500     21100.345703
# 37     382000.0            36     383021.625000     54016.472656
# 38     398000.0            18     371643.750000     19381.425781
# 39     400000.0            36     375671.375000     36396.996094
# 40     402000.0            18     357633.625000     34545.851562
# 41     410000.0            18     396167.406250     21395.556641
# 42     414000.0            18     428922.875000     17527.515625
# 43     420000.0            18     362146.250000     42070.855469
# 44     436000.0            18     379656.000000     31708.726562
# 45     442000.0            18     363939.062500     40019.292969
# 46     443000.0            18     418287.625000     12535.786133
# 47     472000.0            18     386593.968750     65101.113281
# 48     484000.0            18     427259.500000     12114.658203
# 49     494000.0            18     400006.562500     50909.394531
# 50     496000.0            18     378475.406250     38627.843750
#
#     M_cool_pred_min  M_cool_pred_max
# 0      27754.125000    189796.093750
# 1      56153.078125    183143.750000
# 2      89451.328125    213184.875000
# 3      84813.796875    201214.531250
# 4     116213.406250    249530.984375
# 5      61655.093750    212706.500000
# 6      94288.093750    179279.000000
# 7     117090.906250    253328.937500
# 8     137149.562500    231527.562500
# 9     101727.562500    311441.656250
# 10    182718.687500    461549.156250
# 11    165586.109375    331936.812500
# 12    156362.812500    254285.000000
# 13    241850.500000    401100.187500
# 14    162105.046875    273551.375000
# 15    179026.312500    292781.625000
# 16    160964.000000    314217.843750
# 17    181580.000000    298719.437500
# 18    166660.093750    345882.781250
# 19    272967.906250    386886.156250
# 20    256274.531250    432462.562500
# 21    184369.781250    329226.218750
# 22    234127.281250    367594.687500
# 23    222098.281250    494655.812500
# 24    204680.531250    485514.312500
# 25    243171.718750    348861.593750
# 26    252756.953125    432051.750000
# 27    209276.937500    358873.500000
# 28    231181.656250    389775.500000
# 29    237134.937500    427788.625000
# 30    229746.625000    436942.437500
# 31    227740.062500    405969.250000
# 32    329251.062500    497566.156250
# 33    210856.031250    420817.375000
# 34    262517.750000    440210.937500
# 35    313364.781250    474207.687500
# 36    354292.343750    440634.437500
# 37    242114.921875    469671.343750
# 38    341320.875000    413582.625000
# 39    290772.500000    441703.500000
# 40    290812.843750    425839.500000
# 41    343877.781250    429653.468750
# 42    398790.562500    469091.250000
# 43    308671.500000    447333.031250
# 44    333373.906250    470373.125000
# 45    282180.062500    428053.000000
# 46    392181.125000    456089.875000
# 47    257034.531250    476944.187500
# 48    397895.437500    454999.218750
# 49    281953.625000    524274.312500
# 50    315393.062500    445318.375000

# %%
# ====================== 最终优化版：PD=0 纯白色 + YlOrRd 色系 + 轴对齐 + 完整3σ ======================

from scipy.stats import gaussian_kde
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# 选取样本组（保持不变）
tol = 1e-6
trues_rounded = np.round(trues, decimals=8)
unique_combinations = np.unique(trues_rounded, axis=0)
unique_combinations = unique_combinations[np.lexsort((unique_combinations[:, 1], unique_combinations[:, 0]))]

selected_real_pair = unique_combinations[36]  # 可修改索引切换组
print(f"\n选中的样本组：")
print(f"真实 k_LW = {selected_real_pair[0]:.4f}")
print(f"真实 M_cool = {selected_real_pair[1]:.4e} M_⊙")

mask = np.all(np.isclose(trues, selected_real_pair, atol=tol), axis=1)
selected_predictions = predictions[mask]
sample_count = len(selected_predictions)
print(f"该组样本数量：{sample_count}")

pred_klw = selected_predictions[:, 0]
pred_mcool = selected_predictions[:, 1]

# ==================== 绘图 ====================
fig = plt.figure(figsize=(9.5, 7.5))
gs = gridspec.GridSpec(2, 2, width_ratios=[4, 1], height_ratios=[1, 4],
                       wspace=0.08, hspace=0.08)

# 主图 + 共享轴
ax_main = fig.add_subplot(gs[1, 0])
ax_top = fig.add_subplot(gs[0, 0], sharex=ax_main)
ax_right = fig.add_subplot(gs[1, 1], sharey=ax_main)

# 计算 3.5σ 范围，确保完整显示椭圆
mean_klw, std_klw = np.mean(pred_klw), np.std(pred_klw)
mean_mcool, std_mcool = np.mean(pred_mcool), np.std(pred_mcool)

pad_sigma = 3.5
xmin = mean_klw - pad_sigma * std_klw
xmax = mean_klw + pad_sigma * std_klw
ymin = mean_mcool - pad_sigma * std_mcool
ymax = mean_mcool + pad_sigma * std_mcool

# 轻微额外边距
margin_x = 0.03 * (xmax - xmin)
margin_y = 0.03 * (ymax - ymin)
xmin -= margin_x
xmax += margin_x
ymin -= margin_y
ymax += margin_y

ax_main.set_xlim(xmin, xmax)
ax_main.set_ylim(ymin, ymax)

# 二维 KDE
kde = gaussian_kde(np.vstack([pred_klw, pred_mcool]))
X, Y = np.mgrid[xmin:xmax:400j, ymin:ymax:400j]  # 高分辨率
positions = np.vstack([X.ravel(), Y.ravel()])
Z = np.reshape(kde(positions).T, X.shape)

# 新色系：YlOrRd + 强制最低值为纯白色
base_cmap = plt.cm.YlOrRd
cmap_colors = base_cmap(np.linspace(0, 1, 256))
cmap_colors[0] = [1, 1, 1, 1]  # PD=0 强制纯白
white_ylorrd = ListedColormap(cmap_colors)

levels = np.linspace(Z.min(), Z.max(), 50)  # 从实际最小值开始，确保低区白色
cf = ax_main.contourf(X, Y, Z, levels=levels, cmap=white_ylorrd, extend='min')

# 移除所有等高线（只保留平滑填充）

# 红色真实值线
ax_main.axvline(selected_real_pair[0], color='red', linestyle='--', linewidth=1.8)
ax_main.axhline(selected_real_pair[1], color='red', linestyle='--', linewidth=1.8)

ax_main.set_xlabel('Predicted $k_{\\mathrm{LW}}$')
ax_main.set_ylabel('Predicted $M_{\\mathrm{cool}}$ ($M_{\\odot}$)')
ax_main.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax_main.tick_params(axis='y', pad=8)
ax_main.grid(True, alpha=0.3, color='gray', lw=0.5)

# 上方一维 KDE（颜色与主图协调）
kde_klw = gaussian_kde(pred_klw)
x_klw = np.linspace(xmin, xmax, 400)
ax_top.plot(x_klw, kde_klw(x_klw), color='darkred', lw=2.2)
ax_top.axvline(selected_real_pair[0], color='red', linestyle='--', linewidth=1.8)
ax_top.set_ylabel('Density')
ax_top.set_title(f'Real: $k_{{\\mathrm{{LW}}}} = {selected_real_pair[0]:.3f}$, '
                 f'$M_{{\\mathrm{{cool}}}} = {selected_real_pair[1]:.2e}$ $M_{{\\odot}}$')
ax_top.grid(True, alpha=0.3)
ax_top.tick_params(labelbottom=False)

# 右侧一维 KDE
kde_mcool = gaussian_kde(pred_mcool)
y_mcool = np.linspace(ymin, ymax, 400)
ax_right.plot(kde_mcool(y_mcool), y_mcool, color='darkred', lw=2.2)
ax_right.axhline(selected_real_pair[1], color='red', linestyle='--', linewidth=1.8)
ax_right.set_xlabel('Density')
ax_right.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax_right.tick_params(axis='x', pad=8)
ax_right.tick_params(labelleft=False)
ax_right.grid(True, alpha=0.3)

# 颜色条（更长、更清晰）
cbar_ax = fig.add_axes([0.93, 0.15, 0.02, 0.7])
cbar = fig.colorbar(cf, cax=cbar_ax)
cbar.set_label('Probability Density')

plt.tight_layout(rect=[0, 0, 0.91, 1])
plt.savefig('2d_prediction_density_white_background_ylorrd.png', dpi=300, bbox_inches='tight')
plt.show()

# 输出统计
print(f"\n该组预测统计：")
print(f"预测 k_LW:  mean = {mean_klw:.6f} ± {std_klw:.6f}")
print(f"预测 M_cool: mean = {mean_mcool:.8e} ± {std_mcool:.8e}")
# Out:
# 选中的样本组：
# 真实 k_LW = 3.8500
# 真实 M_cool = 3.1300e+05 M_⊙
# 该组样本数量：18
# /tmp/ipykernel_2493574/750594342.py:113: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.91, 1])
# 该组预测统计：
# 预测 k_LW:  mean = 3.998195 ± 0.633133
# 预测 M_cool: mean = 3.26545219e+05 ± 4.34110508e+04

# %%
# ====================== 最终方案：σ 阶梯纯色填充（地形图风格） ======================

from scipy.stats import gaussian_kde
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap, BoundaryNorm

# ==================== 样本选择（保持不变） ====================
tol = 1e-6
trues_rounded = np.round(trues, decimals=8)
unique_combinations = np.unique(trues_rounded, axis=0)
unique_combinations = unique_combinations[np.lexsort(
    (unique_combinations[:, 1], unique_combinations[:, 0]))
]

selected_real_pair = unique_combinations[38]
print(f"\n选中的样本组：")
print(f"真实 k_LW = {selected_real_pair[0]:.4f}")
print(f"真实 M_cool = {selected_real_pair[1]:.4e} M_⊙")

mask = np.all(np.isclose(trues, selected_real_pair, atol=tol), axis=1)
selected_predictions = predictions[mask]
sample_count = len(selected_predictions)
print(f"该组样本数量：{sample_count}")

pred_klw = selected_predictions[:, 0]
pred_mcool = selected_predictions[:, 1]

# ==================== 画布布局 ====================
fig = plt.figure(figsize=(9.5, 7.5))
gs = gridspec.GridSpec(
    2, 2, width_ratios=[4, 1], height_ratios=[1, 4],
    wspace=0.08, hspace=0.08
)

ax_main = fig.add_subplot(gs[1, 0])
ax_top = fig.add_subplot(gs[0, 0], sharex=ax_main)
ax_right = fig.add_subplot(gs[1, 1], sharey=ax_main)

# ==================== 视野范围（完整 3.5σ） ====================
mean_klw, std_klw = np.mean(pred_klw), np.std(pred_klw)
mean_mcool, std_mcool = np.mean(pred_mcool), np.std(pred_mcool)

pad_sigma = 3.5
xmin = mean_klw - pad_sigma * std_klw
xmax = mean_klw + pad_sigma * std_klw
ymin = mean_mcool - pad_sigma * std_mcool
ymax = mean_mcool + pad_sigma * std_mcool

margin_x = 0.03 * (xmax - xmin)
margin_y = 0.03 * (ymax - ymin)
xmin -= margin_x
xmax += margin_x
ymin -= margin_y
ymax += margin_y

ax_main.set_xlim(xmin, xmax)
ax_main.set_ylim(ymin, ymax)

# ==================== 2D KDE ====================
kde = gaussian_kde(np.vstack([pred_klw, pred_mcool]))
X, Y = np.mgrid[xmin:xmax:400j, ymin:ymax:400j]
positions = np.vstack([X.ravel(), Y.ravel()])
Z = np.reshape(kde(positions).T, X.shape)

# ==================== σ 等概率区域计算（核心） ====================
Z_flat = Z.flatten()
idx = np.argsort(Z_flat)[::-1]
Z_sorted = Z_flat[idx]

cdf = np.cumsum(Z_sorted)
cdf /= cdf[-1]

sigma_probs = [0.393, 0.6827, 0.866, 0.9545, 0.9973]
pdf_levels = [Z_sorted[np.searchsorted(cdf, p)] for p in sigma_probs]

levels = [0.0] + sorted(pdf_levels) + [Z.max()]

# ==================== 离散纯色（地形图风格） ====================
sigma_colors = [
    "#ffffff",  # <0.5σ（背景）
    "#fff7bc",  # 0.5σ
    "#fee391",  # 1σ
    "#fec44f",  # 1.5σ
    "#fe9929",  # 2σ
    "#d95f0e",  # 3σ（核心）
]


cmap = ListedColormap(sigma_colors)
norm = BoundaryNorm(levels, cmap.N)

# ==================== 主图：σ 阶梯填色 ====================
cf = ax_main.contourf(
    X, Y, Z,
    levels=levels,
    cmap=cmap,
    norm=norm,
    antialiased=True
)

# σ 边界线（可选但强烈推荐）
ax_main.contour(
    X, Y, Z,
    levels=levels[2:-1],
    colors='k',
    linewidths=1.1
)

# ==================== 真实值 ====================
ax_main.axvline(selected_real_pair[0], color='red', ls='--', lw=1.8)
ax_main.axhline(selected_real_pair[1], color='red', ls='--', lw=1.8)

ax_main.set_xlabel('Predicted $k_{\\mathrm{LW}}$')
ax_main.set_ylabel('Predicted $M_{\\mathrm{cool}}$ ($\\mathrm{{M_{{\\odot}}}}$)')
ax_main.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
ax_main.grid(True, alpha=0.3, lw=0.5)

# ==================== 上方 1D KDE ====================
kde_klw = gaussian_kde(pred_klw)
x_klw = np.linspace(xmin, xmax, 400)
ax_top.plot(x_klw, kde_klw(x_klw), color='darkred', lw=2.2)
ax_top.axvline(selected_real_pair[0], color='red', ls='--', lw=1.8)
ax_top.set_ylabel('PDF')
ax_top.set_title(
    f'Real: $k_{{\\mathrm{{LW}}}}={selected_real_pair[0]:.3f}$, '
    f'$M_{{\\mathrm{{cool}}}}={selected_real_pair[1]:.2e} \\mathrm{{M_{{\\odot}}}}$'
)
ax_top.grid(True, alpha=0.3)
ax_top.tick_params(labelbottom=False)

# ==================== 右侧 1D KDE ====================
kde_mcool = gaussian_kde(pred_mcool)
y_mcool = np.linspace(ymin, ymax, 400)
ax_right.plot(kde_mcool(y_mcool), y_mcool, color='darkred', lw=2.2)
ax_right.axhline(selected_real_pair[1], color='red', ls='--', lw=1.8)
ax_right.set_xlabel('PDF')
ax_right.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
ax_right.tick_params(labelleft=False)
ax_right.grid(True, alpha=0.3)

# ==================== 颜色条（σ 标注） ====================
cbar_ax = fig.add_axes([0.93, 0.15, 0.02, 0.7])
cbar = fig.colorbar(cf, cax=cbar_ax)
cbar.set_ticks([
    (levels[i] + levels[i+1]) / 2 for i in range(1, 6)
])

cbar.set_ticklabels([
    '0.5σ', '1σ', '1.5σ', '2σ', '3σ'
])

cbar.set_label(' ')

plt.tight_layout(rect=[0, 0, 0.91, 1])
plt.savefig('2d_prediction_density_nonoise.pdf',
            dpi=300, bbox_inches='tight')
plt.show()

# ==================== 统计输出 ====================
print(f"\n预测统计：")
print(f"k_LW   = {mean_klw:.6f} ± {std_klw:.6f}")
print(f"M_cool = {mean_mcool:.8e} ± {std_mcool:.8e}")
# Out:
# 选中的样本组：
# 真实 k_LW = 3.9600
# 真实 M_cool = 3.2800e+05 M_⊙
# 该组样本数量：360
# /tmp/ipykernel_2493574/3271103118.py:156: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.91, 1])
# 预测统计：
# k_LW   = 4.243397 ± 0.656075
# M_cool = 3.34411344e+05 ± 4.52793672e+04
