# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchmetrics import MeanAbsoluteError
from torch.utils.data import TensorDataset, DataLoader
print(f'PyTorch Version: {torch.__version__}')
print(f'CUDA Available: {torch.cuda.is_available()}')
print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# PyTorch Version: 2.9.1+cu128
# CUDA Available: True
# GPU: NVIDIA GeForce RTX 5080

# %% [markdown]
# 检查路径

# %%
import os
print(os.listdir('modelD/processed_tensors/caseB'))
# Out:
# ['valid_data.pt', 'test_exdata.pt', 'label_stats.pt', 'train_data.pt', 'test_data.pt']

# %% [markdown]
# 导入数据

# %%
def load_data():
    # 加载训练数据
    train_data = torch.load('modelD/processed_tensors/caseB/train_data.pt')
    train_dataset = TensorDataset(train_data['images'], train_data['labels'])
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    valid_data = torch.load('modelD/processed_tensors/caseB/valid_data.pt')
    valid_dataset = TensorDataset(valid_data['images'], valid_data['labels'])
    valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=True)

    test_data = torch.load('modelD/processed_tensors/caseB/test_exdata.pt')
    test_dataset = TensorDataset(test_data['images'], test_data['labels'])
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

    # 验证样本数量
    expected_sizes = {'train': 28800, 'valid': 3600, 'test': 3600}
    for dataset_type, dataset, data in [
        ('train', train_dataset, train_data),
        ('valid', valid_dataset, valid_data),
        ('test', test_dataset, test_data)
    ]:
        actual_size = len(dataset)
        expected_size = expected_sizes[dataset_type]
        if actual_size != expected_size:
            print(f"警告：{dataset_type} 数据集样本数量 ({actual_size}) 与预期 ({expected_size}) 不符！")

    print(train_data['images'].shape)  # 预期：(7200, 1, 20, 39)
    print(train_data['labels'].shape)  # 预期：(7200,)
    print(f"训练集: {len(train_dataset)} 样本, 数据形状 {train_dataset[0][0].shape}")
    print(f"验证集: {len(valid_dataset)} 样本, 数据形状 {valid_dataset[0][0].shape}")
    print(f"测试集: {len(test_dataset)} 样本, 数据形状 {test_dataset[0][0].shape}")
    return train_loader, valid_loader, test_loader

if __name__ == "__main__":
    train_loader, valid_loader, test_loader = load_data()
# Out:
# 警告：test 数据集样本数量 (4644) 与预期 (3600) 不符！
# torch.Size([28800, 1, 20, 40])
# torch.Size([28800, 2])
# 训练集: 28800 样本, 数据形状 torch.Size([1, 20, 40])
# 验证集: 3600 样本, 数据形状 torch.Size([1, 20, 40])
# 测试集: 4644 样本, 数据形状 torch.Size([1, 20, 40])

# %% [markdown]
# 定义CNN模型

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        # 输入形状 (1, 20, 40)
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)  # 输出 (32, 20, 40)
        self.bn1 = nn.BatchNorm2d(32)  # 批归一化
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)  # 输出 (32, 10, 20)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # 输出 (64, 10, 20)
        self.bn2 = nn.BatchNorm2d(64)  # 批归一化
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)  # 输出 (64, 5, 10)
        self.flatten = nn.Flatten()
        # 计算全连接层输入维度：5 * 10 * 64 = 3200
        self.fc1 = nn.Linear(5 * 10 * 64, 256)  # 更新为3200
        self.relu3 = nn.ReLU()
        self.dropout = nn.Dropout(0.2)  # 可根据验证集性能调整到0.1-0.4
        self.fc2 = nn.Linear(256, 2)  # 双输出，回归任务 (klw, mcool)

    def forward(self, x):
        x = self.pool1(self.relu1(self.bn1(self.conv1(x))))
        x = self.pool2(self.relu2(self.bn2(self.conv2(x))))
        x = self.flatten(x)
        x = self.relu3(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# 定义训练函数

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchmetrics import MeanAbsoluteError
import pandas as pd
import os
from torch.optim.lr_scheduler import ReduceLROnPlateau

def r2_score(y_true, y_pred):
    ss_res = torch.sum((y_true - y_pred) ** 2)
    ss_tot = torch.sum((y_true - torch.mean(y_true)) ** 2)
    return 1 - (ss_res / ss_tot) if ss_tot > 0 else torch.tensor(0.0)

def train_model(model, train_loader, valid_loader, 
                epochs=200, patience=30, 
                w_klw=1.0, w_mcool=1.0,
                save_csv_path='modelD/training_history_caseB.csv'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    
    model = model.to(device)
    criterion = nn.MSELoss()
    mae = MeanAbsoluteError().to(device)
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-3)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=15, min_lr=1e-6)

    best_valid_loss = float('inf')
    early_stop_counter = 0

    # 用于记录训练历史的字典
    history = {
        'epoch': [],
        'train_loss': [],
        'train_mae_klw': [], 'train_mae_mcool': [],
        'valid_loss': [],
        'valid_mae_klw': [], 'valid_mae_mcool': [],
        'valid_r2_klw': [], 'valid_r2_mcool': []
    }

    for epoch in range(epochs):
        # =================== Training ===================
        model.train()
        train_loss = 0.0
        train_mae_klw = 0.0
        train_mae_mcool = 0.0
        train_samples = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            output = model(x)  # (B, 2)
            
            loss_klw = criterion(output[:, 0], y[:, 0]) * w_klw
            loss_mcool = criterion(output[:, 1], y[:, 1]) * w_mcool
            loss = loss_klw + loss_mcool
            
            loss.backward()
            optimizer.step()
            
            batch_size = x.size(0)
            train_loss += loss.item() * batch_size
            train_mae_klw += mae(output[:, 0], y[:, 0]).item() * batch_size
            train_mae_mcool += mae(output[:, 1], y[:, 1]).item() * batch_size
            train_samples += batch_size
        
        train_loss /= train_samples
        train_mae_klw /= train_samples
        train_mae_mcool /= train_samples

        # =================== Validation ===================
        model.eval()
        valid_loss = 0.0
        valid_mae_klw = 0.0
        valid_mae_mcool = 0.0
        valid_samples = 0
        all_preds = []
        all_trues = []
        
        with torch.no_grad():
            for x, y in valid_loader:
                x, y = x.to(device), y.to(device)
                output = model(x)
                
                loss_klw = criterion(output[:, 0], y[:, 0]) * w_klw
                loss_mcool = criterion(output[:, 1], y[:, 1]) * w_mcool
                loss = loss_klw + loss_mcool
                
                batch_size = x.size(0)
                valid_loss += loss.item() * batch_size
                valid_mae_klw += mae(output[:, 0], y[:, 0]).item() * batch_size
                valid_mae_mcool += mae(output[:, 1], y[:, 1]).item() * batch_size
                valid_samples += batch_size
                
                all_preds.append(output.cpu())
                all_trues.append(y.cpu())
        
        valid_loss /= valid_samples
        valid_mae_klw /= valid_samples
        valid_mae_mcool /= valid_samples
        
        all_pred = torch.cat(all_preds, dim=0)
        all_true = torch.cat(all_trues, dim=0)
        valid_r2_klw = r2_score(all_true[:, 0], all_pred[:, 0]).item()
        valid_r2_mcool = r2_score(all_true[:, 1], all_pred[:, 1]).item()

        # =================== Record History ===================
        history['epoch'].append(epoch + 1)
        history['train_loss'].append(train_loss)
        history['train_mae_klw'].append(train_mae_klw)
        history['train_mae_mcool'].append(train_mae_mcool)
        history['valid_loss'].append(valid_loss)
        history['valid_mae_klw'].append(valid_mae_klw)
        history['valid_mae_mcool'].append(valid_mae_mcool)
        history['valid_r2_klw'].append(valid_r2_klw)
        history['valid_r2_mcool'].append(valid_r2_mcool)

        print(f'Epoch {epoch+1:3d}/{epochs} | '
              f'Train Loss: {train_loss:.4f} | Train MAE klw: {train_mae_klw:.4f} | Train MAE mcool: {train_mae_mcool:.4f} | '
              f'Valid Loss: {valid_loss:.4f} | Valid MAE klw: {valid_mae_klw:.4f} | Valid MAE mcool: {valid_mae_mcool:.4f} | '
              f'Valid R² klw: {valid_r2_klw:.4f} | Valid R² mcool: {valid_r2_mcool:.4f}')

        # =================== Early Stopping & Save Best ===================
        scheduler.step(valid_loss)
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            os.makedirs(os.path.dirname('modelD/best_model_caseB.pt'), exist_ok=True)
            torch.save(model.state_dict(), 'modelD/best_model_caseB.pt')
            early_stop_counter = 0
            print("  → New best model saved!")
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                print(f"\nEarly stopping triggered at epoch {epoch+1}")
                break

    # =================== Save History to CSV ===================
    if save_csv_path:
        os.makedirs(os.path.dirname(save_csv_path), exist_ok=True)
        df_history = pd.DataFrame(history)
        df_history.to_csv(save_csv_path, index=False)
        print(f"\nTraining history saved to: {save_csv_path}")

    # 加载最佳模型
    print("Loading best model weights...")
    model.load_state_dict(torch.load('modelD/best_model_caseB.pt'))
    
    return model, history  # 返回模型和历史记录

# %% [markdown]
# 定义测试函数

# %%
import numpy as np
np.random.seed(100000)

def test_model(model, test_loader, w_klw=1.0, w_mcool=1):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.eval()
    criterion = nn.MSELoss()  # 均方误差损失，适用于多输出回归
    mae = MeanAbsoluteError().to(device)  # MAE指标
    test_loss, test_mae_klw, test_mae_mcool = 0.0, 0.0, 0.0
    test_samples = 0
    predictions, trues = [], []

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)  # x: (batch_size, 1, 20, 40), y: (batch_size, 2)
            output = model(x)  # output: (batch_size, 2)
            
            # 计算加权损失
            loss_klw = criterion(output[:, 0], y[:, 0]) * w_klw  # klw的损失
            loss_mcool = criterion(output[:, 1], y[:, 1]) * w_mcool  # mcool的损失
            loss = loss_klw + loss_mcool
            
            # 累积损失和MAE
            test_loss += loss.item() * x.size(0)
            test_mae_klw += mae(output[:, 0], y[:, 0]).item() * x.size(0)
            test_mae_mcool += mae(output[:, 1], y[:, 1]).item() * x.size(0)
            test_samples += x.size(0)
            
            # 存储预测和真实值
            predictions.append(model(x.to(device)).cpu())  # (batch_size, 2)
            trues.append(y.cpu())  # (batch_size, 2)
        all_pred = torch.cat(predictions, dim=0)
        all_true = torch.cat(trues, dim=0)
        test_r2_klw = r2_score(all_true[:, 0], all_pred[:, 0])
        test_r2_mcool = r2_score(all_true[:, 1], all_pred[:, 1])

    test_loss /= test_samples
    test_mae_klw /= test_samples
    test_mae_mcool /= test_samples
    predictions = np.concatenate(predictions, axis=0)  # 形状：(N, 2)
    trues = np.concatenate(trues, axis=0)  # 形状：(N, 2)

    print(f'Test Loss: {test_loss:.4f}, Test MAE klw: {test_mae_klw:.4f}, Test MAE mcool: {test_mae_mcool:.4f}, Test R2 klw: {test_r2_klw:.4f}, Test R2 mcool: {test_r2_mcool:.4f}')
    return test_loss, test_mae_klw, test_mae_mcool, predictions, trues

# %% [markdown]
# 主程序：加载数据、训练和测试

# %%
# 加载数据
train_loader, valid_loader, test_loader = load_data()

# 初始化模型
model = CNN()

# 训练（使用归一化标签，权重设为1.0）
model, history = train_model(
    model, train_loader, valid_loader,
    epochs=400,
    patience=80,
    w_klw=1.0,
    w_mcool=1.0,
    save_csv_path='modelD/training_history_caseB.csv'
)

# 加载最佳模型
model.load_state_dict(torch.load('modelD/best_model_caseB.pt'))

# 测试
test_loss, test_mae_klw, test_mae_mcool, predictions, trues = test_model(model, test_loader, w_klw=1.0, w_mcool=1.0)

# 反归一化
label_stats = torch.load('modelD/processed_tensors/caseB/label_stats.pt')
mean, std = label_stats['mean'], label_stats['std']
predictions = predictions * std.numpy() + mean.numpy()
trues = trues * std.numpy() + mean.numpy()

# 打印结果
print("部分测试集预测值与真实值（klw, mcool）：")
for i in range(min(5, len(predictions))):
    print(f"样本 {i+1}: 预测值=[{predictions[i, 0]:.4f}, {predictions[i, 1]:.4e}], "
          f"真实值=[{trues[i, 0]:.4f}, {trues[i, 1]:.4e}]")
# Out:
# torch.Size([28800, 1, 20, 40])
# torch.Size([28800, 2])
# 训练集: 28800 样本, 数据形状 torch.Size([1, 20, 40])
# 验证集: 3600 样本, 数据形状 torch.Size([1, 20, 40])
# 测试集: 3600 样本, 数据形状 torch.Size([1, 20, 40])
# Using device: cuda
# Epoch   1/400 | Train Loss: 1.1980 | Train MAE klw: 0.5889 | Train MAE mcool: 0.6761 | Valid Loss: 1.0040 | Valid MAE klw: 0.5289 | Valid MAE mcool: 0.6185 | Valid R² klw: 0.5743 | Valid R² mcool: 0.3148
#   → New best model saved!
# Epoch   2/400 | Train Loss: 1.1442 | Train MAE klw: 0.5812 | Train MAE mcool: 0.6604 | Valid Loss: 1.0291 | Valid MAE klw: 0.5586 | Valid MAE mcool: 0.6111 | Valid R² klw: 0.5393 | Valid R² mcool: 0.3248
# Epoch   3/400 | Train Loss: 1.1236 | Train MAE klw: 0.5769 | Train MAE mcool: 0.6532 | Valid Loss: 0.9915 | Valid MAE klw: 0.5456 | Valid MAE mcool: 0.6074 | Valid R² klw: 0.5608 | Valid R² mcool: 0.3443
#   → New best model saved!
# Epoch   4/400 | Train Loss: 1.0480 | Train MAE klw: 0.5607 | Train MAE mcool: 0.6239 | Valid Loss: 0.8701 | Valid MAE klw: 0.5223 | Valid MAE mcool: 0.5627 | Valid R² klw: 0.5952 | Valid R² mcool: 0.4462
#   → New best model saved!
# Epoch   5/400 | Train Loss: 0.9660 | Train MAE klw: 0.5435 | Train MAE mcool: 0.5903 | Valid Loss: 0.8179 | Valid MAE klw: 0.4863 | Valid MAE mcool: 0.5649 | Valid R² klw: 0.6373 | Valid R² mcool: 0.4596
#   → New best model saved!
# Epoch   6/400 | Train Loss: 0.8743 | Train MAE klw: 0.5240 | Train MAE mcool: 0.5490 | Valid Loss: 0.6484 | Valid MAE klw: 0.4387 | Valid MAE mcool: 0.4818 | Valid R² klw: 0.6890 | Valid R² mcool: 0.5976
#   → New best model saved!
# Epoch   7/400 | Train Loss: 0.8696 | Train MAE klw: 0.5236 | Train MAE mcool: 0.5440 | Valid Loss: 0.6632 | Valid MAE klw: 0.4242 | Valid MAE mcool: 0.5101 | Valid R² klw: 0.6964 | Valid R² mcool: 0.5724
# Epoch   8/400 | Train Loss: 0.8109 | Train MAE klw: 0.5110 | Train MAE mcool: 0.5119 | Valid Loss: 0.6139 | Valid MAE klw: 0.4221 | Valid MAE mcool: 0.4795 | Valid R² klw: 0.7027 | Valid R² mcool: 0.6223
#   → New best model saved!
# Epoch   9/400 | Train Loss: 0.7681 | Train MAE klw: 0.5011 | Train MAE mcool: 0.4910 | Valid Loss: 0.5737 | Valid MAE klw: 0.4367 | Valid MAE mcool: 0.4392 | Valid R² klw: 0.7031 | Valid R² mcool: 0.6683
#   → New best model saved!
# Epoch  10/400 | Train Loss: 0.7490 | Train MAE klw: 0.4970 | Train MAE mcool: 0.4824 | Valid Loss: 0.5914 | Valid MAE klw: 0.4548 | Valid MAE mcool: 0.4371 | Valid R² klw: 0.6920 | Valid R² mcool: 0.6602
# Epoch  11/400 | Train Loss: 0.7136 | Train MAE klw: 0.4883 | Train MAE mcool: 0.4638 | Valid Loss: 0.5451 | Valid MAE klw: 0.4470 | Valid MAE mcool: 0.3993 | Valid R² klw: 0.7003 | Valid R² mcool: 0.7045
#   → New best model saved!
# Epoch  12/400 | Train Loss: 0.6805 | Train MAE klw: 0.4800 | Train MAE mcool: 0.4491 | Valid Loss: 0.5716 | Valid MAE klw: 0.4392 | Valid MAE mcool: 0.4215 | Valid R² klw: 0.7188 | Valid R² mcool: 0.6531
# Epoch  13/400 | Train Loss: 0.6441 | Train MAE klw: 0.4652 | Train MAE mcool: 0.4359 | Valid Loss: 0.5245 | Valid MAE klw: 0.3685 | Valid MAE mcool: 0.4379 | Valid R² klw: 0.7494 | Valid R² mcool: 0.6735
#   → New best model saved!
# Epoch  14/400 | Train Loss: 0.6143 | Train MAE klw: 0.4529 | Train MAE mcool: 0.4243 | Valid Loss: 0.4562 | Valid MAE klw: 0.3606 | Valid MAE mcool: 0.3889 | Valid R² klw: 0.7643 | Valid R² mcool: 0.7358
#   → New best model saved!
# Epoch  15/400 | Train Loss: 0.5946 | Train MAE klw: 0.4459 | Train MAE mcool: 0.4168 | Valid Loss: 0.4460 | Valid MAE klw: 0.4066 | Valid MAE mcool: 0.3682 | Valid R² klw: 0.7624 | Valid R² mcool: 0.7497
#   → New best model saved!
# Epoch  16/400 | Train Loss: 0.5695 | Train MAE klw: 0.4309 | Train MAE mcool: 0.4093 | Valid Loss: 0.3804 | Valid MAE klw: 0.3622 | Valid MAE mcool: 0.3367 | Valid R² klw: 0.7983 | Valid R² mcool: 0.7854
#   → New best model saved!
# Epoch  17/400 | Train Loss: 0.6579 | Train MAE klw: 0.4729 | Train MAE mcool: 0.4391 | Valid Loss: 0.4470 | Valid MAE klw: 0.3928 | Valid MAE mcool: 0.3725 | Valid R² klw: 0.7508 | Valid R² mcool: 0.7615
# Epoch  18/400 | Train Loss: 0.6252 | Train MAE klw: 0.4635 | Train MAE mcool: 0.4239 | Valid Loss: 0.6248 | Valid MAE klw: 0.4614 | Valid MAE mcool: 0.4483 | Valid R² klw: 0.6964 | Valid R² mcool: 0.6167
# Epoch  19/400 | Train Loss: 0.5821 | Train MAE klw: 0.4473 | Train MAE mcool: 0.4080 | Valid Loss: 0.4591 | Valid MAE klw: 0.4229 | Valid MAE mcool: 0.3674 | Valid R² klw: 0.7451 | Valid R² mcool: 0.7538
# Epoch  20/400 | Train Loss: 0.5677 | Train MAE klw: 0.4364 | Train MAE mcool: 0.4062 | Valid Loss: 0.5010 | Valid MAE klw: 0.4006 | Valid MAE mcool: 0.4000 | Valid R² klw: 0.7655 | Valid R² mcool: 0.6827
# Epoch  21/400 | Train Loss: 0.5379 | Train MAE klw: 0.4226 | Train MAE mcool: 0.3972 | Valid Loss: 0.4335 | Valid MAE klw: 0.3785 | Valid MAE mcool: 0.3486 | Valid R² klw: 0.7506 | Valid R² mcool: 0.7773
# Epoch  22/400 | Train Loss: 0.5264 | Train MAE klw: 0.4173 | Train MAE mcool: 0.3908 | Valid Loss: 0.4143 | Valid MAE klw: 0.3859 | Valid MAE mcool: 0.3558 | Valid R² klw: 0.7832 | Valid R² mcool: 0.7631
# Epoch  23/400 | Train Loss: 0.5189 | Train MAE klw: 0.4142 | Train MAE mcool: 0.3857 | Valid Loss: 0.3371 | Valid MAE klw: 0.3574 | Valid MAE mcool: 0.3086 | Valid R² klw: 0.8095 | Valid R² mcool: 0.8230
#   → New best model saved!
# Epoch  24/400 | Train Loss: 0.5185 | Train MAE klw: 0.4147 | Train MAE mcool: 0.3832 | Valid Loss: 0.3079 | Valid MAE klw: 0.3308 | Valid MAE mcool: 0.3021 | Valid R² klw: 0.8312 | Valid R² mcool: 0.8325
#   → New best model saved!
# Epoch  25/400 | Train Loss: 0.4891 | Train MAE klw: 0.3998 | Train MAE mcool: 0.3732 | Valid Loss: 0.3822 | Valid MAE klw: 0.3880 | Valid MAE mcool: 0.3344 | Valid R² klw: 0.7889 | Valid R² mcool: 0.7938
# Epoch  26/400 | Train Loss: 0.5883 | Train MAE klw: 0.4528 | Train MAE mcool: 0.4073 | Valid Loss: 0.3595 | Valid MAE klw: 0.3476 | Valid MAE mcool: 0.3293 | Valid R² klw: 0.7937 | Valid R² mcool: 0.8147
# Epoch  27/400 | Train Loss: 0.5219 | Train MAE klw: 0.4187 | Train MAE mcool: 0.3812 | Valid Loss: 0.3133 | Valid MAE klw: 0.3238 | Valid MAE mcool: 0.2995 | Valid R² klw: 0.8304 | Valid R² mcool: 0.8271
# Epoch  28/400 | Train Loss: 0.4856 | Train MAE klw: 0.3995 | Train MAE mcool: 0.3711 | Valid Loss: 0.3346 | Valid MAE klw: 0.3265 | Valid MAE mcool: 0.3201 | Valid R² klw: 0.8138 | Valid R² mcool: 0.8210
# Epoch  29/400 | Train Loss: 0.4690 | Train MAE klw: 0.3929 | Train MAE mcool: 0.3631 | Valid Loss: 0.4175 | Valid MAE klw: 0.4099 | Valid MAE mcool: 0.3549 | Valid R² klw: 0.7762 | Valid R² mcool: 0.7672
# Epoch  30/400 | Train Loss: 0.4520 | Train MAE klw: 0.3849 | Train MAE mcool: 0.3560 | Valid Loss: 0.3102 | Valid MAE klw: 0.3244 | Valid MAE mcool: 0.3022 | Valid R² klw: 0.8323 | Valid R² mcool: 0.8285
# Epoch  31/400 | Train Loss: 0.4531 | Train MAE klw: 0.3841 | Train MAE mcool: 0.3553 | Valid Loss: 0.3235 | Valid MAE klw: 0.3374 | Valid MAE mcool: 0.3240 | Valid R² klw: 0.8262 | Valid R² mcool: 0.8201
# Epoch  32/400 | Train Loss: 0.4529 | Train MAE klw: 0.3825 | Train MAE mcool: 0.3564 | Valid Loss: 0.2805 | Valid MAE klw: 0.2953 | Valid MAE mcool: 0.2869 | Valid R² klw: 0.8400 | Valid R² mcool: 0.8543
#   → New best model saved!
# Epoch  33/400 | Train Loss: 0.4529 | Train MAE klw: 0.3829 | Train MAE mcool: 0.3556 | Valid Loss: 0.3204 | Valid MAE klw: 0.3453 | Valid MAE mcool: 0.2991 | Valid R² klw: 0.8277 | Valid R² mcool: 0.8220
# Epoch  34/400 | Train Loss: 0.4302 | Train MAE klw: 0.3736 | Train MAE mcool: 0.3450 | Valid Loss: 0.3051 | Valid MAE klw: 0.3215 | Valid MAE mcool: 0.3095 | Valid R² klw: 0.8487 | Valid R² mcool: 0.8162
# Epoch  35/400 | Train Loss: 0.4166 | Train MAE klw: 0.3646 | Train MAE mcool: 0.3401 | Valid Loss: 0.2853 | Valid MAE klw: 0.3335 | Valid MAE mcool: 0.2804 | Valid R² klw: 0.8417 | Valid R² mcool: 0.8469
# Epoch  36/400 | Train Loss: 0.4198 | Train MAE klw: 0.3676 | Train MAE mcool: 0.3392 | Valid Loss: 0.3358 | Valid MAE klw: 0.3567 | Valid MAE mcool: 0.3039 | Valid R² klw: 0.8113 | Valid R² mcool: 0.8225
# Epoch  37/400 | Train Loss: 0.4298 | Train MAE klw: 0.3724 | Train MAE mcool: 0.3448 | Valid Loss: 0.3000 | Valid MAE klw: 0.3514 | Valid MAE mcool: 0.2849 | Valid R² klw: 0.8248 | Valid R² mcool: 0.8488
# Epoch  38/400 | Train Loss: 0.4175 | Train MAE klw: 0.3658 | Train MAE mcool: 0.3383 | Valid Loss: 0.2982 | Valid MAE klw: 0.3314 | Valid MAE mcool: 0.2800 | Valid R² klw: 0.8193 | Valid R² mcool: 0.8569
# Epoch  39/400 | Train Loss: 0.4038 | Train MAE klw: 0.3606 | Train MAE mcool: 0.3312 | Valid Loss: 0.2429 | Valid MAE klw: 0.2892 | Valid MAE mcool: 0.2480 | Valid R² klw: 0.8533 | Valid R² mcool: 0.8829
#   → New best model saved!
# Epoch  40/400 | Train Loss: 0.4124 | Train MAE klw: 0.3623 | Train MAE mcool: 0.3359 | Valid Loss: 0.2365 | Valid MAE klw: 0.2764 | Valid MAE mcool: 0.2724 | Valid R² klw: 0.8776 | Valid R² mcool: 0.8632
#   → New best model saved!
# Epoch  41/400 | Train Loss: 0.4120 | Train MAE klw: 0.3640 | Train MAE mcool: 0.3341 | Valid Loss: 0.3080 | Valid MAE klw: 0.3312 | Valid MAE mcool: 0.3097 | Valid R² klw: 0.8431 | Valid R² mcool: 0.8191
# Epoch  42/400 | Train Loss: 0.4199 | Train MAE klw: 0.3657 | Train MAE mcool: 0.3398 | Valid Loss: 0.3440 | Valid MAE klw: 0.3410 | Valid MAE mcool: 0.3356 | Valid R² klw: 0.8327 | Valid R² mcool: 0.7892
# Epoch  43/400 | Train Loss: 0.3984 | Train MAE klw: 0.3553 | Train MAE mcool: 0.3293 | Valid Loss: 0.2471 | Valid MAE klw: 0.2982 | Valid MAE mcool: 0.2578 | Valid R² klw: 0.8599 | Valid R² mcool: 0.8707
# Epoch  44/400 | Train Loss: 0.4003 | Train MAE klw: 0.3565 | Train MAE mcool: 0.3313 | Valid Loss: 0.2481 | Valid MAE klw: 0.2998 | Valid MAE mcool: 0.2633 | Valid R² klw: 0.8636 | Valid R² mcool: 0.8654
# Epoch  45/400 | Train Loss: 0.4089 | Train MAE klw: 0.3614 | Train MAE mcool: 0.3360 | Valid Loss: 0.2601 | Valid MAE klw: 0.3121 | Valid MAE mcool: 0.2722 | Valid R² klw: 0.8571 | Valid R² mcool: 0.8589
# Epoch  46/400 | Train Loss: 0.3891 | Train MAE klw: 0.3516 | Train MAE mcool: 0.3246 | Valid Loss: 0.2518 | Valid MAE klw: 0.3185 | Valid MAE mcool: 0.2591 | Valid R² klw: 0.8537 | Valid R² mcool: 0.8722
# Epoch  47/400 | Train Loss: 0.3932 | Train MAE klw: 0.3534 | Train MAE mcool: 0.3269 | Valid Loss: 0.2200 | Valid MAE klw: 0.2716 | Valid MAE mcool: 0.2452 | Valid R² klw: 0.8711 | Valid R² mcool: 0.8895
#   → New best model saved!
# Epoch  48/400 | Train Loss: 0.3868 | Train MAE klw: 0.3489 | Train MAE mcool: 0.3260 | Valid Loss: 0.2478 | Valid MAE klw: 0.3116 | Valid MAE mcool: 0.2582 | Valid R² klw: 0.8540 | Valid R² mcool: 0.8765
# Epoch  49/400 | Train Loss: 0.3834 | Train MAE klw: 0.3474 | Train MAE mcool: 0.3205 | Valid Loss: 0.2704 | Valid MAE klw: 0.3231 | Valid MAE mcool: 0.2866 | Valid R² klw: 0.8522 | Valid R² mcool: 0.8524
# Epoch  50/400 | Train Loss: 0.3896 | Train MAE klw: 0.3511 | Train MAE mcool: 0.3273 | Valid Loss: 0.1941 | Valid MAE klw: 0.2745 | Valid MAE mcool: 0.2240 | Valid R² klw: 0.8842 | Valid R² mcool: 0.9049
#   → New best model saved!
# Epoch  51/400 | Train Loss: 0.3850 | Train MAE klw: 0.3481 | Train MAE mcool: 0.3223 | Valid Loss: 0.2624 | Valid MAE klw: 0.3018 | Valid MAE mcool: 0.2835 | Valid R² klw: 0.8618 | Valid R² mcool: 0.8509
# Epoch  52/400 | Train Loss: 0.3772 | Train MAE klw: 0.3449 | Train MAE mcool: 0.3190 | Valid Loss: 0.2851 | Valid MAE klw: 0.3117 | Valid MAE mcool: 0.2704 | Valid R² klw: 0.8186 | Valid R² mcool: 0.8729
# Epoch  53/400 | Train Loss: 0.3809 | Train MAE klw: 0.3465 | Train MAE mcool: 0.3225 | Valid Loss: 0.2895 | Valid MAE klw: 0.3178 | Valid MAE mcool: 0.2992 | Valid R² klw: 0.8484 | Valid R² mcool: 0.8346
# Epoch  54/400 | Train Loss: 0.3776 | Train MAE klw: 0.3468 | Train MAE mcool: 0.3192 | Valid Loss: 0.2740 | Valid MAE klw: 0.3094 | Valid MAE mcool: 0.2707 | Valid R² klw: 0.8406 | Valid R² mcool: 0.8611
# Epoch  55/400 | Train Loss: 0.3856 | Train MAE klw: 0.3498 | Train MAE mcool: 0.3235 | Valid Loss: 0.2081 | Valid MAE klw: 0.2669 | Valid MAE mcool: 0.2321 | Valid R² klw: 0.8765 | Valid R² mcool: 0.8973
# Epoch  56/400 | Train Loss: 0.3721 | Train MAE klw: 0.3416 | Train MAE mcool: 0.3152 | Valid Loss: 0.2095 | Valid MAE klw: 0.2809 | Valid MAE mcool: 0.2347 | Valid R² klw: 0.8773 | Valid R² mcool: 0.8948
# Epoch  57/400 | Train Loss: 0.3668 | Train MAE klw: 0.3383 | Train MAE mcool: 0.3132 | Valid Loss: 0.2546 | Valid MAE klw: 0.2643 | Valid MAE mcool: 0.2944 | Valid R² klw: 0.8640 | Valid R² mcool: 0.8576
# Epoch  58/400 | Train Loss: 0.3726 | Train MAE klw: 0.3428 | Train MAE mcool: 0.3167 | Valid Loss: 0.2257 | Valid MAE klw: 0.2631 | Valid MAE mcool: 0.2461 | Valid R² klw: 0.8660 | Valid R² mcool: 0.8886
# Epoch  59/400 | Train Loss: 0.3802 | Train MAE klw: 0.3464 | Train MAE mcool: 0.3209 | Valid Loss: 0.2295 | Valid MAE klw: 0.2777 | Valid MAE mcool: 0.2428 | Valid R² klw: 0.8587 | Valid R² mcool: 0.8925
# Epoch  60/400 | Train Loss: 0.3620 | Train MAE klw: 0.3371 | Train MAE mcool: 0.3088 | Valid Loss: 0.2070 | Valid MAE klw: 0.2752 | Valid MAE mcool: 0.2326 | Valid R² klw: 0.8769 | Valid R² mcool: 0.8981
# Epoch  61/400 | Train Loss: 0.3738 | Train MAE klw: 0.3435 | Train MAE mcool: 0.3143 | Valid Loss: 0.2156 | Valid MAE klw: 0.2715 | Valid MAE mcool: 0.2394 | Valid R² klw: 0.8715 | Valid R² mcool: 0.8942
# Epoch  62/400 | Train Loss: 0.3637 | Train MAE klw: 0.3396 | Train MAE mcool: 0.3118 | Valid Loss: 0.1810 | Valid MAE klw: 0.2465 | Valid MAE mcool: 0.2184 | Valid R² klw: 0.8962 | Valid R² mcool: 0.9066
#   → New best model saved!
# Epoch  63/400 | Train Loss: 0.3656 | Train MAE klw: 0.3389 | Train MAE mcool: 0.3123 | Valid Loss: 0.2268 | Valid MAE klw: 0.2997 | Valid MAE mcool: 0.2528 | Valid R² klw: 0.8671 | Valid R² mcool: 0.8862
# Epoch  64/400 | Train Loss: 0.3613 | Train MAE klw: 0.3377 | Train MAE mcool: 0.3110 | Valid Loss: 0.2453 | Valid MAE klw: 0.2508 | Valid MAE mcool: 0.3034 | Valid R² klw: 0.8892 | Valid R² mcool: 0.8402
# Epoch  65/400 | Train Loss: 0.3642 | Train MAE klw: 0.3384 | Train MAE mcool: 0.3114 | Valid Loss: 0.1853 | Valid MAE klw: 0.2667 | Valid MAE mcool: 0.2249 | Valid R² klw: 0.8917 | Valid R² mcool: 0.9067
# Epoch  66/400 | Train Loss: 0.3584 | Train MAE klw: 0.3350 | Train MAE mcool: 0.3064 | Valid Loss: 0.2523 | Valid MAE klw: 0.3013 | Valid MAE mcool: 0.2540 | Valid R² klw: 0.8408 | Valid R² mcool: 0.8860
# Epoch  67/400 | Train Loss: 0.3598 | Train MAE klw: 0.3343 | Train MAE mcool: 0.3108 | Valid Loss: 0.1954 | Valid MAE klw: 0.2492 | Valid MAE mcool: 0.2493 | Valid R² klw: 0.9000 | Valid R² mcool: 0.8857
# Epoch  68/400 | Train Loss: 0.3494 | Train MAE klw: 0.3298 | Train MAE mcool: 0.3045 | Valid Loss: 0.2198 | Valid MAE klw: 0.2602 | Valid MAE mcool: 0.2561 | Valid R² klw: 0.8780 | Valid R² mcool: 0.8821
# Epoch  69/400 | Train Loss: 0.3690 | Train MAE klw: 0.3399 | Train MAE mcool: 0.3145 | Valid Loss: 0.2340 | Valid MAE klw: 0.2864 | Valid MAE mcool: 0.2483 | Valid R² klw: 0.8545 | Valid R² mcool: 0.8919
# Epoch  70/400 | Train Loss: 0.3488 | Train MAE klw: 0.3293 | Train MAE mcool: 0.3029 | Valid Loss: 0.2460 | Valid MAE klw: 0.3230 | Valid MAE mcool: 0.2531 | Valid R² klw: 0.8516 | Valid R² mcool: 0.8812
# Epoch  71/400 | Train Loss: 0.3528 | Train MAE klw: 0.3325 | Train MAE mcool: 0.3053 | Valid Loss: 0.1879 | Valid MAE klw: 0.2434 | Valid MAE mcool: 0.2424 | Valid R² klw: 0.9047 | Valid R² mcool: 0.8892
# Epoch  72/400 | Train Loss: 0.3526 | Train MAE klw: 0.3322 | Train MAE mcool: 0.3050 | Valid Loss: 0.2055 | Valid MAE klw: 0.2654 | Valid MAE mcool: 0.2433 | Valid R² klw: 0.8820 | Valid R² mcool: 0.8942
# Epoch  73/400 | Train Loss: 0.3566 | Train MAE klw: 0.3328 | Train MAE mcool: 0.3106 | Valid Loss: 0.1995 | Valid MAE klw: 0.2498 | Valid MAE mcool: 0.2414 | Valid R² klw: 0.8873 | Valid R² mcool: 0.8952
# Epoch  74/400 | Train Loss: 0.3458 | Train MAE klw: 0.3281 | Train MAE mcool: 0.3032 | Valid Loss: 0.2150 | Valid MAE klw: 0.2941 | Valid MAE mcool: 0.2349 | Valid R² klw: 0.8734 | Valid R² mcool: 0.8928
# Epoch  75/400 | Train Loss: 0.3547 | Train MAE klw: 0.3320 | Train MAE mcool: 0.3068 | Valid Loss: 0.1767 | Valid MAE klw: 0.2467 | Valid MAE mcool: 0.2193 | Valid R² klw: 0.8960 | Valid R² mcool: 0.9118
#   → New best model saved!
# Epoch  76/400 | Train Loss: 0.3494 | Train MAE klw: 0.3286 | Train MAE mcool: 0.3030 | Valid Loss: 0.2259 | Valid MAE klw: 0.2734 | Valid MAE mcool: 0.2464 | Valid R² klw: 0.8593 | Valid R² mcool: 0.8958
# Epoch  77/400 | Train Loss: 0.3428 | Train MAE klw: 0.3288 | Train MAE mcool: 0.3010 | Valid Loss: 0.1666 | Valid MAE klw: 0.2465 | Valid MAE mcool: 0.2114 | Valid R² klw: 0.9019 | Valid R² mcool: 0.9169
#   → New best model saved!
# Epoch  78/400 | Train Loss: 0.3480 | Train MAE klw: 0.3287 | Train MAE mcool: 0.3012 | Valid Loss: 0.2031 | Valid MAE klw: 0.2804 | Valid MAE mcool: 0.2309 | Valid R² klw: 0.8775 | Valid R² mcool: 0.9019
# Epoch  79/400 | Train Loss: 0.3479 | Train MAE klw: 0.3287 | Train MAE mcool: 0.3051 | Valid Loss: 0.1699 | Valid MAE klw: 0.2635 | Valid MAE mcool: 0.2116 | Valid R² klw: 0.8985 | Valid R² mcool: 0.9169
# Epoch  80/400 | Train Loss: 0.3466 | Train MAE klw: 0.3276 | Train MAE mcool: 0.3042 | Valid Loss: 0.1909 | Valid MAE klw: 0.2616 | Valid MAE mcool: 0.2245 | Valid R² klw: 0.8836 | Valid R² mcool: 0.9092
# Epoch  81/400 | Train Loss: 0.3444 | Train MAE klw: 0.3278 | Train MAE mcool: 0.3012 | Valid Loss: 0.1926 | Valid MAE klw: 0.2272 | Valid MAE mcool: 0.2538 | Valid R² klw: 0.8992 | Valid R² mcool: 0.8899
# Epoch  82/400 | Train Loss: 0.3382 | Train MAE klw: 0.3241 | Train MAE mcool: 0.2982 | Valid Loss: 0.2070 | Valid MAE klw: 0.2649 | Valid MAE mcool: 0.2349 | Valid R² klw: 0.8796 | Valid R² mcool: 0.8951
# Epoch  83/400 | Train Loss: 0.3382 | Train MAE klw: 0.3209 | Train MAE mcool: 0.3002 | Valid Loss: 0.1649 | Valid MAE klw: 0.2488 | Valid MAE mcool: 0.2063 | Valid R² klw: 0.9022 | Valid R² mcool: 0.9185
#   → New best model saved!
# Epoch  84/400 | Train Loss: 0.3392 | Train MAE klw: 0.3240 | Train MAE mcool: 0.2984 | Valid Loss: 0.3231 | Valid MAE klw: 0.3543 | Valid MAE mcool: 0.3183 | Valid R² klw: 0.8257 | Valid R² mcool: 0.8211
# Epoch  85/400 | Train Loss: 0.3334 | Train MAE klw: 0.3215 | Train MAE mcool: 0.2938 | Valid Loss: 0.1862 | Valid MAE klw: 0.2448 | Valid MAE mcool: 0.2351 | Valid R² klw: 0.8938 | Valid R² mcool: 0.9032
# Epoch  86/400 | Train Loss: 0.3359 | Train MAE klw: 0.3228 | Train MAE mcool: 0.2962 | Valid Loss: 0.1885 | Valid MAE klw: 0.2631 | Valid MAE mcool: 0.2255 | Valid R² klw: 0.8894 | Valid R² mcool: 0.9055
# Epoch  87/400 | Train Loss: 0.3355 | Train MAE klw: 0.3229 | Train MAE mcool: 0.2977 | Valid Loss: 0.1613 | Valid MAE klw: 0.2469 | Valid MAE mcool: 0.2018 | Valid R² klw: 0.9038 | Valid R² mcool: 0.9208
#   → New best model saved!
# Epoch  88/400 | Train Loss: 0.3417 | Train MAE klw: 0.3241 | Train MAE mcool: 0.3034 | Valid Loss: 0.1834 | Valid MAE klw: 0.2432 | Valid MAE mcool: 0.2211 | Valid R² klw: 0.8990 | Valid R² mcool: 0.9008
# Epoch  89/400 | Train Loss: 0.3310 | Train MAE klw: 0.3177 | Train MAE mcool: 0.2963 | Valid Loss: 0.1953 | Valid MAE klw: 0.2735 | Valid MAE mcool: 0.2301 | Valid R² klw: 0.8822 | Valid R² mcool: 0.9056
# Epoch  90/400 | Train Loss: 0.3424 | Train MAE klw: 0.3262 | Train MAE mcool: 0.3012 | Valid Loss: 0.3571 | Valid MAE klw: 0.3170 | Valid MAE mcool: 0.3544 | Valid R² klw: 0.8059 | Valid R² mcool: 0.8039
# Epoch  91/400 | Train Loss: 0.3347 | Train MAE klw: 0.3213 | Train MAE mcool: 0.2967 | Valid Loss: 0.1677 | Valid MAE klw: 0.2228 | Valid MAE mcool: 0.2164 | Valid R² klw: 0.9078 | Valid R² mcool: 0.9090
# Epoch  92/400 | Train Loss: 0.3282 | Train MAE klw: 0.3192 | Train MAE mcool: 0.2929 | Valid Loss: 0.2428 | Valid MAE klw: 0.3112 | Valid MAE mcool: 0.2586 | Valid R² klw: 0.8587 | Valid R² mcool: 0.8770
# Epoch  93/400 | Train Loss: 0.3310 | Train MAE klw: 0.3200 | Train MAE mcool: 0.2945 | Valid Loss: 0.1687 | Valid MAE klw: 0.2408 | Valid MAE mcool: 0.2208 | Valid R² klw: 0.9051 | Valid R² mcool: 0.9109
# Epoch  94/400 | Train Loss: 0.3320 | Train MAE klw: 0.3193 | Train MAE mcool: 0.2960 | Valid Loss: 0.1514 | Valid MAE klw: 0.2140 | Valid MAE mcool: 0.2191 | Valid R² klw: 0.9208 | Valid R² mcool: 0.9134
#   → New best model saved!
# Epoch  95/400 | Train Loss: 0.3254 | Train MAE klw: 0.3176 | Train MAE mcool: 0.2925 | Valid Loss: 0.1836 | Valid MAE klw: 0.2705 | Valid MAE mcool: 0.2246 | Valid R² klw: 0.8944 | Valid R² mcool: 0.9056
# Epoch  96/400 | Train Loss: 0.3263 | Train MAE klw: 0.3164 | Train MAE mcool: 0.2927 | Valid Loss: 0.1659 | Valid MAE klw: 0.2314 | Valid MAE mcool: 0.2274 | Valid R² klw: 0.9157 | Valid R² mcool: 0.9023
# Epoch  97/400 | Train Loss: 0.3283 | Train MAE klw: 0.3176 | Train MAE mcool: 0.2927 | Valid Loss: 0.1509 | Valid MAE klw: 0.2287 | Valid MAE mcool: 0.1984 | Valid R² klw: 0.9108 | Valid R² mcool: 0.9251
#   → New best model saved!
# Epoch  98/400 | Train Loss: 0.3300 | Train MAE klw: 0.3180 | Train MAE mcool: 0.2934 | Valid Loss: 0.1729 | Valid MAE klw: 0.2495 | Valid MAE mcool: 0.2157 | Valid R² klw: 0.9014 | Valid R² mcool: 0.9101
# Epoch  99/400 | Train Loss: 0.3201 | Train MAE klw: 0.3130 | Train MAE mcool: 0.2902 | Valid Loss: 0.1697 | Valid MAE klw: 0.2340 | Valid MAE mcool: 0.2280 | Valid R² klw: 0.9059 | Valid R² mcool: 0.9088
# Epoch 100/400 | Train Loss: 0.3245 | Train MAE klw: 0.3126 | Train MAE mcool: 0.2925 | Valid Loss: 0.2670 | Valid MAE klw: 0.2952 | Valid MAE mcool: 0.2686 | Valid R² klw: 0.8348 | Valid R² mcool: 0.8758
# Epoch 101/400 | Train Loss: 0.3307 | Train MAE klw: 0.3195 | Train MAE mcool: 0.2954 | Valid Loss: 0.2381 | Valid MAE klw: 0.2922 | Valid MAE mcool: 0.2445 | Valid R² klw: 0.8466 | Valid R² mcool: 0.8960
# Epoch 102/400 | Train Loss: 0.3235 | Train MAE klw: 0.3149 | Train MAE mcool: 0.2901 | Valid Loss: 0.2525 | Valid MAE klw: 0.2918 | Valid MAE mcool: 0.2888 | Valid R² klw: 0.8760 | Valid R² mcool: 0.8466
# Epoch 103/400 | Train Loss: 0.3198 | Train MAE klw: 0.3149 | Train MAE mcool: 0.2882 | Valid Loss: 0.1517 | Valid MAE klw: 0.2412 | Valid MAE mcool: 0.1942 | Valid R² klw: 0.9070 | Valid R² mcool: 0.9284
# Epoch 104/400 | Train Loss: 0.3223 | Train MAE klw: 0.3134 | Train MAE mcool: 0.2924 | Valid Loss: 0.1694 | Valid MAE klw: 0.2256 | Valid MAE mcool: 0.2197 | Valid R² klw: 0.9094 | Valid R² mcool: 0.9053
# Epoch 105/400 | Train Loss: 0.3195 | Train MAE klw: 0.3115 | Train MAE mcool: 0.2889 | Valid Loss: 0.1609 | Valid MAE klw: 0.2502 | Valid MAE mcool: 0.1972 | Valid R² klw: 0.9007 | Valid R² mcool: 0.9249
# Epoch 106/400 | Train Loss: 0.3248 | Train MAE klw: 0.3153 | Train MAE mcool: 0.2926 | Valid Loss: 0.1635 | Valid MAE klw: 0.2280 | Valid MAE mcool: 0.2192 | Valid R² klw: 0.9139 | Valid R² mcool: 0.9072
# Epoch 107/400 | Train Loss: 0.3176 | Train MAE klw: 0.3100 | Train MAE mcool: 0.2886 | Valid Loss: 0.1716 | Valid MAE klw: 0.2408 | Valid MAE mcool: 0.2101 | Valid R² klw: 0.8931 | Valid R² mcool: 0.9210
# Epoch 108/400 | Train Loss: 0.3210 | Train MAE klw: 0.3129 | Train MAE mcool: 0.2916 | Valid Loss: 0.1614 | Valid MAE klw: 0.2675 | Valid MAE mcool: 0.1889 | Valid R² klw: 0.8949 | Valid R² mcool: 0.9307
# Epoch 109/400 | Train Loss: 0.3228 | Train MAE klw: 0.3142 | Train MAE mcool: 0.2909 | Valid Loss: 0.1671 | Valid MAE klw: 0.2267 | Valid MAE mcool: 0.2169 | Valid R² klw: 0.9013 | Valid R² mcool: 0.9170
# Epoch 110/400 | Train Loss: 0.3123 | Train MAE klw: 0.3090 | Train MAE mcool: 0.2870 | Valid Loss: 0.1506 | Valid MAE klw: 0.2240 | Valid MAE mcool: 0.1953 | Valid R² klw: 0.9070 | Valid R² mcool: 0.9297
#   → New best model saved!
# Epoch 111/400 | Train Loss: 0.3141 | Train MAE klw: 0.3080 | Train MAE mcool: 0.2894 | Valid Loss: 0.2755 | Valid MAE klw: 0.2735 | Valid MAE mcool: 0.2923 | Valid R² klw: 0.8535 | Valid R² mcool: 0.8451
# Epoch 112/400 | Train Loss: 0.3200 | Train MAE klw: 0.3104 | Train MAE mcool: 0.2928 | Valid Loss: 0.2576 | Valid MAE klw: 0.2705 | Valid MAE mcool: 0.2734 | Valid R² klw: 0.8556 | Valid R² mcool: 0.8634
# Epoch 113/400 | Train Loss: 0.3157 | Train MAE klw: 0.3083 | Train MAE mcool: 0.2898 | Valid Loss: 0.1739 | Valid MAE klw: 0.2303 | Valid MAE mcool: 0.2191 | Valid R² klw: 0.8953 | Valid R² mcool: 0.9159
# Epoch 114/400 | Train Loss: 0.3205 | Train MAE klw: 0.3136 | Train MAE mcool: 0.2926 | Valid Loss: 0.1455 | Valid MAE klw: 0.2350 | Valid MAE mcool: 0.1978 | Valid R² klw: 0.9148 | Valid R² mcool: 0.9269
#   → New best model saved!
# Epoch 115/400 | Train Loss: 0.3056 | Train MAE klw: 0.3049 | Train MAE mcool: 0.2842 | Valid Loss: 0.1797 | Valid MAE klw: 0.2489 | Valid MAE mcool: 0.2352 | Valid R² klw: 0.9035 | Valid R² mcool: 0.8999
# Epoch 116/400 | Train Loss: 0.3039 | Train MAE klw: 0.3026 | Train MAE mcool: 0.2833 | Valid Loss: 0.1622 | Valid MAE klw: 0.2138 | Valid MAE mcool: 0.2285 | Valid R² klw: 0.9166 | Valid R² mcool: 0.9056
# Epoch 117/400 | Train Loss: 0.3034 | Train MAE klw: 0.3036 | Train MAE mcool: 0.2853 | Valid Loss: 0.1515 | Valid MAE klw: 0.2424 | Valid MAE mcool: 0.1967 | Valid R² klw: 0.9103 | Valid R² mcool: 0.9250
# Epoch 118/400 | Train Loss: 0.3080 | Train MAE klw: 0.3073 | Train MAE mcool: 0.2862 | Valid Loss: 0.1391 | Valid MAE klw: 0.2064 | Valid MAE mcool: 0.2000 | Valid R² klw: 0.9200 | Valid R² mcool: 0.9285
#   → New best model saved!
# Epoch 119/400 | Train Loss: 0.2980 | Train MAE klw: 0.2983 | Train MAE mcool: 0.2810 | Valid Loss: 0.2479 | Valid MAE klw: 0.3001 | Valid MAE mcool: 0.2312 | Valid R² klw: 0.8297 | Valid R² mcool: 0.9034
# Epoch 120/400 | Train Loss: 0.3073 | Train MAE klw: 0.3063 | Train MAE mcool: 0.2850 | Valid Loss: 0.1975 | Valid MAE klw: 0.2373 | Valid MAE mcool: 0.2665 | Valid R² klw: 0.9128 | Valid R² mcool: 0.8691
# Epoch 121/400 | Train Loss: 0.3007 | Train MAE klw: 0.3035 | Train MAE mcool: 0.2816 | Valid Loss: 0.1690 | Valid MAE klw: 0.2434 | Valid MAE mcool: 0.2247 | Valid R² klw: 0.9093 | Valid R² mcool: 0.9058
# Epoch 122/400 | Train Loss: 0.3007 | Train MAE klw: 0.3019 | Train MAE mcool: 0.2821 | Valid Loss: 0.1609 | Valid MAE klw: 0.2335 | Valid MAE mcool: 0.2120 | Valid R² klw: 0.9130 | Valid R² mcool: 0.9111
# Epoch 123/400 | Train Loss: 0.3010 | Train MAE klw: 0.3030 | Train MAE mcool: 0.2820 | Valid Loss: 0.1797 | Valid MAE klw: 0.2309 | Valid MAE mcool: 0.2354 | Valid R² klw: 0.9025 | Valid R² mcool: 0.9011
# Epoch 124/400 | Train Loss: 0.2995 | Train MAE klw: 0.3026 | Train MAE mcool: 0.2818 | Valid Loss: 0.1519 | Valid MAE klw: 0.2201 | Valid MAE mcool: 0.2082 | Valid R² klw: 0.9133 | Valid R² mcool: 0.9212
# Epoch 125/400 | Train Loss: 0.3034 | Train MAE klw: 0.3023 | Train MAE mcool: 0.2850 | Valid Loss: 0.1345 | Valid MAE klw: 0.2057 | Valid MAE mcool: 0.1877 | Valid R² klw: 0.9210 | Valid R² mcool: 0.9326
#   → New best model saved!
# Epoch 126/400 | Train Loss: 0.3034 | Train MAE klw: 0.3027 | Train MAE mcool: 0.2848 | Valid Loss: 0.1485 | Valid MAE klw: 0.2227 | Valid MAE mcool: 0.1898 | Valid R² klw: 0.9064 | Valid R² mcool: 0.9327
# Epoch 127/400 | Train Loss: 0.3035 | Train MAE klw: 0.3024 | Train MAE mcool: 0.2837 | Valid Loss: 0.1395 | Valid MAE klw: 0.2127 | Valid MAE mcool: 0.2016 | Valid R² klw: 0.9233 | Valid R² mcool: 0.9243
# Epoch 128/400 | Train Loss: 0.2978 | Train MAE klw: 0.3015 | Train MAE mcool: 0.2810 | Valid Loss: 0.1404 | Valid MAE klw: 0.2114 | Valid MAE mcool: 0.1988 | Valid R² klw: 0.9220 | Valid R² mcool: 0.9247
# Epoch 129/400 | Train Loss: 0.2984 | Train MAE klw: 0.3034 | Train MAE mcool: 0.2809 | Valid Loss: 0.1481 | Valid MAE klw: 0.2264 | Valid MAE mcool: 0.1930 | Valid R² klw: 0.9119 | Valid R² mcool: 0.9271
# Epoch 130/400 | Train Loss: 0.3067 | Train MAE klw: 0.3042 | Train MAE mcool: 0.2867 | Valid Loss: 0.1487 | Valid MAE klw: 0.2299 | Valid MAE mcool: 0.2075 | Valid R² klw: 0.9177 | Valid R² mcool: 0.9200
# Epoch 131/400 | Train Loss: 0.2944 | Train MAE klw: 0.2986 | Train MAE mcool: 0.2784 | Valid Loss: 0.2479 | Valid MAE klw: 0.2907 | Valid MAE mcool: 0.2929 | Valid R² klw: 0.8804 | Valid R² mcool: 0.8470
# Epoch 132/400 | Train Loss: 0.2987 | Train MAE klw: 0.2994 | Train MAE mcool: 0.2825 | Valid Loss: 0.1627 | Valid MAE klw: 0.2314 | Valid MAE mcool: 0.2045 | Valid R² klw: 0.8999 | Valid R² mcool: 0.9237
# Epoch 133/400 | Train Loss: 0.3025 | Train MAE klw: 0.3037 | Train MAE mcool: 0.2834 | Valid Loss: 0.1692 | Valid MAE klw: 0.2305 | Valid MAE mcool: 0.2314 | Valid R² klw: 0.9142 | Valid R² mcool: 0.9002
# Epoch 134/400 | Train Loss: 0.2862 | Train MAE klw: 0.2929 | Train MAE mcool: 0.2757 | Valid Loss: 0.1373 | Valid MAE klw: 0.2296 | Valid MAE mcool: 0.1761 | Valid R² klw: 0.9110 | Valid R² mcool: 0.9406
# Epoch 135/400 | Train Loss: 0.2964 | Train MAE klw: 0.2982 | Train MAE mcool: 0.2807 | Valid Loss: 0.1615 | Valid MAE klw: 0.2413 | Valid MAE mcool: 0.2035 | Valid R² klw: 0.8989 | Valid R² mcool: 0.9261
# Epoch 136/400 | Train Loss: 0.2981 | Train MAE klw: 0.2998 | Train MAE mcool: 0.2835 | Valid Loss: 0.1299 | Valid MAE klw: 0.2196 | Valid MAE mcool: 0.1816 | Valid R² klw: 0.9227 | Valid R² mcool: 0.9361
#   → New best model saved!
# Epoch 137/400 | Train Loss: 0.2976 | Train MAE klw: 0.3002 | Train MAE mcool: 0.2822 | Valid Loss: 0.1768 | Valid MAE klw: 0.2523 | Valid MAE mcool: 0.2135 | Valid R² klw: 0.8879 | Valid R² mcool: 0.9207
# Epoch 138/400 | Train Loss: 0.2890 | Train MAE klw: 0.2966 | Train MAE mcool: 0.2775 | Valid Loss: 0.1427 | Valid MAE klw: 0.2250 | Valid MAE mcool: 0.1967 | Valid R² klw: 0.9160 | Valid R² mcool: 0.9288
# Epoch 139/400 | Train Loss: 0.2973 | Train MAE klw: 0.3022 | Train MAE mcool: 0.2800 | Valid Loss: 0.1529 | Valid MAE klw: 0.2285 | Valid MAE mcool: 0.2085 | Valid R² klw: 0.9106 | Valid R² mcool: 0.9230
# Epoch 140/400 | Train Loss: 0.2886 | Train MAE klw: 0.2961 | Train MAE mcool: 0.2774 | Valid Loss: 0.1553 | Valid MAE klw: 0.2396 | Valid MAE mcool: 0.2098 | Valid R² klw: 0.9140 | Valid R² mcool: 0.9165
# Epoch 141/400 | Train Loss: 0.2902 | Train MAE klw: 0.2955 | Train MAE mcool: 0.2779 | Valid Loss: 0.1711 | Valid MAE klw: 0.2406 | Valid MAE mcool: 0.2255 | Valid R² klw: 0.9119 | Valid R² mcool: 0.9005
# Epoch 142/400 | Train Loss: 0.2973 | Train MAE klw: 0.2992 | Train MAE mcool: 0.2827 | Valid Loss: 0.1564 | Valid MAE klw: 0.2200 | Valid MAE mcool: 0.2103 | Valid R² klw: 0.9106 | Valid R² mcool: 0.9190
# Epoch 143/400 | Train Loss: 0.2920 | Train MAE klw: 0.2990 | Train MAE mcool: 0.2796 | Valid Loss: 0.1377 | Valid MAE klw: 0.2163 | Valid MAE mcool: 0.2003 | Valid R² klw: 0.9234 | Valid R² mcool: 0.9263
# Epoch 144/400 | Train Loss: 0.2955 | Train MAE klw: 0.2986 | Train MAE mcool: 0.2806 | Valid Loss: 0.1708 | Valid MAE klw: 0.2369 | Valid MAE mcool: 0.2305 | Valid R² klw: 0.9030 | Valid R² mcool: 0.9108
# Epoch 145/400 | Train Loss: 0.2878 | Train MAE klw: 0.2946 | Train MAE mcool: 0.2760 | Valid Loss: 0.1391 | Valid MAE klw: 0.2368 | Valid MAE mcool: 0.1822 | Valid R² klw: 0.9134 | Valid R² mcool: 0.9359
# Epoch 146/400 | Train Loss: 0.2895 | Train MAE klw: 0.2956 | Train MAE mcool: 0.2789 | Valid Loss: 0.1403 | Valid MAE klw: 0.2172 | Valid MAE mcool: 0.1974 | Valid R² klw: 0.9201 | Valid R² mcool: 0.9270
# Epoch 147/400 | Train Loss: 0.2832 | Train MAE klw: 0.2927 | Train MAE mcool: 0.2735 | Valid Loss: 0.1272 | Valid MAE klw: 0.1869 | Valid MAE mcool: 0.1986 | Valid R² klw: 0.9317 | Valid R² mcool: 0.9292
#   → New best model saved!
# Epoch 148/400 | Train Loss: 0.2849 | Train MAE klw: 0.2950 | Train MAE mcool: 0.2748 | Valid Loss: 0.1419 | Valid MAE klw: 0.2094 | Valid MAE mcool: 0.2033 | Valid R² klw: 0.9234 | Valid R² mcool: 0.9214
# Epoch 149/400 | Train Loss: 0.2914 | Train MAE klw: 0.2960 | Train MAE mcool: 0.2785 | Valid Loss: 0.1582 | Valid MAE klw: 0.2423 | Valid MAE mcool: 0.2055 | Valid R² klw: 0.9074 | Valid R² mcool: 0.9204
# Epoch 150/400 | Train Loss: 0.2886 | Train MAE klw: 0.2948 | Train MAE mcool: 0.2778 | Valid Loss: 0.1706 | Valid MAE klw: 0.2339 | Valid MAE mcool: 0.2177 | Valid R² klw: 0.8971 | Valid R² mcool: 0.9176
# Epoch 151/400 | Train Loss: 0.2849 | Train MAE klw: 0.2927 | Train MAE mcool: 0.2739 | Valid Loss: 0.1356 | Valid MAE klw: 0.1924 | Valid MAE mcool: 0.2072 | Valid R² klw: 0.9322 | Valid R² mcool: 0.9190
# Epoch 152/400 | Train Loss: 0.2869 | Train MAE klw: 0.2952 | Train MAE mcool: 0.2750 | Valid Loss: 0.1351 | Valid MAE klw: 0.1973 | Valid MAE mcool: 0.1980 | Valid R² klw: 0.9236 | Valid R² mcool: 0.9291
# Epoch 153/400 | Train Loss: 0.2899 | Train MAE klw: 0.2969 | Train MAE mcool: 0.2771 | Valid Loss: 0.2395 | Valid MAE klw: 0.2618 | Valid MAE mcool: 0.2856 | Valid R² klw: 0.8674 | Valid R² mcool: 0.8712
# Epoch 154/400 | Train Loss: 0.2907 | Train MAE klw: 0.2958 | Train MAE mcool: 0.2801 | Valid Loss: 0.1333 | Valid MAE klw: 0.2270 | Valid MAE mcool: 0.1805 | Valid R² klw: 0.9205 | Valid R² mcool: 0.9346
# Epoch 155/400 | Train Loss: 0.2899 | Train MAE klw: 0.2939 | Train MAE mcool: 0.2778 | Valid Loss: 0.1675 | Valid MAE klw: 0.2416 | Valid MAE mcool: 0.2289 | Valid R² klw: 0.9133 | Valid R² mcool: 0.9031
# Epoch 156/400 | Train Loss: 0.2830 | Train MAE klw: 0.2911 | Train MAE mcool: 0.2746 | Valid Loss: 0.1541 | Valid MAE klw: 0.2254 | Valid MAE mcool: 0.2009 | Valid R² klw: 0.9097 | Valid R² mcool: 0.9228
# Epoch 157/400 | Train Loss: 0.2909 | Train MAE klw: 0.2967 | Train MAE mcool: 0.2769 | Valid Loss: 0.1268 | Valid MAE klw: 0.2067 | Valid MAE mcool: 0.1929 | Valid R² klw: 0.9283 | Valid R² mcool: 0.9335
#   → New best model saved!
# Epoch 158/400 | Train Loss: 0.2834 | Train MAE klw: 0.2932 | Train MAE mcool: 0.2735 | Valid Loss: 0.1372 | Valid MAE klw: 0.2144 | Valid MAE mcool: 0.1924 | Valid R² klw: 0.9185 | Valid R² mcool: 0.9324
# Epoch 159/400 | Train Loss: 0.2862 | Train MAE klw: 0.2921 | Train MAE mcool: 0.2777 | Valid Loss: 0.1557 | Valid MAE klw: 0.2201 | Valid MAE mcool: 0.2085 | Valid R² klw: 0.9115 | Valid R² mcool: 0.9187
# Epoch 160/400 | Train Loss: 0.2859 | Train MAE klw: 0.2931 | Train MAE mcool: 0.2762 | Valid Loss: 0.1749 | Valid MAE klw: 0.2391 | Valid MAE mcool: 0.2219 | Valid R² klw: 0.8953 | Valid R² mcool: 0.9146
# Epoch 161/400 | Train Loss: 0.2857 | Train MAE klw: 0.2933 | Train MAE mcool: 0.2755 | Valid Loss: 0.1309 | Valid MAE klw: 0.2084 | Valid MAE mcool: 0.1934 | Valid R² klw: 0.9260 | Valid R² mcool: 0.9312
# Epoch 162/400 | Train Loss: 0.2838 | Train MAE klw: 0.2908 | Train MAE mcool: 0.2755 | Valid Loss: 0.1498 | Valid MAE klw: 0.2337 | Valid MAE mcool: 0.2027 | Valid R² klw: 0.9159 | Valid R² mcool: 0.9207
# Epoch 163/400 | Train Loss: 0.2873 | Train MAE klw: 0.2952 | Train MAE mcool: 0.2764 | Valid Loss: 0.1449 | Valid MAE klw: 0.2254 | Valid MAE mcool: 0.1984 | Valid R² klw: 0.9135 | Valid R² mcool: 0.9291
# Epoch 164/400 | Train Loss: 0.2794 | Train MAE klw: 0.2890 | Train MAE mcool: 0.2712 | Valid Loss: 0.1216 | Valid MAE klw: 0.2089 | Valid MAE mcool: 0.1804 | Valid R² klw: 0.9286 | Valid R² mcool: 0.9392
#   → New best model saved!
# Epoch 165/400 | Train Loss: 0.2845 | Train MAE klw: 0.2929 | Train MAE mcool: 0.2767 | Valid Loss: 0.1317 | Valid MAE klw: 0.2195 | Valid MAE mcool: 0.1851 | Valid R² klw: 0.9209 | Valid R² mcool: 0.9361
# Epoch 166/400 | Train Loss: 0.2845 | Train MAE klw: 0.2935 | Train MAE mcool: 0.2743 | Valid Loss: 0.1421 | Valid MAE klw: 0.2220 | Valid MAE mcool: 0.2031 | Valid R² klw: 0.9226 | Valid R² mcool: 0.9222
# Epoch 167/400 | Train Loss: 0.2849 | Train MAE klw: 0.2929 | Train MAE mcool: 0.2764 | Valid Loss: 0.1524 | Valid MAE klw: 0.2348 | Valid MAE mcool: 0.2071 | Valid R² klw: 0.9121 | Valid R² mcool: 0.9219
# Epoch 168/400 | Train Loss: 0.2832 | Train MAE klw: 0.2913 | Train MAE mcool: 0.2755 | Valid Loss: 0.1552 | Valid MAE klw: 0.2418 | Valid MAE mcool: 0.2043 | Valid R² klw: 0.9089 | Valid R² mcool: 0.9223
# Epoch 169/400 | Train Loss: 0.2834 | Train MAE klw: 0.2925 | Train MAE mcool: 0.2731 | Valid Loss: 0.1292 | Valid MAE klw: 0.2077 | Valid MAE mcool: 0.1955 | Valid R² klw: 0.9278 | Valid R² mcool: 0.9312
# Epoch 170/400 | Train Loss: 0.2789 | Train MAE klw: 0.2881 | Train MAE mcool: 0.2719 | Valid Loss: 0.1577 | Valid MAE klw: 0.2251 | Valid MAE mcool: 0.2248 | Valid R² klw: 0.9217 | Valid R² mcool: 0.9051
# Epoch 171/400 | Train Loss: 0.2745 | Train MAE klw: 0.2880 | Train MAE mcool: 0.2679 | Valid Loss: 0.1289 | Valid MAE klw: 0.1960 | Valid MAE mcool: 0.1869 | Valid R² klw: 0.9238 | Valid R² mcool: 0.9360
# Epoch 172/400 | Train Loss: 0.2784 | Train MAE klw: 0.2915 | Train MAE mcool: 0.2709 | Valid Loss: 0.1247 | Valid MAE klw: 0.2133 | Valid MAE mcool: 0.1785 | Valid R² klw: 0.9248 | Valid R² mcool: 0.9397
# Epoch 173/400 | Train Loss: 0.2791 | Train MAE klw: 0.2897 | Train MAE mcool: 0.2718 | Valid Loss: 0.1147 | Valid MAE klw: 0.1920 | Valid MAE mcool: 0.1801 | Valid R² klw: 0.9351 | Valid R² mcool: 0.9399
#   → New best model saved!
# Epoch 174/400 | Train Loss: 0.2822 | Train MAE klw: 0.2902 | Train MAE mcool: 0.2741 | Valid Loss: 0.1482 | Valid MAE klw: 0.2334 | Valid MAE mcool: 0.2080 | Valid R² klw: 0.9167 | Valid R² mcool: 0.9216
# Epoch 175/400 | Train Loss: 0.2796 | Train MAE klw: 0.2914 | Train MAE mcool: 0.2700 | Valid Loss: 0.1287 | Valid MAE klw: 0.2111 | Valid MAE mcool: 0.1883 | Valid R² klw: 0.9281 | Valid R² mcool: 0.9315
# Epoch 176/400 | Train Loss: 0.2768 | Train MAE klw: 0.2894 | Train MAE mcool: 0.2700 | Valid Loss: 0.1282 | Valid MAE klw: 0.2075 | Valid MAE mcool: 0.1801 | Valid R² klw: 0.9230 | Valid R² mcool: 0.9378
# Epoch 177/400 | Train Loss: 0.2766 | Train MAE klw: 0.2876 | Train MAE mcool: 0.2718 | Valid Loss: 0.1659 | Valid MAE klw: 0.2480 | Valid MAE mcool: 0.2091 | Valid R² klw: 0.8975 | Valid R² mcool: 0.9225
# Epoch 178/400 | Train Loss: 0.2805 | Train MAE klw: 0.2905 | Train MAE mcool: 0.2735 | Valid Loss: 0.1748 | Valid MAE klw: 0.2645 | Valid MAE mcool: 0.2171 | Valid R² klw: 0.8994 | Valid R² mcool: 0.9103
# Epoch 179/400 | Train Loss: 0.2763 | Train MAE klw: 0.2895 | Train MAE mcool: 0.2702 | Valid Loss: 0.1468 | Valid MAE klw: 0.2174 | Valid MAE mcool: 0.2020 | Valid R² klw: 0.9146 | Valid R² mcool: 0.9256
# Epoch 180/400 | Train Loss: 0.2794 | Train MAE klw: 0.2915 | Train MAE mcool: 0.2737 | Valid Loss: 0.1321 | Valid MAE klw: 0.2040 | Valid MAE mcool: 0.1897 | Valid R² klw: 0.9219 | Valid R² mcool: 0.9345
# Epoch 181/400 | Train Loss: 0.2724 | Train MAE klw: 0.2863 | Train MAE mcool: 0.2681 | Valid Loss: 0.1694 | Valid MAE klw: 0.2470 | Valid MAE mcool: 0.1860 | Valid R² klw: 0.8817 | Valid R² mcool: 0.9362
# Epoch 182/400 | Train Loss: 0.2782 | Train MAE klw: 0.2861 | Train MAE mcool: 0.2709 | Valid Loss: 0.1099 | Valid MAE klw: 0.1835 | Valid MAE mcool: 0.1855 | Valid R² klw: 0.9418 | Valid R² mcool: 0.9379
#   → New best model saved!
# Epoch 183/400 | Train Loss: 0.2754 | Train MAE klw: 0.2870 | Train MAE mcool: 0.2691 | Valid Loss: 0.1353 | Valid MAE klw: 0.2208 | Valid MAE mcool: 0.1856 | Valid R² klw: 0.9166 | Valid R² mcool: 0.9367
# Epoch 184/400 | Train Loss: 0.2776 | Train MAE klw: 0.2880 | Train MAE mcool: 0.2700 | Valid Loss: 0.1637 | Valid MAE klw: 0.2350 | Valid MAE mcool: 0.2001 | Valid R² klw: 0.8954 | Valid R² mcool: 0.9275
# Epoch 185/400 | Train Loss: 0.2764 | Train MAE klw: 0.2887 | Train MAE mcool: 0.2696 | Valid Loss: 0.1301 | Valid MAE klw: 0.2012 | Valid MAE mcool: 0.1966 | Valid R² klw: 0.9270 | Valid R² mcool: 0.9310
# Epoch 186/400 | Train Loss: 0.2762 | Train MAE klw: 0.2882 | Train MAE mcool: 0.2711 | Valid Loss: 0.1191 | Valid MAE klw: 0.2011 | Valid MAE mcool: 0.1801 | Valid R² klw: 0.9336 | Valid R² mcool: 0.9365
# Epoch 187/400 | Train Loss: 0.2734 | Train MAE klw: 0.2873 | Train MAE mcool: 0.2684 | Valid Loss: 0.1216 | Valid MAE klw: 0.2095 | Valid MAE mcool: 0.1765 | Valid R² klw: 0.9290 | Valid R² mcool: 0.9387
# Epoch 188/400 | Train Loss: 0.2797 | Train MAE klw: 0.2896 | Train MAE mcool: 0.2722 | Valid Loss: 0.1702 | Valid MAE klw: 0.2412 | Valid MAE mcool: 0.2132 | Valid R² klw: 0.8935 | Valid R² mcool: 0.9222
# Epoch 189/400 | Train Loss: 0.2731 | Train MAE klw: 0.2867 | Train MAE mcool: 0.2681 | Valid Loss: 0.1338 | Valid MAE klw: 0.2196 | Valid MAE mcool: 0.1838 | Valid R² klw: 0.9178 | Valid R² mcool: 0.9370
# Epoch 190/400 | Train Loss: 0.2803 | Train MAE klw: 0.2919 | Train MAE mcool: 0.2715 | Valid Loss: 0.1401 | Valid MAE klw: 0.2419 | Valid MAE mcool: 0.1769 | Valid R² klw: 0.9086 | Valid R² mcool: 0.9401
# Epoch 191/400 | Train Loss: 0.2685 | Train MAE klw: 0.2843 | Train MAE mcool: 0.2654 | Valid Loss: 0.1681 | Valid MAE klw: 0.2530 | Valid MAE mcool: 0.2163 | Valid R² klw: 0.9068 | Valid R² mcool: 0.9097
# Epoch 192/400 | Train Loss: 0.2741 | Train MAE klw: 0.2870 | Train MAE mcool: 0.2692 | Valid Loss: 0.1343 | Valid MAE klw: 0.2175 | Valid MAE mcool: 0.1969 | Valid R² klw: 0.9251 | Valid R² mcool: 0.9284
# Epoch 193/400 | Train Loss: 0.2736 | Train MAE klw: 0.2887 | Train MAE mcool: 0.2684 | Valid Loss: 0.1201 | Valid MAE klw: 0.2168 | Valid MAE mcool: 0.1750 | Valid R² klw: 0.9268 | Valid R² mcool: 0.9429
# Epoch 194/400 | Train Loss: 0.2736 | Train MAE klw: 0.2849 | Train MAE mcool: 0.2701 | Valid Loss: 0.1206 | Valid MAE klw: 0.1927 | Valid MAE mcool: 0.1889 | Valid R² klw: 0.9346 | Valid R² mcool: 0.9335
# Epoch 195/400 | Train Loss: 0.2750 | Train MAE klw: 0.2875 | Train MAE mcool: 0.2712 | Valid Loss: 0.1442 | Valid MAE klw: 0.2233 | Valid MAE mcool: 0.1817 | Valid R² klw: 0.9061 | Valid R² mcool: 0.9382
# Epoch 196/400 | Train Loss: 0.2673 | Train MAE klw: 0.2840 | Train MAE mcool: 0.2648 | Valid Loss: 0.1236 | Valid MAE klw: 0.1749 | Valid MAE mcool: 0.2044 | Valid R² klw: 0.9424 | Valid R² mcool: 0.9215
# Epoch 197/400 | Train Loss: 0.2728 | Train MAE klw: 0.2870 | Train MAE mcool: 0.2687 | Valid Loss: 0.1627 | Valid MAE klw: 0.2592 | Valid MAE mcool: 0.2133 | Valid R² klw: 0.9053 | Valid R² mcool: 0.9176
# Epoch 198/400 | Train Loss: 0.2740 | Train MAE klw: 0.2859 | Train MAE mcool: 0.2705 | Valid Loss: 0.1420 | Valid MAE klw: 0.2314 | Valid MAE mcool: 0.2010 | Valid R² klw: 0.9192 | Valid R² mcool: 0.9260
# Epoch 199/400 | Train Loss: 0.2433 | Train MAE klw: 0.2689 | Train MAE mcool: 0.2498 | Valid Loss: 0.1108 | Valid MAE klw: 0.1943 | Valid MAE mcool: 0.1733 | Valid R² klw: 0.9356 | Valid R² mcool: 0.9437
# Epoch 200/400 | Train Loss: 0.2445 | Train MAE klw: 0.2665 | Train MAE mcool: 0.2500 | Valid Loss: 0.1395 | Valid MAE klw: 0.2253 | Valid MAE mcool: 0.1887 | Valid R² klw: 0.9110 | Valid R² mcool: 0.9380
# Epoch 201/400 | Train Loss: 0.2470 | Train MAE klw: 0.2684 | Train MAE mcool: 0.2525 | Valid Loss: 0.1173 | Valid MAE klw: 0.1971 | Valid MAE mcool: 0.1772 | Valid R² klw: 0.9292 | Valid R² mcool: 0.9434
# Epoch 202/400 | Train Loss: 0.2447 | Train MAE klw: 0.2650 | Train MAE mcool: 0.2531 | Valid Loss: 0.1196 | Valid MAE klw: 0.2095 | Valid MAE mcool: 0.1813 | Valid R² klw: 0.9323 | Valid R² mcool: 0.9372
# Epoch 203/400 | Train Loss: 0.2404 | Train MAE klw: 0.2646 | Train MAE mcool: 0.2511 | Valid Loss: 0.1073 | Valid MAE klw: 0.1911 | Valid MAE mcool: 0.1695 | Valid R² klw: 0.9379 | Valid R² mcool: 0.9453
#   → New best model saved!
# Epoch 204/400 | Train Loss: 0.2456 | Train MAE klw: 0.2663 | Train MAE mcool: 0.2526 | Valid Loss: 0.0990 | Valid MAE klw: 0.1782 | Valid MAE mcool: 0.1636 | Valid R² klw: 0.9432 | Valid R² mcool: 0.9489
#   → New best model saved!
# Epoch 205/400 | Train Loss: 0.2429 | Train MAE klw: 0.2650 | Train MAE mcool: 0.2506 | Valid Loss: 0.1055 | Valid MAE klw: 0.1850 | Valid MAE mcool: 0.1684 | Valid R² klw: 0.9383 | Valid R² mcool: 0.9470
# Epoch 206/400 | Train Loss: 0.2427 | Train MAE klw: 0.2661 | Train MAE mcool: 0.2501 | Valid Loss: 0.1330 | Valid MAE klw: 0.2164 | Valid MAE mcool: 0.1852 | Valid R² klw: 0.9165 | Valid R² mcool: 0.9394
# Epoch 207/400 | Train Loss: 0.2439 | Train MAE klw: 0.2642 | Train MAE mcool: 0.2509 | Valid Loss: 0.1373 | Valid MAE klw: 0.2277 | Valid MAE mcool: 0.1798 | Valid R² klw: 0.9095 | Valid R² mcool: 0.9422
# Epoch 208/400 | Train Loss: 0.2436 | Train MAE klw: 0.2668 | Train MAE mcool: 0.2513 | Valid Loss: 0.1179 | Valid MAE klw: 0.1988 | Valid MAE mcool: 0.1873 | Valid R² klw: 0.9367 | Valid R² mcool: 0.9345
# Epoch 209/400 | Train Loss: 0.2421 | Train MAE klw: 0.2650 | Train MAE mcool: 0.2499 | Valid Loss: 0.1217 | Valid MAE klw: 0.2014 | Valid MAE mcool: 0.1819 | Valid R² klw: 0.9270 | Valid R² mcool: 0.9409
# Epoch 210/400 | Train Loss: 0.2409 | Train MAE klw: 0.2658 | Train MAE mcool: 0.2487 | Valid Loss: 0.1235 | Valid MAE klw: 0.1999 | Valid MAE mcool: 0.1810 | Valid R² klw: 0.9257 | Valid R² mcool: 0.9402
# Epoch 211/400 | Train Loss: 0.2433 | Train MAE klw: 0.2661 | Train MAE mcool: 0.2520 | Valid Loss: 0.1049 | Valid MAE klw: 0.1982 | Valid MAE mcool: 0.1590 | Valid R² klw: 0.9346 | Valid R² mcool: 0.9518
# Epoch 212/400 | Train Loss: 0.2430 | Train MAE klw: 0.2662 | Train MAE mcool: 0.2508 | Valid Loss: 0.1130 | Valid MAE klw: 0.1953 | Valid MAE mcool: 0.1764 | Valid R² klw: 0.9335 | Valid R² mcool: 0.9435
# Epoch 213/400 | Train Loss: 0.2386 | Train MAE klw: 0.2633 | Train MAE mcool: 0.2474 | Valid Loss: 0.1059 | Valid MAE klw: 0.1787 | Valid MAE mcool: 0.1709 | Valid R² klw: 0.9384 | Valid R² mcool: 0.9464
# Epoch 214/400 | Train Loss: 0.2444 | Train MAE klw: 0.2661 | Train MAE mcool: 0.2523 | Valid Loss: 0.1006 | Valid MAE klw: 0.1921 | Valid MAE mcool: 0.1646 | Valid R² klw: 0.9411 | Valid R² mcool: 0.9494
# Epoch 215/400 | Train Loss: 0.2404 | Train MAE klw: 0.2656 | Train MAE mcool: 0.2486 | Valid Loss: 0.1116 | Valid MAE klw: 0.2134 | Valid MAE mcool: 0.1591 | Valid R² klw: 0.9279 | Valid R² mcool: 0.9514
# Epoch 216/400 | Train Loss: 0.2451 | Train MAE klw: 0.2660 | Train MAE mcool: 0.2497 | Valid Loss: 0.1166 | Valid MAE klw: 0.2041 | Valid MAE mcool: 0.1686 | Valid R² klw: 0.9268 | Valid R² mcool: 0.9468
# Epoch 217/400 | Train Loss: 0.2422 | Train MAE klw: 0.2639 | Train MAE mcool: 0.2503 | Valid Loss: 0.0970 | Valid MAE klw: 0.1892 | Valid MAE mcool: 0.1565 | Valid R² klw: 0.9412 | Valid R² mcool: 0.9535
#   → New best model saved!
# Epoch 218/400 | Train Loss: 0.2457 | Train MAE klw: 0.2672 | Train MAE mcool: 0.2515 | Valid Loss: 0.0984 | Valid MAE klw: 0.1850 | Valid MAE mcool: 0.1611 | Valid R² klw: 0.9441 | Valid R² mcool: 0.9487
# Epoch 219/400 | Train Loss: 0.2415 | Train MAE klw: 0.2630 | Train MAE mcool: 0.2491 | Valid Loss: 0.1236 | Valid MAE klw: 0.2235 | Valid MAE mcool: 0.1822 | Valid R² klw: 0.9275 | Valid R² mcool: 0.9380
# Epoch 220/400 | Train Loss: 0.2426 | Train MAE klw: 0.2649 | Train MAE mcool: 0.2503 | Valid Loss: 0.1207 | Valid MAE klw: 0.1858 | Valid MAE mcool: 0.1943 | Valid R² klw: 0.9351 | Valid R² mcool: 0.9328
# Epoch 221/400 | Train Loss: 0.2432 | Train MAE klw: 0.2670 | Train MAE mcool: 0.2500 | Valid Loss: 0.1109 | Valid MAE klw: 0.1980 | Valid MAE mcool: 0.1717 | Valid R² klw: 0.9356 | Valid R² mcool: 0.9437
# Epoch 222/400 | Train Loss: 0.2434 | Train MAE klw: 0.2662 | Train MAE mcool: 0.2496 | Valid Loss: 0.0912 | Valid MAE klw: 0.1745 | Valid MAE mcool: 0.1535 | Valid R² klw: 0.9473 | Valid R² mcool: 0.9534
#   → New best model saved!
# Epoch 223/400 | Train Loss: 0.2377 | Train MAE klw: 0.2619 | Train MAE mcool: 0.2467 | Valid Loss: 0.1144 | Valid MAE klw: 0.2010 | Valid MAE mcool: 0.1698 | Valid R² klw: 0.9301 | Valid R² mcool: 0.9458
# Epoch 224/400 | Train Loss: 0.2401 | Train MAE klw: 0.2652 | Train MAE mcool: 0.2473 | Valid Loss: 0.1068 | Valid MAE klw: 0.1911 | Valid MAE mcool: 0.1693 | Valid R² klw: 0.9360 | Valid R² mcool: 0.9479
# Epoch 225/400 | Train Loss: 0.2379 | Train MAE klw: 0.2641 | Train MAE mcool: 0.2475 | Valid Loss: 0.1028 | Valid MAE klw: 0.1946 | Valid MAE mcool: 0.1629 | Valid R² klw: 0.9379 | Valid R² mcool: 0.9504
# Epoch 226/400 | Train Loss: 0.2424 | Train MAE klw: 0.2656 | Train MAE mcool: 0.2494 | Valid Loss: 0.0999 | Valid MAE klw: 0.1770 | Valid MAE mcool: 0.1745 | Valid R² klw: 0.9482 | Valid R² mcool: 0.9423
# Epoch 227/400 | Train Loss: 0.2363 | Train MAE klw: 0.2610 | Train MAE mcool: 0.2460 | Valid Loss: 0.1318 | Valid MAE klw: 0.2278 | Valid MAE mcool: 0.1732 | Valid R² klw: 0.9116 | Valid R² mcool: 0.9462
# Epoch 228/400 | Train Loss: 0.2334 | Train MAE klw: 0.2613 | Train MAE mcool: 0.2448 | Valid Loss: 0.0956 | Valid MAE klw: 0.1778 | Valid MAE mcool: 0.1569 | Valid R² klw: 0.9429 | Valid R² mcool: 0.9532
# Epoch 229/400 | Train Loss: 0.2364 | Train MAE klw: 0.2632 | Train MAE mcool: 0.2479 | Valid Loss: 0.0934 | Valid MAE klw: 0.1729 | Valid MAE mcool: 0.1580 | Valid R² klw: 0.9463 | Valid R² mcool: 0.9520
# ...
# Epoch 326/400 | Train Loss: 0.2115 | Train MAE klw: 0.2418 | Train MAE mcool: 0.2303 | Valid Loss: 0.0797 | Valid MAE klw: 0.1679 | Valid MAE mcool: 0.1407 | Valid R² klw: 0.9515 | Valid R² mcool: 0.9620
# Epoch 327/400 | Train Loss: 0.2057 | Train MAE klw: 0.2403 | Train MAE mcool: 0.2275 | Valid Loss: 0.0800 | Valid MAE klw: 0.1660 | Valid MAE mcool: 0.1451 | Valid R² klw: 0.9534 | Valid R² mcool: 0.9595
# Epoch 328/400 | Train Loss: 0.2103 | Train MAE klw: 0.2419 | Train MAE mcool: 0.2286 | Valid Loss: 0.0808 | Valid MAE klw: 0.1678 | Valid MAE mcool: 0.1421 | Valid R² klw: 0.9509 | Valid R² mcool: 0.9613
# Epoch 329/400 | Train Loss: 0.2100 | Train MAE klw: 0.2414 | Train MAE mcool: 0.2295 | Valid Loss: 0.0864 | Valid MAE klw: 0.1747 | Valid MAE mcool: 0.1465 | Valid R² klw: 0.9466 | Valid R² mcool: 0.9597
# Epoch 330/400 | Train Loss: 0.2082 | Train MAE klw: 0.2414 | Train MAE mcool: 0.2292 | Valid Loss: 0.0789 | Valid MAE klw: 0.1660 | Valid MAE mcool: 0.1402 | Valid R² klw: 0.9523 | Valid R² mcool: 0.9620
# Epoch 331/400 | Train Loss: 0.2113 | Train MAE klw: 0.2417 | Train MAE mcool: 0.2301 | Valid Loss: 0.0824 | Valid MAE klw: 0.1734 | Valid MAE mcool: 0.1397 | Valid R² klw: 0.9481 | Valid R² mcool: 0.9627
# Epoch 332/400 | Train Loss: 0.2097 | Train MAE klw: 0.2403 | Train MAE mcool: 0.2299 | Valid Loss: 0.0778 | Valid MAE klw: 0.1658 | Valid MAE mcool: 0.1380 | Valid R² klw: 0.9532 | Valid R² mcool: 0.9623
# Epoch 333/400 | Train Loss: 0.2108 | Train MAE klw: 0.2417 | Train MAE mcool: 0.2292 | Valid Loss: 0.0798 | Valid MAE klw: 0.1655 | Valid MAE mcool: 0.1430 | Valid R² klw: 0.9520 | Valid R² mcool: 0.9612
# Epoch 334/400 | Train Loss: 0.2091 | Train MAE klw: 0.2404 | Train MAE mcool: 0.2292 | Valid Loss: 0.0846 | Valid MAE klw: 0.1721 | Valid MAE mcool: 0.1461 | Valid R² klw: 0.9482 | Valid R² mcool: 0.9600
# Epoch 335/400 | Train Loss: 0.2099 | Train MAE klw: 0.2404 | Train MAE mcool: 0.2294 | Valid Loss: 0.0760 | Valid MAE klw: 0.1601 | Valid MAE mcool: 0.1406 | Valid R² klw: 0.9555 | Valid R² mcool: 0.9618
#   → New best model saved!
# Epoch 336/400 | Train Loss: 0.2100 | Train MAE klw: 0.2424 | Train MAE mcool: 0.2275 | Valid Loss: 0.0778 | Valid MAE klw: 0.1649 | Valid MAE mcool: 0.1395 | Valid R² klw: 0.9537 | Valid R² mcool: 0.9618
# Epoch 337/400 | Train Loss: 0.2092 | Train MAE klw: 0.2405 | Train MAE mcool: 0.2293 | Valid Loss: 0.0837 | Valid MAE klw: 0.1743 | Valid MAE mcool: 0.1418 | Valid R² klw: 0.9476 | Valid R² mcool: 0.9617
# Epoch 338/400 | Train Loss: 0.2100 | Train MAE klw: 0.2424 | Train MAE mcool: 0.2284 | Valid Loss: 0.0796 | Valid MAE klw: 0.1682 | Valid MAE mcool: 0.1411 | Valid R² klw: 0.9518 | Valid R² mcool: 0.9617
# Epoch 339/400 | Train Loss: 0.2088 | Train MAE klw: 0.2388 | Train MAE mcool: 0.2293 | Valid Loss: 0.0821 | Valid MAE klw: 0.1702 | Valid MAE mcool: 0.1417 | Valid R² klw: 0.9492 | Valid R² mcool: 0.9617
# Epoch 340/400 | Train Loss: 0.2097 | Train MAE klw: 0.2416 | Train MAE mcool: 0.2287 | Valid Loss: 0.0786 | Valid MAE klw: 0.1639 | Valid MAE mcool: 0.1406 | Valid R² klw: 0.9533 | Valid R² mcool: 0.9613
# Epoch 341/400 | Train Loss: 0.2108 | Train MAE klw: 0.2420 | Train MAE mcool: 0.2292 | Valid Loss: 0.0804 | Valid MAE klw: 0.1690 | Valid MAE mcool: 0.1392 | Valid R² klw: 0.9503 | Valid R² mcool: 0.9626
# Epoch 342/400 | Train Loss: 0.2118 | Train MAE klw: 0.2426 | Train MAE mcool: 0.2292 | Valid Loss: 0.0804 | Valid MAE klw: 0.1660 | Valid MAE mcool: 0.1445 | Valid R² klw: 0.9525 | Valid R² mcool: 0.9601
# Epoch 343/400 | Train Loss: 0.2113 | Train MAE klw: 0.2425 | Train MAE mcool: 0.2309 | Valid Loss: 0.0802 | Valid MAE klw: 0.1676 | Valid MAE mcool: 0.1414 | Valid R² klw: 0.9518 | Valid R² mcool: 0.9610
# Epoch 344/400 | Train Loss: 0.2078 | Train MAE klw: 0.2413 | Train MAE mcool: 0.2269 | Valid Loss: 0.0779 | Valid MAE klw: 0.1648 | Valid MAE mcool: 0.1378 | Valid R² klw: 0.9523 | Valid R² mcool: 0.9632
# Epoch 345/400 | Train Loss: 0.2082 | Train MAE klw: 0.2399 | Train MAE mcool: 0.2279 | Valid Loss: 0.0771 | Valid MAE klw: 0.1624 | Valid MAE mcool: 0.1388 | Valid R² klw: 0.9535 | Valid R² mcool: 0.9628
# Epoch 346/400 | Train Loss: 0.2077 | Train MAE klw: 0.2387 | Train MAE mcool: 0.2290 | Valid Loss: 0.0810 | Valid MAE klw: 0.1710 | Valid MAE mcool: 0.1379 | Valid R² klw: 0.9490 | Valid R² mcool: 0.9633
# Epoch 347/400 | Train Loss: 0.2116 | Train MAE klw: 0.2422 | Train MAE mcool: 0.2301 | Valid Loss: 0.0819 | Valid MAE klw: 0.1696 | Valid MAE mcool: 0.1422 | Valid R² klw: 0.9498 | Valid R² mcool: 0.9614
# Epoch 348/400 | Train Loss: 0.2085 | Train MAE klw: 0.2413 | Train MAE mcool: 0.2288 | Valid Loss: 0.0753 | Valid MAE klw: 0.1595 | Valid MAE mcool: 0.1394 | Valid R² klw: 0.9564 | Valid R² mcool: 0.9617
#   → New best model saved!
# Epoch 349/400 | Train Loss: 0.2098 | Train MAE klw: 0.2413 | Train MAE mcool: 0.2301 | Valid Loss: 0.0799 | Valid MAE klw: 0.1675 | Valid MAE mcool: 0.1412 | Valid R² klw: 0.9514 | Valid R² mcool: 0.9619
# Epoch 350/400 | Train Loss: 0.2079 | Train MAE klw: 0.2409 | Train MAE mcool: 0.2271 | Valid Loss: 0.0785 | Valid MAE klw: 0.1659 | Valid MAE mcool: 0.1378 | Valid R² klw: 0.9518 | Valid R² mcool: 0.9631
# Epoch 351/400 | Train Loss: 0.2082 | Train MAE klw: 0.2406 | Train MAE mcool: 0.2281 | Valid Loss: 0.0813 | Valid MAE klw: 0.1697 | Valid MAE mcool: 0.1410 | Valid R² klw: 0.9497 | Valid R² mcool: 0.9622
# Epoch 352/400 | Train Loss: 0.2100 | Train MAE klw: 0.2419 | Train MAE mcool: 0.2290 | Valid Loss: 0.0770 | Valid MAE klw: 0.1611 | Valid MAE mcool: 0.1405 | Valid R² klw: 0.9543 | Valid R² mcool: 0.9620
# Epoch 353/400 | Train Loss: 0.2109 | Train MAE klw: 0.2422 | Train MAE mcool: 0.2283 | Valid Loss: 0.0790 | Valid MAE klw: 0.1660 | Valid MAE mcool: 0.1396 | Valid R² klw: 0.9519 | Valid R² mcool: 0.9624
# Epoch 354/400 | Train Loss: 0.2091 | Train MAE klw: 0.2406 | Train MAE mcool: 0.2293 | Valid Loss: 0.0766 | Valid MAE klw: 0.1622 | Valid MAE mcool: 0.1362 | Valid R² klw: 0.9533 | Valid R² mcool: 0.9636
# Epoch 355/400 | Train Loss: 0.2099 | Train MAE klw: 0.2412 | Train MAE mcool: 0.2290 | Valid Loss: 0.0848 | Valid MAE klw: 0.1727 | Valid MAE mcool: 0.1463 | Valid R² klw: 0.9485 | Valid R² mcool: 0.9595
# Epoch 356/400 | Train Loss: 0.2070 | Train MAE klw: 0.2397 | Train MAE mcool: 0.2282 | Valid Loss: 0.0795 | Valid MAE klw: 0.1671 | Valid MAE mcool: 0.1412 | Valid R² klw: 0.9519 | Valid R² mcool: 0.9618
# Epoch 357/400 | Train Loss: 0.2072 | Train MAE klw: 0.2387 | Train MAE mcool: 0.2293 | Valid Loss: 0.0794 | Valid MAE klw: 0.1652 | Valid MAE mcool: 0.1408 | Valid R² klw: 0.9518 | Valid R² mcool: 0.9620
# Epoch 358/400 | Train Loss: 0.2073 | Train MAE klw: 0.2391 | Train MAE mcool: 0.2287 | Valid Loss: 0.0793 | Valid MAE klw: 0.1676 | Valid MAE mcool: 0.1371 | Valid R² klw: 0.9505 | Valid R² mcool: 0.9636
# Epoch 359/400 | Train Loss: 0.2088 | Train MAE klw: 0.2409 | Train MAE mcool: 0.2290 | Valid Loss: 0.0769 | Valid MAE klw: 0.1640 | Valid MAE mcool: 0.1384 | Valid R² klw: 0.9538 | Valid R² mcool: 0.9627
# Epoch 360/400 | Train Loss: 0.2100 | Train MAE klw: 0.2422 | Train MAE mcool: 0.2282 | Valid Loss: 0.0806 | Valid MAE klw: 0.1708 | Valid MAE mcool: 0.1395 | Valid R² klw: 0.9499 | Valid R² mcool: 0.9627
# Epoch 361/400 | Train Loss: 0.2115 | Train MAE klw: 0.2416 | Train MAE mcool: 0.2293 | Valid Loss: 0.0802 | Valid MAE klw: 0.1678 | Valid MAE mcool: 0.1397 | Valid R² klw: 0.9504 | Valid R² mcool: 0.9626
# Epoch 362/400 | Train Loss: 0.2083 | Train MAE klw: 0.2410 | Train MAE mcool: 0.2281 | Valid Loss: 0.0818 | Valid MAE klw: 0.1692 | Valid MAE mcool: 0.1420 | Valid R² klw: 0.9499 | Valid R² mcool: 0.9613
# Epoch 363/400 | Train Loss: 0.2093 | Train MAE klw: 0.2389 | Train MAE mcool: 0.2294 | Valid Loss: 0.0855 | Valid MAE klw: 0.1762 | Valid MAE mcool: 0.1430 | Valid R² klw: 0.9461 | Valid R² mcool: 0.9613
# Epoch 364/400 | Train Loss: 0.2094 | Train MAE klw: 0.2410 | Train MAE mcool: 0.2306 | Valid Loss: 0.0802 | Valid MAE klw: 0.1672 | Valid MAE mcool: 0.1405 | Valid R² klw: 0.9509 | Valid R² mcool: 0.9622
# Epoch 365/400 | Train Loss: 0.2076 | Train MAE klw: 0.2414 | Train MAE mcool: 0.2285 | Valid Loss: 0.0756 | Valid MAE klw: 0.1633 | Valid MAE mcool: 0.1345 | Valid R² klw: 0.9537 | Valid R² mcool: 0.9644
# Epoch 366/400 | Train Loss: 0.2057 | Train MAE klw: 0.2383 | Train MAE mcool: 0.2278 | Valid Loss: 0.0793 | Valid MAE klw: 0.1657 | Valid MAE mcool: 0.1419 | Valid R² klw: 0.9525 | Valid R² mcool: 0.9613
# Epoch 367/400 | Train Loss: 0.2082 | Train MAE klw: 0.2400 | Train MAE mcool: 0.2287 | Valid Loss: 0.0781 | Valid MAE klw: 0.1637 | Valid MAE mcool: 0.1402 | Valid R² klw: 0.9529 | Valid R² mcool: 0.9622
# Epoch 368/400 | Train Loss: 0.2059 | Train MAE klw: 0.2388 | Train MAE mcool: 0.2259 | Valid Loss: 0.0767 | Valid MAE klw: 0.1622 | Valid MAE mcool: 0.1376 | Valid R² klw: 0.9533 | Valid R² mcool: 0.9634
# Epoch 369/400 | Train Loss: 0.2049 | Train MAE klw: 0.2399 | Train MAE mcool: 0.2246 | Valid Loss: 0.0786 | Valid MAE klw: 0.1654 | Valid MAE mcool: 0.1399 | Valid R² klw: 0.9527 | Valid R² mcool: 0.9620
# Epoch 370/400 | Train Loss: 0.2094 | Train MAE klw: 0.2409 | Train MAE mcool: 0.2294 | Valid Loss: 0.0758 | Valid MAE klw: 0.1611 | Valid MAE mcool: 0.1383 | Valid R² klw: 0.9546 | Valid R² mcool: 0.9630
# Epoch 371/400 | Train Loss: 0.2069 | Train MAE klw: 0.2385 | Train MAE mcool: 0.2282 | Valid Loss: 0.0784 | Valid MAE klw: 0.1663 | Valid MAE mcool: 0.1385 | Valid R² klw: 0.9519 | Valid R² mcool: 0.9630
# Epoch 372/400 | Train Loss: 0.2089 | Train MAE klw: 0.2401 | Train MAE mcool: 0.2283 | Valid Loss: 0.0756 | Valid MAE klw: 0.1622 | Valid MAE mcool: 0.1362 | Valid R² klw: 0.9542 | Valid R² mcool: 0.9637
# Epoch 373/400 | Train Loss: 0.2059 | Train MAE klw: 0.2381 | Train MAE mcool: 0.2275 | Valid Loss: 0.0776 | Valid MAE klw: 0.1647 | Valid MAE mcool: 0.1375 | Valid R² klw: 0.9527 | Valid R² mcool: 0.9631
# Epoch 374/400 | Train Loss: 0.2081 | Train MAE klw: 0.2392 | Train MAE mcool: 0.2277 | Valid Loss: 0.0794 | Valid MAE klw: 0.1681 | Valid MAE mcool: 0.1382 | Valid R² klw: 0.9508 | Valid R² mcool: 0.9630
# Epoch 375/400 | Train Loss: 0.2077 | Train MAE klw: 0.2393 | Train MAE mcool: 0.2291 | Valid Loss: 0.0783 | Valid MAE klw: 0.1659 | Valid MAE mcool: 0.1372 | Valid R² klw: 0.9517 | Valid R² mcool: 0.9635
# Epoch 376/400 | Train Loss: 0.2076 | Train MAE klw: 0.2399 | Train MAE mcool: 0.2276 | Valid Loss: 0.0782 | Valid MAE klw: 0.1642 | Valid MAE mcool: 0.1407 | Valid R² klw: 0.9534 | Valid R² mcool: 0.9616
# Epoch 377/400 | Train Loss: 0.2083 | Train MAE klw: 0.2396 | Train MAE mcool: 0.2285 | Valid Loss: 0.0774 | Valid MAE klw: 0.1641 | Valid MAE mcool: 0.1372 | Valid R² klw: 0.9526 | Valid R² mcool: 0.9635
# Epoch 378/400 | Train Loss: 0.2066 | Train MAE klw: 0.2386 | Train MAE mcool: 0.2281 | Valid Loss: 0.0793 | Valid MAE klw: 0.1687 | Valid MAE mcool: 0.1376 | Valid R² klw: 0.9506 | Valid R² mcool: 0.9634
# Epoch 379/400 | Train Loss: 0.2066 | Train MAE klw: 0.2396 | Train MAE mcool: 0.2275 | Valid Loss: 0.0790 | Valid MAE klw: 0.1647 | Valid MAE mcool: 0.1406 | Valid R² klw: 0.9522 | Valid R² mcool: 0.9621
# Epoch 380/400 | Train Loss: 0.2090 | Train MAE klw: 0.2407 | Train MAE mcool: 0.2288 | Valid Loss: 0.0787 | Valid MAE klw: 0.1650 | Valid MAE mcool: 0.1395 | Valid R² klw: 0.9519 | Valid R² mcool: 0.9627
# Epoch 381/400 | Train Loss: 0.2079 | Train MAE klw: 0.2382 | Train MAE mcool: 0.2299 | Valid Loss: 0.0774 | Valid MAE klw: 0.1651 | Valid MAE mcool: 0.1379 | Valid R² klw: 0.9528 | Valid R² mcool: 0.9632
# Epoch 382/400 | Train Loss: 0.2070 | Train MAE klw: 0.2390 | Train MAE mcool: 0.2277 | Valid Loss: 0.0792 | Valid MAE klw: 0.1670 | Valid MAE mcool: 0.1383 | Valid R² klw: 0.9511 | Valid R² mcool: 0.9630
# Epoch 383/400 | Train Loss: 0.2046 | Train MAE klw: 0.2388 | Train MAE mcool: 0.2263 | Valid Loss: 0.0788 | Valid MAE klw: 0.1648 | Valid MAE mcool: 0.1397 | Valid R² klw: 0.9520 | Valid R² mcool: 0.9625
# Epoch 384/400 | Train Loss: 0.2062 | Train MAE klw: 0.2406 | Train MAE mcool: 0.2265 | Valid Loss: 0.0795 | Valid MAE klw: 0.1680 | Valid MAE mcool: 0.1380 | Valid R² klw: 0.9505 | Valid R² mcool: 0.9633
# Epoch 385/400 | Train Loss: 0.2081 | Train MAE klw: 0.2407 | Train MAE mcool: 0.2272 | Valid Loss: 0.0774 | Valid MAE klw: 0.1652 | Valid MAE mcool: 0.1372 | Valid R² klw: 0.9524 | Valid R² mcool: 0.9637
# Epoch 386/400 | Train Loss: 0.2111 | Train MAE klw: 0.2415 | Train MAE mcool: 0.2294 | Valid Loss: 0.0794 | Valid MAE klw: 0.1670 | Valid MAE mcool: 0.1384 | Valid R² klw: 0.9509 | Valid R² mcool: 0.9630
# Epoch 387/400 | Train Loss: 0.2094 | Train MAE klw: 0.2412 | Train MAE mcool: 0.2280 | Valid Loss: 0.0783 | Valid MAE klw: 0.1660 | Valid MAE mcool: 0.1387 | Valid R² klw: 0.9522 | Valid R² mcool: 0.9628
# Epoch 388/400 | Train Loss: 0.2065 | Train MAE klw: 0.2376 | Train MAE mcool: 0.2285 | Valid Loss: 0.0774 | Valid MAE klw: 0.1640 | Valid MAE mcool: 0.1377 | Valid R² klw: 0.9527 | Valid R² mcool: 0.9633
# Epoch 389/400 | Train Loss: 0.2061 | Train MAE klw: 0.2391 | Train MAE mcool: 0.2267 | Valid Loss: 0.0792 | Valid MAE klw: 0.1667 | Valid MAE mcool: 0.1391 | Valid R² klw: 0.9515 | Valid R² mcool: 0.9626
# Epoch 390/400 | Train Loss: 0.2053 | Train MAE klw: 0.2369 | Train MAE mcool: 0.2278 | Valid Loss: 0.0791 | Valid MAE klw: 0.1656 | Valid MAE mcool: 0.1410 | Valid R² klw: 0.9521 | Valid R² mcool: 0.9620
# Epoch 391/400 | Train Loss: 0.2074 | Train MAE klw: 0.2395 | Train MAE mcool: 0.2271 | Valid Loss: 0.0785 | Valid MAE klw: 0.1655 | Valid MAE mcool: 0.1387 | Valid R² klw: 0.9521 | Valid R² mcool: 0.9628
# Epoch 392/400 | Train Loss: 0.2040 | Train MAE klw: 0.2379 | Train MAE mcool: 0.2271 | Valid Loss: 0.0767 | Valid MAE klw: 0.1635 | Valid MAE mcool: 0.1382 | Valid R² klw: 0.9536 | Valid R² mcool: 0.9630
# Epoch 393/400 | Train Loss: 0.2092 | Train MAE klw: 0.2399 | Train MAE mcool: 0.2300 | Valid Loss: 0.0775 | Valid MAE klw: 0.1656 | Valid MAE mcool: 0.1366 | Valid R² klw: 0.9521 | Valid R² mcool: 0.9639
# Epoch 394/400 | Train Loss: 0.2050 | Train MAE klw: 0.2386 | Train MAE mcool: 0.2274 | Valid Loss: 0.0789 | Valid MAE klw: 0.1673 | Valid MAE mcool: 0.1378 | Valid R² klw: 0.9511 | Valid R² mcool: 0.9634
# Epoch 395/400 | Train Loss: 0.2060 | Train MAE klw: 0.2390 | Train MAE mcool: 0.2289 | Valid Loss: 0.0782 | Valid MAE klw: 0.1631 | Valid MAE mcool: 0.1409 | Valid R² klw: 0.9533 | Valid R² mcool: 0.9617
# Epoch 396/400 | Train Loss: 0.2101 | Train MAE klw: 0.2405 | Train MAE mcool: 0.2291 | Valid Loss: 0.0800 | Valid MAE klw: 0.1683 | Valid MAE mcool: 0.1403 | Valid R² klw: 0.9509 | Valid R² mcool: 0.9623
# Epoch 397/400 | Train Loss: 0.2141 | Train MAE klw: 0.2425 | Train MAE mcool: 0.2312 | Valid Loss: 0.0756 | Valid MAE klw: 0.1604 | Valid MAE mcool: 0.1385 | Valid R² klw: 0.9550 | Valid R² mcool: 0.9628
# Epoch 398/400 | Train Loss: 0.2069 | Train MAE klw: 0.2394 | Train MAE mcool: 0.2274 | Valid Loss: 0.0777 | Valid MAE klw: 0.1628 | Valid MAE mcool: 0.1404 | Valid R² klw: 0.9537 | Valid R² mcool: 0.9618
# Epoch 399/400 | Train Loss: 0.2100 | Train MAE klw: 0.2400 | Train MAE mcool: 0.2301 | Valid Loss: 0.0790 | Valid MAE klw: 0.1656 | Valid MAE mcool: 0.1403 | Valid R² klw: 0.9522 | Valid R² mcool: 0.9621
# Epoch 400/400 | Train Loss: 0.2060 | Train MAE klw: 0.2385 | Train MAE mcool: 0.2285 | Valid Loss: 0.0775 | Valid MAE klw: 0.1647 | Valid MAE mcool: 0.1379 | Valid R² klw: 0.9528 | Valid R² mcool: 0.9632
#
# Training history saved to: modelD/training_history_caseB.csv
# Loading best model weights...
# Test Loss: 0.0984, Test MAE klw: 0.1651, Test MAE mcool: 0.1665, Test R2 klw: 0.9497, Test R2 mcool: 0.9470
# 部分测试集预测值与真实值（klw, mcool）：
# 样本 1: 预测值=[3.0625, 3.0672e+05], 真实值=[2.9600, 3.0700e+05]
# 样本 2: 预测值=[0.8487, 1.4837e+05], 真实值=[0.2000, 1.6400e+05]
# 样本 3: 预测值=[3.2415, 2.2006e+05], 真实值=[3.2900, 2.1600e+05]
# 样本 4: 预测值=[2.0961, 1.6896e+05], 真实值=[1.7200, 1.4900e+05]
# 样本 5: 预测值=[4.9591, 4.2552e+05], 真实值=[4.9200, 4.4300e+05]

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame(history)

plt.figure(figsize=(8, 10))

plt.subplot(3, 1, 1)
plt.plot(df['epoch'], df['train_loss'], label='Train Loss')
plt.plot(df['epoch'], df['valid_loss'], label='Valid Loss')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.legend(fontsize=14)

plt.subplot(3, 1, 2)
plt.plot(df['epoch'], df['train_mae_klw'], label='Train MAE $\\alpha_\\mathrm{LW}$', color='skyblue')
plt.plot(df['epoch'], df['valid_mae_klw'], label='Valid MAE $\\alpha_\\mathrm{LW}$', color='salmon')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('MAE',fontsize=16)
plt.legend(fontsize=14)

plt.subplot(3, 1, 3)
plt.plot(df['epoch'], df['train_mae_mcool'], label='Train MAE $M_{\mathrm{cool}}$', color='teal')
plt.plot(df['epoch'], df['valid_mae_mcool'], label='Valid MAE $M_{\mathrm{cool}}$', color='orange')
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('MAE', fontsize=16)
plt.legend(fontsize=14)

plt.tight_layout()
plt.savefig('modelD/traininghistory_CaseB.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# 测试集参数估计可视化

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# MODIFIED: 设置学术论文字体和样式（全局配置）
plt.rcParams['font.size'] = 10  # 默认字体大小10pt
plt.rcParams['axes.titlesize'] = 12  # 标题12pt
plt.rcParams['axes.labelsize'] = 10  # 轴标签10pt
plt.rcParams['xtick.labelsize'] = 10  # x轴刻度10pt
plt.rcParams['ytick.labelsize'] = 10  # y轴刻度10pt
plt.rcParams['legend.fontsize'] = 10  # 图例10pt
plt.rcParams['lines.linewidth'] = 1.5  # 线宽1.5pt
plt.rcParams['lines.markersize'] = 6  # 标记大小6pt

# 加载数据（仅测试集）
_, _, test_loader = load_data()

# 初始化模型并加载最佳权重
model = CNN()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
model.load_state_dict(torch.load('modelD/best_model_caseB.pt'))
model.eval()

# 测试模型，获取预测和真实值
test_loss, test_mae_klw, test_mae_mcool, predictions, trues = test_model(model, test_loader, w_klw=1.0, w_mcool=1.0)

# 反归一化
label_stats = torch.load('modelD/processed_tensors/caseB/label_stats.pt')
mean = label_stats['mean']  # [klw_mean, mcool_mean]
std = label_stats['std']    # [klw_std, mcool_std]
predictions = predictions * std.numpy() + mean.numpy()  # 形状: (900, 2)
trues = trues * std.numpy() + mean.numpy()             # 形状: (900, 2)

# 1. 可视化预测结果：散点图比较预测值 vs 真实值（保持原样，但受益于全局字体）
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# k_LW的散点图
axes[0].scatter(trues[:, 0], predictions[:, 0], alpha=0.6, color='blue')
axes[0].plot([trues[:, 0].min(), trues[:, 0].max()], [trues[:, 0].min(), trues[:, 0].max()], 'r--', lw=1.5)
axes[0].set_xlabel('Real $k_{\mathrm{LW}}$')
axes[0].set_ylabel('Predicted $k_{\mathrm{LW}}$')
axes[0].set_title('$k_{\mathrm{LW}}$ Predicted vs Real')
axes[0].grid(True, alpha=0.3)
# M_cool的散点图（使用科学计数法）
axes[1].scatter(trues[:, 1], predictions[:, 1], alpha=0.6, color='green')
axes[1].plot([trues[:, 1].min(), trues[:, 1].max()], [trues[:, 1].min(), trues[:, 1].max()], 'r--', lw=1.5)
axes[1].set_xlabel('Real $M_{\mathrm{cool}}$')
axes[1].set_ylabel('Predicted $M_{\mathrm{cool}}$')
axes[1].set_title('$M_{\mathrm{cool}}$ Predicted vs Real')
axes[1].ticklabel_format(style='sci', axis='both', scilimits=(0,0))  # 科学计数法
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('modelD/prediction_scatter_10000.png', dpi=300, bbox_inches='tight')
plt.show()

# 2. 误差棒图：按真实值分组，计算对应预测值的范围（MODIFIED: 添加1sigma std范围）
# 第一张：按真实 k_LW 分组，计算预测 k_LW 的均值、std、max和min
unique_klw_real = np.unique(trues[:, 0])
unique_klw_real.sort()
mean_klw_pred = []  # MODIFIED: 新增均值
std_klw_pred = []   # MODIFIED: 新增标准差
max_klw_pred = []
min_klw_pred = []
sample_counts_klw = []
for klw_real in unique_klw_real:
    mask = np.isclose(trues[:, 0], klw_real, atol=1e-4)
    group_klw_preds = predictions[mask, 0]
    
    if len(group_klw_preds) > 1:  # MODIFIED: 至少2个样本才能计算std
        mean_klw_pred.append(np.mean(group_klw_preds))
        std_klw_pred.append(np.std(group_klw_preds))  # 1sigma = std
        max_klw_pred.append(np.max(group_klw_preds))
        min_klw_pred.append(np.min(group_klw_preds))
        sample_counts_klw.append(np.sum(mask))
    else:
        mean_klw_pred.append(np.nan)
        std_klw_pred.append(0)  # MODIFIED: std设为0，避免NaN
        max_klw_pred.append(np.nan)
        min_klw_pred.append(np.nan)
        sample_counts_klw.append(len(group_klw_preds))
mean_klw_pred = np.array(mean_klw_pred)
std_klw_pred = np.array(std_klw_pred)
max_klw_pred = np.array(max_klw_pred)
min_klw_pred = np.array(min_klw_pred)
sample_counts_klw = np.array(sample_counts_klw)

# 第二张：按真实 M_cool 分组，计算预测 M_cool 的均值、std、max和min
unique_mcool_real = np.unique(trues[:, 1])
unique_mcool_real.sort()
mean_mcool_pred = []  # MODIFIED: 新增均值
std_mcool_pred = []   # MODIFIED: 新增标准差
max_mcool_pred = []
min_mcool_pred = []
sample_counts_mcool = []
for mcool_real in unique_mcool_real:
    mask = np.isclose(trues[:, 1], mcool_real, atol=1e-4)
    group_mcool_preds = predictions[mask, 1]
    
    if len(group_mcool_preds) > 1:
        mean_mcool_pred.append(np.mean(group_mcool_preds))
        std_mcool_pred.append(np.std(group_mcool_preds))  # 1sigma = std
        max_mcool_pred.append(np.max(group_mcool_preds))
        min_mcool_pred.append(np.min(group_mcool_preds))
        sample_counts_mcool.append(np.sum(mask))
    else:
        mean_mcool_pred.append(np.nan)
        std_mcool_pred.append(0)
        max_mcool_pred.append(np.nan)
        min_mcool_pred.append(np.nan)
        sample_counts_mcool.append(len(group_mcool_preds))
mean_mcool_pred = np.array(mean_mcool_pred)
std_mcool_pred = np.array(std_mcool_pred)
max_mcool_pred = np.array(max_mcool_pred)
min_mcool_pred = np.array(min_mcool_pred)
sample_counts_mcool = np.array(sample_counts_mcool)

# 绘制误差棒图（MODIFIED: 双误差棒 + 学术样式）
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# 第一张：k_LW 误差棒图
# MODIFIED: 添加1sigma (std) 误差棒（蓝色，细线）
valid_idx_klw = ~np.isnan(mean_klw_pred)  # 只绘制有效组
axes[0].errorbar(unique_klw_real[valid_idx_klw], mean_klw_pred[valid_idx_klw], 
                 yerr=std_klw_pred[valid_idx_klw], fmt='o', capsize=3, color='blue', 
                 linewidth=1, elinewidth=1, markersize=6, label='1σ Prediction Range')
# 原max-min范围（绿色，粗线）
axes[0].errorbar(unique_klw_real[valid_idx_klw], (max_klw_pred[valid_idx_klw] + min_klw_pred[valid_idx_klw]) / 2, 
                 yerr=[(max_klw_pred[valid_idx_klw] - min_klw_pred[valid_idx_klw]) / 2], 
                 fmt='s', capsize=5, color='green', markerfacecolor='none', 
                 linewidth=1.5, elinewidth=1.5, markersize=6, label='Max-Min Prediction Range')
axes[0].plot(unique_klw_real, unique_klw_real, 'r--', lw=1.5, label='Ideal Line (y=x)')
axes[0].set_xlabel('Real $k_{\mathrm{LW}}$')
axes[0].set_ylabel('Predicted $k_{\mathrm{LW}}$')
axes[0].set_title('$k_{\mathrm{LW}}$ Prediction Ranges by Real $k_{\mathrm{LW}}$')
axes[0].legend(frameon=False)  # 无边框图例
axes[0].grid(True, alpha=0.3)

# 第二张：M_cool 误差棒图
# MODIFIED: 添加1sigma (std) 误差棒（蓝色，细线）
valid_idx_mcool = ~np.isnan(mean_mcool_pred)
axes[1].errorbar(unique_mcool_real[valid_idx_mcool], mean_mcool_pred[valid_idx_mcool], 
                 yerr=std_mcool_pred[valid_idx_mcool], fmt='o', capsize=3, color='blue', 
                 linewidth=1, elinewidth=1, markersize=6, label='1σ Prediction Range')
# 原max-min范围（绿色，粗线）
axes[1].errorbar(unique_mcool_real[valid_idx_mcool], (max_mcool_pred[valid_idx_mcool] + min_mcool_pred[valid_idx_mcool]) / 2, 
                 yerr=[(max_mcool_pred[valid_idx_mcool] - min_mcool_pred[valid_idx_mcool]) / 2], 
                 fmt='s', capsize=5, color='green', markerfacecolor='none', 
                 linewidth=1.5, elinewidth=1.5, markersize=6, label='Max-Min Prediction Range')
axes[1].plot(unique_mcool_real, unique_mcool_real, 'r--', lw=1.5, label='Ideal Line (y=x)')
axes[1].set_xlabel('Real $M_{\mathrm{cool}}$')
axes[1].set_ylabel('Predicted $M_{\mathrm{cool}}$')
axes[1].set_title('$M_{\mathrm{cool}}$ Prediction Ranges by Real $M_{\mathrm{cool}}$')
axes[1].ticklabel_format(style='sci', axis='both', scilimits=(0,0))  # 科学计数法
axes[1].legend(frameon=False)  # 无边框图例
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('modelD/error_bar_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# 打印分组统计（MODIFIED: 添加std信息）
print("k_LW 分组统计（真实 k_LW -> 预测 k_LW 范围）：")
for i, klw_real in enumerate(unique_klw_real):
    if not np.isnan(mean_klw_pred[i]):
        print(f"k_LW_real={klw_real:.2f}: mean={mean_klw_pred[i]:.4f}, 1σ=[{mean_klw_pred[i]-std_klw_pred[i]:.4f}, {mean_klw_pred[i]+std_klw_pred[i]:.4f}], "
              f"max-min=[{min_klw_pred[i]:.4f}, {max_klw_pred[i]:.4f}] (样本数: {sample_counts_klw[i]})")
print("\nM_cool 分组统计（真实 M_cool -> 预测 M_cool 范围）：")
for i, mcool_real in enumerate(unique_mcool_real):
    if not np.isnan(mean_mcool_pred[i]):
        print(f"M_cool_real={mcool_real:.4e}: mean={mean_mcool_pred[i]:.4e}, 1σ=[{mean_mcool_pred[i]-std_mcool_pred[i]:.4e}, {mean_mcool_pred[i]+std_mcool_pred[i]:.4e}], "
              f"max-min=[{min_mcool_pred[i]:.4e}, {max_mcool_pred[i]:.4e}] (样本数: {sample_counts_mcool[i]})")
# Out:
# 警告：test 数据集样本数量 (4644) 与预期 (3600) 不符！
# torch.Size([28800, 1, 20, 40])
# torch.Size([28800, 2])
# 训练集: 28800 样本, 数据形状 torch.Size([1, 20, 40])
# 验证集: 3600 样本, 数据形状 torch.Size([1, 20, 40])
# 测试集: 4644 样本, 数据形状 torch.Size([1, 20, 40])
# Test Loss: 0.0857, Test MAE klw: 0.1584, Test MAE mcool: 0.1488, Test R2 klw: 0.9398, Test R2 mcool: 0.9541
# k_LW 分组统计（真实 k_LW -> 预测 k_LW 范围）：
# k_LW_real=0.00: mean=0.1213, 1σ=[-0.2526, 0.4952], max-min=[-1.0223, 1.0316] (样本数: 36)
# k_LW_real=0.20: mean=0.7424, 1σ=[0.4113, 1.0736], max-min=[-0.1104, 1.3630] (样本数: 36)
# k_LW_real=0.23: mean=0.7231, 1σ=[0.4683, 0.9779], max-min=[0.1648, 1.2548] (样本数: 36)
# k_LW_real=0.38: mean=0.7874, 1σ=[0.5816, 0.9932], max-min=[0.2177, 1.2040] (样本数: 36)
# k_LW_real=0.49: mean=0.6127, 1σ=[0.4416, 0.7839], max-min=[0.0392, 0.9539] (样本数: 36)
# k_LW_real=0.52: mean=0.7186, 1σ=[0.5442, 0.8929], max-min=[0.3274, 1.0711] (样本数: 36)
# k_LW_real=0.54: mean=0.2886, 1σ=[0.0712, 0.5060], max-min=[-0.3367, 0.6653] (样本数: 36)
# k_LW_real=0.71: mean=1.2819, 1σ=[1.0880, 1.4759], max-min=[0.6810, 1.7074] (样本数: 36)
# k_LW_real=0.76: mean=1.0246, 1σ=[0.8669, 1.1823], max-min=[0.6803, 1.4258] (样本数: 36)
# k_LW_real=0.83: mean=0.7506, 1σ=[0.5575, 0.9438], max-min=[0.3801, 1.1031] (样本数: 36)
# k_LW_real=0.86: mean=1.0541, 1σ=[0.8855, 1.2226], max-min=[0.7968, 1.4541] (样本数: 36)
# k_LW_real=0.88: mean=0.9131, 1σ=[0.7351, 1.0911], max-min=[0.4888, 1.2247] (样本数: 36)
# k_LW_real=0.89: mean=1.0182, 1σ=[0.8701, 1.1663], max-min=[0.6509, 1.3158] (样本数: 36)
# k_LW_real=1.02: mean=1.6208, 1σ=[1.4425, 1.7990], max-min=[1.2865, 2.0471] (样本数: 36)
# k_LW_real=1.15: mean=1.0903, 1σ=[0.9403, 1.2402], max-min=[0.8125, 1.3633] (样本数: 36)
# k_LW_real=1.53: mean=1.8671, 1σ=[1.7385, 1.9956], max-min=[1.6417, 2.1374] (样本数: 36)
# k_LW_real=1.57: mean=2.0697, 1σ=[1.9030, 2.2364], max-min=[1.7912, 2.3462] (样本数: 36)
# k_LW_real=1.72: mean=2.1295, 1σ=[1.9658, 2.2932], max-min=[1.7787, 2.4960] (样本数: 36)
# k_LW_real=1.75: mean=2.1982, 1σ=[2.0680, 2.3284], max-min=[1.9221, 2.5046] (样本数: 36)
# k_LW_real=1.83: mean=2.0882, 1σ=[1.9416, 2.2349], max-min=[1.8708, 2.3955] (样本数: 36)
# k_LW_real=1.84: mean=2.1929, 1σ=[2.0422, 2.3436], max-min=[1.9230, 2.6653] (样本数: 36)
# k_LW_real=1.86: mean=2.2176, 1σ=[2.0689, 2.3663], max-min=[1.9569, 2.5800] (样本数: 36)
# k_LW_real=1.91: mean=2.2679, 1σ=[2.1289, 2.4070], max-min=[1.9272, 2.6384] (样本数: 36)
# k_LW_real=1.95: mean=2.2745, 1σ=[2.1389, 2.4102], max-min=[2.0087, 2.6732] (样本数: 72)
# k_LW_real=2.03: mean=2.3632, 1σ=[2.2438, 2.4827], max-min=[2.1599, 2.6612] (样本数: 36)
# k_LW_real=2.37: mean=2.5700, 1σ=[2.4149, 2.7252], max-min=[2.2199, 2.8687] (样本数: 36)
# k_LW_real=2.40: mean=2.5537, 1σ=[2.3963, 2.7110], max-min=[2.2342, 2.9257] (样本数: 36)
# k_LW_real=2.44: mean=2.5758, 1σ=[2.4754, 2.6763], max-min=[2.3940, 2.8152] (样本数: 36)
# k_LW_real=2.45: mean=2.7007, 1σ=[2.5588, 2.8426], max-min=[2.3407, 2.9965] (样本数: 72)
# k_LW_real=2.49: mean=2.6941, 1σ=[2.5580, 2.8302], max-min=[2.4005, 3.0198] (样本数: 36)
# k_LW_real=2.56: mean=2.7101, 1σ=[2.5917, 2.8284], max-min=[2.5191, 2.9202] (样本数: 36)
# k_LW_real=2.57: mean=2.7967, 1σ=[2.7027, 2.8907], max-min=[2.6166, 2.9767] (样本数: 36)
# k_LW_real=2.62: mean=2.7310, 1σ=[2.6014, 2.8607], max-min=[2.4561, 3.0402] (样本数: 36)
# k_LW_real=2.71: mean=2.8928, 1σ=[2.7816, 3.0041], max-min=[2.6863, 3.2462] (样本数: 36)
# k_LW_real=2.73: mean=2.6169, 1σ=[2.3055, 2.9282], max-min=[2.0673, 3.2938] (样本数: 36)
# k_LW_real=2.79: mean=2.9854, 1σ=[2.7078, 3.2630], max-min=[2.5382, 3.6196] (样本数: 36)
# k_LW_real=2.96: mean=3.0496, 1σ=[2.9509, 3.1482], max-min=[2.7877, 3.2502] (样本数: 36)
# k_LW_real=3.07: mean=3.2058, 1σ=[2.9226, 3.4891], max-min=[2.7628, 4.0348] (样本数: 36)
# k_LW_real=3.12: mean=3.1412, 1σ=[2.9682, 3.3142], max-min=[2.8599, 3.6771] (样本数: 36)
# k_LW_real=3.15: mean=3.3956, 1σ=[3.2620, 3.5292], max-min=[3.1869, 3.7652] (样本数: 36)
# k_LW_real=3.27: mean=3.4654, 1σ=[3.1637, 3.7670], max-min=[2.9792, 4.2701] (样本数: 36)
# k_LW_real=3.29: mean=3.2889, 1σ=[3.1107, 3.4670], max-min=[3.0065, 3.6110] (样本数: 36)
# k_LW_real=3.37: mean=3.6488, 1σ=[3.4545, 3.8431], max-min=[3.3435, 4.3849] (样本数: 36)
# k_LW_real=3.38: mean=3.5544, 1σ=[3.4372, 3.6715], max-min=[3.3048, 3.8570] (样本数: 36)
# k_LW_real=3.39: mean=3.5074, 1σ=[3.2469, 3.7679], max-min=[3.0583, 4.3125] (样本数: 72)
# k_LW_real=3.43: mean=3.6307, 1σ=[3.4796, 3.7819], max-min=[3.2775, 4.0569] (样本数: 36)
# k_LW_real=3.53: mean=3.5127, 1σ=[3.3347, 3.6908], max-min=[3.2392, 3.8677] (样本数: 36)
# k_LW_real=3.55: mean=3.6969, 1σ=[3.3726, 4.0211], max-min=[2.7997, 4.7229] (样本数: 1080)
# k_LW_real=3.63: mean=3.5589, 1σ=[3.3653, 3.7524], max-min=[3.2106, 3.9441] (样本数: 36)
# k_LW_real=3.64: mean=4.0080, 1σ=[3.8102, 4.2058], max-min=[3.5841, 4.4833] (样本数: 36)
# k_LW_real=3.65: mean=3.5756, 1σ=[3.3889, 3.7624], max-min=[3.2317, 3.9912] (样本数: 36)
# k_LW_real=3.80: mean=3.7813, 1σ=[3.5796, 3.9829], max-min=[3.2909, 4.3291] (样本数: 36)
# k_LW_real=3.89: mean=3.8357, 1σ=[3.6245, 4.0470], max-min=[3.2840, 4.2401] (样本数: 36)
# k_LW_real=3.96: mean=4.1037, 1σ=[3.7848, 4.4226], max-min=[3.4991, 4.9324] (样本数: 36)
# k_LW_real=3.99: mean=4.0210, 1σ=[3.7519, 4.2900], max-min=[3.4764, 4.5052] (样本数: 36)
# k_LW_real=4.01: mean=3.1159, 1σ=[2.4156, 3.8163], max-min=[1.8874, 4.7064] (样本数: 36)
# k_LW_real=4.21: mean=4.6663, 1σ=[4.4097, 4.9229], max-min=[4.1770, 5.1542] (样本数: 36)
# k_LW_real=4.25: mean=4.5341, 1σ=[4.2887, 4.7795], max-min=[4.0649, 5.0119] (样本数: 36)
# k_LW_real=4.31: mean=4.4175, 1σ=[4.0722, 4.7628], max-min=[3.7004, 5.2661] (样本数: 36)
# k_LW_real=4.34: mean=4.3530, 1σ=[4.1379, 4.5681], max-min=[4.0301, 4.8726] (样本数: 36)
# k_LW_real=4.37: mean=4.9428, 1σ=[4.6664, 5.2192], max-min=[4.5335, 6.0978] (样本数: 36)
# k_LW_real=4.43: mean=4.5950, 1σ=[4.2394, 4.9507], max-min=[3.6281, 5.2053] (样本数: 36)
# k_LW_real=4.44: mean=4.4752, 1σ=[4.1577, 4.7926], max-min=[3.6653, 5.0867] (样本数: 36)
# k_LW_real=4.51: mean=5.0784, 1σ=[4.7720, 5.3847], max-min=[4.5366, 5.8431] (样本数: 36)
# k_LW_real=4.53: mean=4.8594, 1σ=[4.5137, 5.2052], max-min=[4.0886, 5.7547] (样本数: 36)
# k_LW_real=4.55: mean=5.1872, 1σ=[4.8588, 5.5156], max-min=[4.5527, 6.0624] (样本数: 36)
# k_LW_real=4.65: mean=5.0201, 1σ=[4.7128, 5.3273], max-min=[4.2548, 5.6169] (样本数: 36)
# k_LW_real=4.74: mean=4.9479, 1σ=[4.6671, 5.2287], max-min=[4.2969, 5.4181] (样本数: 36)
# k_LW_real=4.76: mean=4.8137, 1σ=[4.3435, 5.2838], max-min=[4.0276, 6.6451] (样本数: 36)
# k_LW_real=4.79: mean=4.9045, 1σ=[4.7260, 5.0830], max-min=[4.4256, 5.2848] (样本数: 36)
# k_LW_real=4.86: mean=5.0601, 1σ=[4.7117, 5.4084], max-min=[4.2168, 5.5975] (样本数: 36)
# k_LW_real=4.92: mean=5.3504, 1σ=[5.0161, 5.6848], max-min=[4.6711, 5.9157] (样本数: 36)
# k_LW_real=4.93: mean=5.0317, 1σ=[4.8083, 5.2551], max-min=[4.6423, 5.4535] (样本数: 36)
# k_LW_real=5.17: mean=5.6633, 1σ=[5.3679, 5.9587], max-min=[5.1034, 6.3663] (样本数: 36)
# k_LW_real=5.41: mean=5.7997, 1σ=[5.4631, 6.1362], max-min=[5.2660, 6.5824] (样本数: 36)
# k_LW_real=5.56: mean=5.5127, 1σ=[5.2650, 5.7604], max-min=[5.0775, 6.1024] (样本数: 36)
# k_LW_real=5.63: mean=5.5455, 1σ=[5.3144, 5.7766], max-min=[5.0017, 5.9142] (样本数: 36)
# k_LW_real=5.66: mean=5.6046, 1σ=[5.2694, 5.9397], max-min=[4.6637, 6.1151] (样本数: 36)
# k_LW_real=5.77: mean=5.5136, 1σ=[5.2710, 5.7563], max-min=[5.0875, 6.1180] (样本数: 36)
# k_LW_real=5.81: mean=5.7305, 1σ=[5.4337, 6.0273], max-min=[4.8628, 6.8068] (样本数: 72)
# k_LW_real=5.94: mean=5.7016, 1σ=[5.3577, 6.0454], max-min=[4.7686, 6.4280] (样本数: 36)
# k_LW_real=5.99: mean=5.7319, 1σ=[5.3264, 6.1374], max-min=[4.5600, 6.7284] (样本数: 36)
# k_LW_real=6.02: mean=6.0928, 1σ=[5.7159, 6.4696], max-min=[5.6312, 7.5034] (样本数: 36)
# k_LW_real=6.11: mean=5.5828, 1σ=[5.3109, 5.8547], max-min=[5.1290, 6.1304] (样本数: 36)
# k_LW_real=6.22: mean=6.0132, 1σ=[5.5736, 6.4528], max-min=[5.1578, 7.1083] (样本数: 36)
# k_LW_real=6.27: mean=5.9521, 1σ=[5.6429, 6.2613], max-min=[4.9409, 6.4553] (样本数: 36)
# k_LW_real=6.29: mean=5.8581, 1σ=[5.5580, 6.1581], max-min=[4.8970, 6.2824] (样本数: 36)
# k_LW_real=6.30: mean=5.6739, 1σ=[5.4319, 5.9158], max-min=[5.2007, 6.2904] (样本数: 36)
# k_LW_real=6.34: mean=5.9450, 1σ=[5.6756, 6.2145], max-min=[5.3176, 6.5466] (样本数: 36)
# k_LW_real=6.45: mean=5.9365, 1σ=[5.4913, 6.3816], max-min=[4.4079, 6.7319] (样本数: 36)
# k_LW_real=6.68: mean=6.4925, 1σ=[6.0110, 6.9740], max-min=[5.8519, 8.0719] (样本数: 36)
# k_LW_real=6.79: mean=6.1836, 1σ=[5.8800, 6.4872], max-min=[5.0877, 6.6996] (样本数: 36)
# k_LW_real=6.85: mean=6.1994, 1σ=[5.9680, 6.4307], max-min=[5.8075, 6.7226] (样本数: 36)
# k_LW_real=6.91: mean=6.1452, 1σ=[5.7580, 6.5323], max-min=[5.5324, 7.1040] (样本数: 36)
# k_LW_real=6.92: mean=6.1621, 1σ=[5.9412, 6.3830], max-min=[5.4021, 6.5778] (样本数: 36)
# k_LW_real=6.94: mean=6.1515, 1σ=[5.9647, 6.3383], max-min=[5.5067, 6.4839] (样本数: 36)
#
# M_cool 分组统计（真实 M_cool -> 预测 M_cool 范围）：
# M_cool_real=5.0600e+04: mean=7.3452e+04, 1σ=[4.6952e+04, 9.9953e+04], max-min=[1.7669e+04, 1.3492e+05] (样本数: 36)
# M_cool_real=5.9900e+04: mean=9.2550e+04, 1σ=[7.6500e+04, 1.0860e+05], max-min=[4.4199e+04, 1.4001e+05] (样本数: 36)
# M_cool_real=6.9700e+04: mean=9.4429e+04, 1σ=[7.9475e+04, 1.0938e+05], max-min=[5.9614e+04, 1.1932e+05] (样本数: 36)
# M_cool_real=7.7400e+04: mean=1.0488e+05, 1σ=[9.1933e+04, 1.1782e+05], max-min=[8.0080e+04, 1.3520e+05] (样本数: 36)
# M_cool_real=8.3400e+04: mean=9.5930e+04, 1σ=[8.3806e+04, 1.0805e+05], max-min=[4.9995e+04, 1.1288e+05] (样本数: 36)
# M_cool_real=9.8800e+04: mean=1.0578e+05, 1σ=[8.2992e+04, 1.2857e+05], max-min=[5.7274e+04, 1.7560e+05] (样本数: 36)
# M_cool_real=1.0000e+05: mean=1.1863e+05, 1σ=[8.4457e+04, 1.5281e+05], max-min=[6.4672e+04, 2.0685e+05] (样本数: 36)
# M_cool_real=1.0800e+05: mean=1.2381e+05, 1σ=[1.1485e+05, 1.3278e+05], max-min=[1.0421e+05, 1.4130e+05] (样本数: 36)
# M_cool_real=1.1500e+05: mean=1.3236e+05, 1σ=[1.2435e+05, 1.4038e+05], max-min=[1.0959e+05, 1.4436e+05] (样本数: 36)
# M_cool_real=1.1700e+05: mean=1.3782e+05, 1σ=[1.2788e+05, 1.4777e+05], max-min=[1.0430e+05, 1.5372e+05] (样本数: 36)
# M_cool_real=1.2100e+05: mean=1.3496e+05, 1σ=[1.2730e+05, 1.4262e+05], max-min=[1.1883e+05, 1.5558e+05] (样本数: 36)
# M_cool_real=1.2200e+05: mean=1.3548e+05, 1σ=[1.2410e+05, 1.4685e+05], max-min=[1.1927e+05, 1.6272e+05] (样本数: 36)
# M_cool_real=1.4900e+05: mean=1.6612e+05, 1σ=[1.5662e+05, 1.7562e+05], max-min=[1.4891e+05, 1.8634e+05] (样本数: 36)
# M_cool_real=1.5300e+05: mean=1.6382e+05, 1σ=[1.5493e+05, 1.7271e+05], max-min=[1.4113e+05, 1.8146e+05] (样本数: 36)
# M_cool_real=1.5700e+05: mean=1.7111e+05, 1σ=[1.6149e+05, 1.8074e+05], max-min=[1.5012e+05, 1.9801e+05] (样本数: 36)
# M_cool_real=1.6000e+05: mean=1.7908e+05, 1σ=[1.7394e+05, 1.8422e+05], max-min=[1.7021e+05, 1.9262e+05] (样本数: 36)
# M_cool_real=1.6400e+05: mean=1.6177e+05, 1σ=[1.3702e+05, 1.8653e+05], max-min=[1.1820e+05, 2.3181e+05] (样本数: 36)
# M_cool_real=4.7300e+05: mean=4.1389e+05, 1σ=[3.9485e+05, 4.3294e+05], max-min=[3.8190e+05, 4.5552e+05] (样本数: 36)
# M_cool_real=4.7700e+05: mean=4.5187e+05, 1σ=[4.2201e+05, 4.8172e+05], max-min=[3.6370e+05, 5.0910e+05] (样本数: 36)
# M_cool_real=4.7800e+05: mean=4.3995e+05, 1σ=[4.1411e+05, 4.6579e+05], max-min=[3.6637e+05, 5.2906e+05] (样本数: 36)
# M_cool_real=4.8000e+05: mean=4.8489e+05, 1σ=[4.5797e+05, 5.1182e+05], max-min=[4.1913e+05, 5.6222e+05] (样本数: 36)
# M_cool_real=4.8500e+05: mean=4.2156e+05, 1σ=[4.0027e+05, 4.4285e+05], max-min=[3.7325e+05, 4.8697e+05] (样本数: 36)
# M_cool_real=4.9000e+05: mean=4.1456e+05, 1σ=[3.9268e+05, 4.3644e+05], max-min=[3.6268e+05, 4.6157e+05] (样本数: 36)
# M_cool_real=4.9200e+05: mean=4.2078e+05, 1σ=[4.0121e+05, 4.4034e+05], max-min=[3.5453e+05, 4.5435e+05] (样本数: 36)
# M_cool_real=4.9400e+05: mean=4.3824e+05, 1σ=[4.1278e+05, 4.6371e+05], max-min=[3.9097e+05, 4.8835e+05] (样本数: 36)
# M_cool_real=4.9500e+05: mean=4.2522e+05, 1σ=[4.0132e+05, 4.4911e+05], max-min=[3.6261e+05, 4.7939e+05] (样本数: 36)
# M_cool_real=4.9900e+05: mean=4.3958e+05, 1σ=[4.2318e+05, 4.5599e+05], max-min=[4.0417e+05, 4.7453e+05] (样本数: 36)

# %%
import pandas as pd
import numpy as np

# --- k_LW 分组：收集所有预测值 ---
klw_groups = []  # 存储每组的信息

for klw_real in unique_klw_real:
    mask = np.isclose(trues[:, 0], klw_real, atol=1e-4)
    group_preds = predictions[mask, 0]  # 该组所有预测的 k_LW 值
    
    if len(group_preds) > 0:  # 只保存有样本的组
        klw_groups.append({
            "k_LW_real": round(klw_real, 4),
            "sample_count": len(group_preds),
            "k_LW_pred_mean": np.mean(group_preds),
            "k_LW_pred_std": np.std(group_preds),
            "k_LW_pred_min": np.min(group_preds),
            "k_LW_pred_max": np.max(group_preds),
            "all_k_LW_predictions": group_preds.tolist()  # 保存所有单个预测值（列表）
        })

df_klw_full = pd.DataFrame(klw_groups)

# 保存为 CSV（pandas 会自动将列表转为字符串显示，但内容完整保留）
df_klw_full.to_csv("modelD/k_LW_B.csv", index=False)
print("已保存：k_LW_B.csv.csv")
print(f"一共 {len(df_klw_full)} 个 k_LW 分组，每组所有预测值已完整保存。")
print(df_klw_full[['k_LW_real', 'sample_count', 'k_LW_pred_mean', 'k_LW_pred_std', 'k_LW_pred_min', 'k_LW_pred_max']])  # 预览统计列


# --- M_cool 分组：收集所有预测值 ---
mcool_groups = []

for mcool_real in unique_mcool_real:
    mask = np.isclose(trues[:, 1], mcool_real, atol=1e-4)
    group_preds = predictions[mask, 1]  # 该组所有预测的 M_cool 值
    
    if len(group_preds) > 0:
        mcool_groups.append({
            "M_cool_real": mcool_real,  # 科学计数法，保持原样
            "sample_count": len(group_preds),
            "M_cool_pred_mean": np.mean(group_preds),
            "M_cool_pred_std": np.std(group_preds),
            "M_cool_pred_min": np.min(group_preds),
            "M_cool_pred_max": np.max(group_preds),
            "all_M_cool_predictions": group_preds.tolist()  # 所有单个预测值
        })

df_mcool_full = pd.DataFrame(mcool_groups)

df_mcool_full.to_csv("modelD/M_cool_B.csv", index=False)
print("\n已保存：M_cool_B.csv")
print(f"一共 {len(df_mcool_full)} 个 M_cool 分组，每组所有预测值已完整保存。")
print(df_mcool_full[['M_cool_real', 'sample_count', 'M_cool_pred_mean', 'M_cool_pred_std', 'M_cool_pred_min', 'M_cool_pred_max']])
# Out:
# 已保存：k_LW_B.csv.csv
# 一共 96 个 k_LW 分组，每组所有预测值已完整保存。
#     k_LW_real  sample_count  k_LW_pred_mean  k_LW_pred_std  k_LW_pred_min  \
# 0        0.00            36        0.121319       0.373880      -1.022269
# 1        0.20            36        0.742437       0.331122      -0.110448
# 2        0.23            36        0.723115       0.254794       0.164835
# 3        0.38            36        0.787370       0.205809       0.217689
# 4        0.49            36        0.612714       0.171150       0.039155
# ..        ...           ...             ...            ...            ...
# 91       6.79            36        6.183607       0.303579       5.087731
# 92       6.85            36        6.199359       0.231364       5.807489
# 93       6.91            36        6.145160       0.387136       5.532436
# 94       6.92            36        6.162091       0.220870       5.402054
# 95       6.94            36        6.151477       0.186825       5.506674
#
#     k_LW_pred_max
# 0        1.031610
# 1        1.362974
# 2        1.254781
# 3        1.203971
# 4        0.953894
# ..            ...
# 91       6.699629
# 92       6.722569
# 93       7.103964
# 94       6.577817
# 95       6.483862
#
# [96 rows x 6 columns]
#
# 已保存：M_cool_B.csv
# 一共 84 个 M_cool 分组，每组所有预测值已完整保存。
#     M_cool_real  sample_count  M_cool_pred_mean  M_cool_pred_std  \
# 0       50600.0            36      73452.320312     26500.601562
# 1       59900.0            36      92550.312500     16050.127930
# 2       69700.0            36      94428.992188     14953.928711
# 3       77400.0            36     104878.140625     12945.033203
# 4       83400.0            36      95930.101562     12123.774414
# ..          ...           ...               ...              ...
# 79     490000.0            36     414559.375000     21879.904297
# 80     492000.0            36     420775.718750     19563.712891
# 81     494000.0            36     438242.812500     25467.591797
# 82     495000.0            36     425216.375000     23895.453125
# 83     499000.0            36     439584.375000     16408.556641
#
#     M_cool_pred_min  M_cool_pred_max
# 0      17668.828125    134922.546875
# 1      44198.593750    140010.250000
# 2      59614.250000    119321.046875
# 3      80080.406250    135203.218750
# 4      49995.203125    112878.265625
# ..              ...              ...
# 79    362676.500000    461573.093750
# 80    354525.468750    454351.281250
# 81    390969.156250    488348.500000
# 82    362610.312500    479394.937500
# 83    404167.750000    474527.187500
#
# [84 rows x 6 columns]

# %%
# ====================== 新代码块：四张独立图（Max-Min errorbar 实心中心 + 7bin 1σ色带） ======================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 设置学术风格
plt.rcParams['font.size'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['lines.linewidth'] = 1.5
plt.rcParams['lines.markersize'] = 6
plt.rcParams['text.usetex'] = False

# 读取数据（文件名完全保持原样）
df_k_nonoise   = pd.read_csv("modelD/k_LW_B.csv")    # 无噪音
df_m_nonoise   = pd.read_csv("modelD/M_cool_B.csv")  # 无噪音

# --------------------- 修改后的绘制函数 ---------------------
def plot_maxmin_with_sigma_band(df, real_col, min_col, max_col, mean_col, std_col,
                                         title, xlabel, ylabel, filename, use_sci=False):
    df_valid = df.dropna(subset=[min_col, max_col])
    
    if len(df_valid) == 0:
        print(f"警告：{filename} 无有效数据")
        return
    
    real = df_valid[real_col].values
    pred_min = df_valid[min_col].values
    pred_max = df_valid[max_col].values
    
    # 预测均值（若无则取中点）
    if mean_col in df_valid.columns and not df_valid[mean_col].isna().all():
        pred_mean = df_valid[mean_col].values
    else:
        pred_mean = (pred_min + pred_max) / 2
    
    # 预测标准差（若无则为0）
    if std_col in df_valid.columns and not df_valid[std_col].isna().all():
        pred_std = df_valid[std_col].values
    else:
        pred_std = np.zeros_like(pred_min)
    
    # 为了填充Max-Min范围，需要对点按real值排序
    sort_idx = np.argsort(real)
    real_sorted = real[sort_idx]
    min_sorted = pred_min[sort_idx]
    max_sorted = pred_max[sort_idx]
    
    # 创建图片
    fig, ax = plt.subplots(figsize=(7, 6))
    
    # === Max-Min 预测范围色带（不分bin，直接填充所有点的min到max）===
    ax.vlines(real_sorted, min_sorted, max_sorted,
                    color='lightgreen', alpha=0.5,linewidth=8,
                    label='Max-Min Prediction Range')
    
    # === errorbar 显示 ±1σ（中心为均值，实心圆点）===
    ax.errorbar(real, pred_mean, yerr=pred_std,
                fmt='o', color='blue', capsize=5, markersize=6,
                markerfacecolor='none', markeredgewidth=1.8, elinewidth=1.8, alpha=0.7,
                label='Predicted Mean ±1σ')
    
    # 理想线 y = x
    overall_min = real.min()
    overall_max = real.max()
    ax.plot([overall_min, overall_max], [overall_min, overall_max],
            'r--', lw=1.5, label='Ideal y = x')
    
    ax.set_xlabel(xlabel, fontsize=16)
    ax.set_ylabel(ylabel, fontsize=16)
    ax.set_title(title)
    if use_sci:
        ax.ticklabel_format(style='sci', axis='both', scilimits=(0,0))
    ax.legend(frameon=False, fontsize=14)
    
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()

# --------------------- 绘制四张独立图 ---------------------

# 2. k_LW 无噪音
plot_maxmin_with_sigma_band(
    df_k_nonoise,
    real_col="k_LW_real",
    min_col="k_LW_pred_min",
    max_col="k_LW_pred_max",
    mean_col="k_LW_pred_mean",
    std_col="k_LW_pred_std",
    title=" ",
    xlabel="Real $\\alpha_{\\mathrm{LW}}$",
    ylabel="Predicted $\\alpha_{\\mathrm{LW}}$",
    filename="modelD/alphaLW_CaseB.pdf"
)

# 4. M_cool 无噪音
plot_maxmin_with_sigma_band(
    df_m_nonoise,
    real_col="M_cool_real",
    min_col="M_cool_pred_min",
    max_col="M_cool_pred_max",
    mean_col="M_cool_pred_mean",
    std_col="M_cool_pred_std",
    title=" ",
    xlabel="Real $M_{\\mathrm{cool}}(\\mathrm{{M_{{\\odot}}}})$",
    ylabel="Predicted $M_{\\mathrm{cool}}(\\mathrm{{M_{{\\odot}}}})$",
    filename="modelD/Mcool_CaseB.pdf",
    use_sci=True
)

# %%
# ====================== σ 阶梯纯色填充（地形图风格） ======================

from scipy.stats import gaussian_kde
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap, BoundaryNorm

# ==================== 样本选择（保持不变） ====================
tol = 1e-6
trues_rounded = np.round(trues, decimals=8)
unique_combinations = np.unique(trues_rounded, axis=0)
unique_combinations = unique_combinations[np.lexsort(
    (unique_combinations[:, 1], unique_combinations[:, 0]))
]

selected_real_pair = unique_combinations[50]
print(f"\n选中的样本组：")
print(f"真实 k_LW = {selected_real_pair[0]:.4f}")
print(f"真实 M_cool = {selected_real_pair[1]:.4e} M_⊙")

mask = np.all(np.isclose(trues, selected_real_pair, atol=tol), axis=1)
selected_predictions = predictions[mask]
sample_count = len(selected_predictions)
print(f"该组样本数量：{sample_count}")

pred_klw = selected_predictions[:, 0]
pred_mcool = selected_predictions[:, 1]

# ==================== 画布布局 ====================
fig = plt.figure(figsize=(9.5, 7.5))
gs = gridspec.GridSpec(
    2, 2, width_ratios=[4, 1], height_ratios=[1, 4],
    wspace=0.08, hspace=0.08
)

ax_main = fig.add_subplot(gs[1, 0])
ax_top = fig.add_subplot(gs[0, 0], sharex=ax_main)
ax_right = fig.add_subplot(gs[1, 1], sharey=ax_main)

# ==================== 视野范围（完整 3.5σ） ====================
mean_klw, std_klw = np.mean(pred_klw), np.std(pred_klw)
mean_mcool, std_mcool = np.mean(pred_mcool), np.std(pred_mcool)

pad_sigma = 3.5
#xmin = mean_klw - pad_sigma * std_klw
#xmax = mean_klw + pad_sigma * std_klw
#ymin = mean_mcool - pad_sigma * std_mcool
#ymax = mean_mcool + pad_sigma * std_mcool
xmin = 2.2
xmax = 4.9
ymin = 1e5
ymax = 2.3e5

margin_x = 0.03 * (xmax - xmin)
margin_y = 0.03 * (ymax - ymin)
xmin -= margin_x
xmax += margin_x
ymin -= margin_y
ymax += margin_y

ax_main.set_xlim(xmin, xmax)
ax_main.set_ylim(ymin, ymax)

# ==================== 2D KDE ====================
kde = gaussian_kde(np.vstack([pred_klw, pred_mcool]))
X, Y = np.mgrid[xmin:xmax:400j, ymin:ymax:400j]
positions = np.vstack([X.ravel(), Y.ravel()])
Z = np.reshape(kde(positions).T, X.shape)

# ==================== corner-style HPD σ ====================
Z_flat = Z.flatten()
idx = np.argsort(Z_flat)[::-1]
Z_sorted = Z_flat[idx]

cdf = np.cumsum(Z_sorted)
cdf /= cdf[-1]

sigma_probs = [0.6827, 0.9545, 0.9973]
levels = [Z_sorted[np.searchsorted(cdf, p)] for p in sigma_probs]
levels = sorted(levels)
levels = [0.0] + levels + [Z.max()]

# ==================== 离散纯色（地形图风格） ====================
sigma_colors = [
    "#ffffff",  # 之外
    "#fee391",  # 3σ
    "#fec44f",  # 2σ
    "#d95f0e",  # 1σ（核心）
]


cmap = ListedColormap(sigma_colors)
norm = BoundaryNorm(levels, cmap.N)

# ==================== 主图：σ 阶梯填色 ====================
cf = ax_main.contourf(
    X, Y, Z,
    levels=levels,
    cmap=cmap,
    norm=norm,
    antialiased=True
)

# σ 边界线（可选但强烈推荐）
ax_main.contour(
    X, Y, Z,
    levels=levels[1:-1],
    colors='k',
    linewidths=1.2
)

# ==================== 叠加 Fisher 解析椭圆（1σ/2σ/3σ） ====================

from matplotlib.patches import Ellipse

x_center_fisher = 3.5500
y_center_fisher = 165000   # 1.65 × 10^5 M_⊙

# 1σ
major_1sigma = 27738.918773 * 2    # width = 2 × 长半轴
minor_1sigma = 0.578358 * 2        # height = 2 × 短半轴
angle_1sigma = -89.999899

# 2σ
major_2sigma = 45432.662943 * 2
minor_2sigma = 0.947273 * 2
angle_2sigma = -89.999899

# 3σ
major_3sigma = 62829.935587 * 2
minor_3sigma = 1.310007 * 2
angle_3sigma = -89.999899

# 添加椭圆（颜色/线型模仿常见 Fisher 图风格）
# 1σ：橙色实线
ellipse1 = Ellipse(
    xy=(x_center_fisher, y_center_fisher),
    width=major_1sigma,
    height=minor_1sigma,
    angle=angle_1sigma,
    edgecolor='#d95f0e',       # 深橙（和你的核心密度色匹配）
    facecolor='none',
    linewidth=2.2,
    linestyle='-',
    label='Fisher 1σ'
)
ax_main.add_patch(ellipse1)

# 2σ：红色虚线
ellipse2 = Ellipse(
    xy=(x_center_fisher, y_center_fisher),
    width=major_2sigma,
    height=minor_2sigma,
    angle=angle_2sigma,
    edgecolor='red',
    facecolor='none',
    linewidth=1.8,
    linestyle='--',
    label='Fisher 2σ'
)
ax_main.add_patch(ellipse2)

# 3σ：深红点线
ellipse3 = Ellipse(
    xy=(x_center_fisher, y_center_fisher),
    width=major_3sigma,
    height=minor_3sigma,
    angle=angle_3sigma,
    edgecolor='maroon',
    facecolor='none',
    linewidth=1.5,
    linestyle=':',
    label='Fisher 3σ'
)
ax_main.add_patch(ellipse3)

# 加图例（放在合适位置）
ax_main.legend(loc='upper right', fontsize=18, framealpha=0.9)

# ==================== 真实值 ====================
ax_main.axvline(selected_real_pair[0], color='red', ls='--', lw=1.8)
ax_main.axhline(selected_real_pair[1], color='red', ls='--', lw=1.8)

ax_main.set_xlabel('Predicted $\\alpha_{\\mathrm{LW}}$', fontsize=18)
ax_main.set_ylabel('Predicted $M_{\\mathrm{cool}}$ ($\\mathrm{{M_{{\\odot}}}}$)', fontsize=18)
ax_main.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
ax_main.yaxis.get_offset_text().set_fontsize(16)
ax_main.tick_params(axis='both', labelsize=16)

# ==================== 上方 1D KDE ====================
kde_klw = gaussian_kde(pred_klw)
x_klw = np.linspace(xmin, xmax, 400)
ax_top.plot(x_klw, kde_klw(x_klw), color='darkred', lw=2.2)
ax_top.axvline(selected_real_pair[0], color='red', ls='--', lw=1.8)
ax_top.set_ylabel('PDF', fontsize=18)
ax_top.set_title(
    f'Real: $\\alpha_{{\\mathrm{{LW}}}}={selected_real_pair[0]:.2f}$, '
    f'$M_{{\\mathrm{{cool}}}}={selected_real_pair[1]:.2e} \\mathrm{{M_{{\\odot}}}}$'
    , fontsize=18
)
ax_top.tick_params(labelbottom=False, labelsize=16)

# ==================== 右侧 1D KDE ====================
kde_mcool = gaussian_kde(pred_mcool)
y_mcool = np.linspace(ymin, ymax, 400)
ax_right.plot(kde_mcool(y_mcool), y_mcool, color='darkred', lw=2.2)
ax_right.axhline(selected_real_pair[1], color='red', ls='--', lw=1.8)
ax_right.set_xlabel('PDF', fontsize=18)
ax_right.ticklabel_format(style='sci', axis='x', scilimits=(0, 0))
ax_right.xaxis.get_offset_text().set_fontsize(16)
ax_right.xaxis.get_offset_text().set_x(1.15)
ax_right.tick_params(labelleft=False, labelsize=16)

# ==================== 颜色条（σ 标注） ====================
cbar_ax = fig.add_axes([0.93, 0.15, 0.02, 0.7])
cbar = fig.colorbar(cf, cax=cbar_ax)
cbar.set_ticks([
    (levels[i] + levels[i+1]) / 2 for i in range(len(levels)-1)
])

cbar.set_ticklabels([
    '>99.7%', '95.5%-99.7%', '68.3%-95.5%', '<68.3%'
],fontsize=16)

cbar.set_label(' ')

plt.tight_layout(rect=[0, 0, 0.91, 1])
plt.savefig('modelD/2d_prediction_density_B_withfisher.pdf',
            dpi=300, bbox_inches='tight')
plt.show()

# ==================== 统计输出 ====================
print(f"\n预测统计：")
print(f"k_LW   = {mean_klw:.6f} ± {std_klw:.6f}")
print(f"M_cool = {mean_mcool:.8e} ± {std_mcool:.8e}")
# Out:
# 选中的样本组：
# 真实 k_LW = 3.5500
# 真实 M_cool = 1.6500e+05 M_⊙
# 该组样本数量：1080
# /tmp/ipykernel_3003610/134276663.py:228: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.91, 1])
# 预测统计：
# k_LW   = 3.696874 ± 0.324244
# M_cool = 1.74243906e+05 ± 9.54221094e+03

# %%
# klw 和 mcool 的分箱边界
klw_bins = np.linspace(0.0, 7.0, 4)          # 3 bins
mcool_bins = np.linspace(5e4, 5e5, 4)        # 3 bins

def mse_1d(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)


def r2_score_1d(y_true, y_pred):
    ss_res = np.sum((y_true - y_pred) ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    return 1.0 - ss_res / ss_tot if ss_tot > 0 else np.nan

mse_klw_grid   = np.full((3, 3), np.nan)
mse_mcool_grid = np.full((3, 3), np.nan)
r2_klw_grid = np.full((3, 3), np.nan)
r2_mcool_grid = np.full((3, 3), np.nan)
count_grid = np.zeros((3, 3), dtype=int)

for i in range(3):      # klw bins
    for j in range(3):  # mcool bins
        
        klw_mask = (trues[:, 0] >= klw_bins[i]) & (trues[:, 0] < klw_bins[i+1])
        mcool_mask = (trues[:, 1] >= mcool_bins[j]) & (trues[:, 1] < mcool_bins[j+1])
        mask = klw_mask & mcool_mask
        
        if np.sum(mask) < 2:
            continue
        
        y_true_bin = trues[mask]
        y_pred_bin = predictions[mask]
        
        # klw
        mse_klw_grid[i, j] = mse_1d(
            y_true_bin[:, 0], y_pred_bin[:, 0]
        )
        r2_klw_grid[i, j] = r2_score_1d(
            y_true_bin[:, 0], y_pred_bin[:, 0]
        )
        
        # mcool
        mse_mcool_grid[i, j] = mse_1d(
            y_true_bin[:, 1], y_pred_bin[:, 1]
        )
        r2_mcool_grid[i, j] = r2_score_1d(
            y_true_bin[:, 1], y_pred_bin[:, 1]
        )
        
        count_grid[i, j] = np.sum(mask)

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(mse_klw_grid, origin='lower')

ax.set_xticks(range(3))
ax.set_yticks(range(3))
ax.set_xticklabels([f'{mcool_bins[i]:.1e}–{mcool_bins[i+1]:.1e}' for i in range(3)])
ax.set_yticklabels([f'{klw_bins[i]:.1f}–{klw_bins[i+1]:.1f}' for i in range(3)])

ax.set_xlabel('$M_{\\mathrm{cool}}$ (real)')
ax.set_ylabel('$\\alpha_{\\mathrm{LW}}$ (real)')
ax.set_title(' ')

cbar = plt.colorbar(im, ax=ax)
cbar.set_label('MSE of predicted $\\alpha_{\\mathrm{LW}}$')

plt.tight_layout()
plt.savefig("modelD/local_MSELW_vs_real_B.pdf", dpi=300, bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(mse_mcool_grid, origin='lower')

ax.set_xticks(range(3))
ax.set_yticks(range(3))
ax.set_xticklabels([f'{mcool_bins[i]:.1e}–{mcool_bins[i+1]:.1e}' for i in range(3)])
ax.set_yticklabels([f'{klw_bins[i]:.1f}–{klw_bins[i+1]:.1f}' for i in range(3)])

ax.set_xlabel('$M_{\\mathrm{cool}}$ (real)')
ax.set_ylabel('$\\alpha_{\\mathrm{LW}}$ (real)')
ax.set_title(' ')

cbar = plt.colorbar(im, ax=ax)
cbar.set_label('MSE of predicted $M_{\\mathrm{cool}}$')

plt.tight_layout()
plt.savefig("modelD/local_MSEmcool_vs_real_B.pdf", dpi=300, bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(r2_klw_grid, origin='lower', vmin=-1, vmax=1)

ax.set_xticks(range(3))
ax.set_yticks(range(3))
ax.set_xticklabels([f'{mcool_bins[i]:.1e}–{mcool_bins[i+1]:.1e}' for i in range(3)])
ax.set_yticklabels([f'{klw_bins[i]:.1f}–{klw_bins[i+1]:.1f}' for i in range(3)])

ax.set_xlabel('$M_{\\mathrm{cool}}$ (real)')
ax.set_ylabel('$\\alpha_{\\mathrm{LW}}$ (real)')
ax.set_title(' ')

cbar = plt.colorbar(im, ax=ax)
cbar.set_label('R² on $\\alpha_{\\mathrm{LW}}$')
plt.tight_layout()
plt.savefig("modelD/local_R2LW_vs_real_B.pdf", dpi=300, bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(r2_mcool_grid, origin='lower', vmin=-1, vmax=1)

ax.set_xticks(range(3))
ax.set_yticks(range(3))
ax.set_xticklabels([f'{mcool_bins[i]:.1e}–{mcool_bins[i+1]:.1e}' for i in range(3)])
ax.set_yticklabels([f'{klw_bins[i]:.1f}–{klw_bins[i+1]:.1f}' for i in range(3)])

ax.set_xlabel('$M_{\\mathrm{cool}}$ (real)')
ax.set_ylabel('$\\alpha_{\\mathrm{LW}}$ (real)')
ax.set_title(' ')

cbar = plt.colorbar(im, ax=ax)
cbar.set_label('R² on $M_{\\mathrm{cool}}$')
plt.tight_layout()
plt.savefig("modelD/local_R2mcool_vs_real_B.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
print("=" * 80)
print("R^2 values in each (klw, mcool) bin")
print("=" * 80)

for i in range(3):      # klw bins
    for j in range(3):  # mcool bins
        
        klw_range = f"[{klw_bins[i]:.2f}, {klw_bins[i+1]:.2f})"
        mcool_range = f"[{mcool_bins[j]:.2e}, {mcool_bins[j+1]:.2e})"
        N = count_grid[i, j]
        
        if N < 2:
            print(f"klw {klw_range}, mcool {mcool_range} : "
                  f"N = {N}  --> insufficient samples")
            continue
        
        print(
            f"klw {klw_range}, mcool {mcool_range} : "
            f"N = {N:4d} | "
            f"R^2(klw) = {r2_klw_grid[i, j]: .4f} | "
            f"R^2(mcool) = {r2_mcool_grid[i, j]: .4f}"
        )

print("=" * 80)

# %% [markdown]
# crossvalidation

# %%
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from sklearn.model_selection import KFold

train_data = torch.load('modelD/processed_tensors/caseB/train_data.pt')
valid_data = torch.load('modelD/processed_tensors/caseB/valid_data.pt')
train_images = train_data['images']
train_labels = train_data['labels']
valid_images = valid_data['images']
valid_labels = valid_data['labels']
# 合并成完整数据集
full_images = torch.cat([train_images, valid_images])
full_labels = torch.cat([train_labels, valid_labels])

print(f"Full dataset size: {len(full_images)}, {len(full_labels)}")  # 比如 1000 张
# Out:
# Full dataset size: 32400, 32400

# %%
# ------------------- 1. 自定义 Dataset -------------------
class MergedDataset(Dataset):
    def __init__(self, images, labels):
        """
        images: torch.Tensor of shape (N, C, H, W)
        labels: torch.Tensor of shape (N, 2)  # 两个回归目标
        """
        self.images = images
        self.labels = labels
        assert len(self.images) == len(self.labels), "Images and labels must have same length!"

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]   # 已经是 tensor，不需要 ToTensor
        label = self.labels[idx]   # shape (2,)
        return image, label

# %%
def load_and_merge(train_pt_path='train_data.pt', valid_pt_path='valid_data.pt'):
    print("Loading train and valid .pt files...")

    # 合并
    full_images = torch.cat([train_images, valid_images], dim=0)
    full_labels = torch.cat([train_labels, valid_labels], dim=0)

    print(f"Train images: {train_images.shape} → labels: {train_labels.shape}")
    print(f"Valid images: {valid_images.shape} → labels: {valid_labels.shape}")
    print(f"Full dataset: images {full_images.shape}, labels {full_labels.shape}")

    return MergedDataset(full_images, full_labels)

# %%
def r2_score(y_true, y_pred):
    ss_res = torch.sum((y_true - y_pred) ** 2)
    ss_tot = torch.sum((y_true - torch.mean(y_true)) ** 2)
    return 1 - (ss_res / ss_tot)

def train_model_cv(
    model, train_loader, valid_loader,
    criterion, mae_metric, optimizer, scheduler,
    epochs=200, patience=30,
    w_klw=1.0, w_mcool=1.0,
    device=None,
    fold=None,                    # 新增：当前是第几个 fold
    save_dir='cv_models_modelD'   # 新增：统一保存目录
):
    """
    CV 专用的训练函数，每个 fold 独立保存模型和历史记录
    """
    if device is None:
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    
    model = model.to(device)
    
    os.makedirs(save_dir, exist_ok=True)
    
    # 每个 fold 独立的路径
    if fold is not None:
        model_path = os.path.join(save_dir, f'best_model_fold{fold}.pt')
        csv_path = os.path.join(save_dir, f'training_history_fold{fold}.csv')
    else:
        model_path = os.path.join(save_dir, 'best_model_caseB_crossvalid.pt')
        csv_path = os.path.join(save_dir, 'training_history_caseB_crossvalid.csv')

    best_valid_loss = float('inf')
    early_stop_counter = 0

    # 历史记录
    history = {
        'epoch': [],
        'train_loss': [],
        'train_mae_klw': [], 'train_mae_mcool': [],
        'valid_loss': [],
        'valid_mae_klw': [], 'valid_mae_mcool': [],
        'valid_r2_klw': [], 'valid_r2_mcool': []
    }

    for epoch in range(epochs):
        # =================== Training ===================
        model.train()
        train_loss = 0.0
        train_mae_klw = 0.0
        train_mae_mcool = 0.0
        train_samples = 0

        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            
            optimizer.zero_grad()
            output = model(x)  # (B, 2)
            
            loss_klw = criterion(output[:, 0], y[:, 0]) * w_klw
            loss_mcool = criterion(output[:, 1], y[:, 1]) * w_mcool
            loss = loss_klw + loss_mcool
            
            loss.backward()
            optimizer.step()
            
            batch_size = x.size(0)
            train_loss += loss.item() * batch_size
            train_mae_klw += mae_metric(output[:, 0], y[:, 0]).item() * batch_size
            train_mae_mcool += mae_metric(output[:, 1], y[:, 1]).item() * batch_size
            train_samples += batch_size
        
        train_loss /= train_samples
        train_mae_klw /= train_samples
        train_mae_mcool /= train_samples

        # =================== Validation ===================
        model.eval()
        valid_loss = 0.0
        valid_mae_klw = 0.0
        valid_mae_mcool = 0.0
        valid_samples = 0
        all_preds = []
        all_trues = []
        
        with torch.no_grad():
            for x, y in valid_loader:
                x, y = x.to(device), y.to(device)
                output = model(x)
                
                loss_klw = criterion(output[:, 0], y[:, 0]) * w_klw
                loss_mcool = criterion(output[:, 1], y[:, 1]) * w_mcool
                loss = loss_klw + loss_mcool
                
                batch_size = x.size(0)
                valid_loss += loss.item() * batch_size
                valid_mae_klw += mae_metric(output[:, 0], y[:, 0]).item() * batch_size
                valid_mae_mcool += mae_metric(output[:, 1], y[:, 1]).item() * batch_size
                valid_samples += batch_size
                
                all_preds.append(output.cpu())
                all_trues.append(y.cpu())
        
        valid_loss /= valid_samples
        valid_mae_klw /= valid_samples
        valid_mae_mcool /= valid_samples
        
        all_pred = torch.cat(all_preds, dim=0)
        all_true = torch.cat(all_trues, dim=0)
        valid_r2_klw = r2_score(all_true[:, 0], all_pred[:, 0]).item()
        valid_r2_mcool = r2_score(all_true[:, 1], all_pred[:, 1]).item()

        # =================== Scheduler Step ===================
        scheduler.step(valid_loss)

        # =================== Record History ===================
        history['epoch'].append(epoch + 1)
        history['train_loss'].append(train_loss)
        history['train_mae_klw'].append(train_mae_klw)
        history['train_mae_mcool'].append(train_mae_mcool)
        history['valid_loss'].append(valid_loss)
        history['valid_mae_klw'].append(valid_mae_klw)
        history['valid_mae_mcool'].append(valid_mae_mcool)
        history['valid_r2_klw'].append(valid_r2_klw)
        history['valid_r2_mcool'].append(valid_r2_mcool)

        # =================== Print ===================
        fold_str = f"[Fold {fold}] " if fold is not None else ""
        print(f'{fold_str}Epoch {epoch+1:3d}/{epochs} | '
              f'Train Loss: {train_loss:.4f} | T-MAE klw: {train_mae_klw:.4f} | T-MAE mcool: {train_mae_mcool:.4f} | '
              f'Valid Loss: {valid_loss:.4f} | V-MAE klw: {valid_mae_klw:.4f} | V-MAE mcool: {valid_mae_mcool:.4f} | '
              f'V-R² klw: {valid_r2_klw:.4f} | V-R² mcool: {valid_r2_mcool:.4f}')

        # =================== Early Stopping & Save Best ===================
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), model_path)
            early_stop_counter = 0
            print(f"  → New best model saved! (Valid Loss: {best_valid_loss:.4f})")
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                print(f"\nEarly stopping triggered at epoch {epoch+1}")
                break

    # =================== Save History ===================
    df_history = pd.DataFrame(history)
    df_history.to_csv(csv_path, index=False)
    print(f"Training history saved to: {csv_path}")

    # =================== Load Best Model ===================
    print(f"Loading best model weights from {model_path}...")
    model.load_state_dict(torch.load(model_path, map_location=device))

    return model, history

# %%
def run_cross_validation(
    model_class,
    full_dataset,
    k_folds=5,
    batch_size=32,
    epochs=200,
    patience=25,
    lr=0.001,
    weight_decay=1e-3,
    save_dir='modelD/cvmodelB'
):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    os.makedirs(save_dir, exist_ok=True)

    kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)
    results = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(np.arange(len(full_dataset)))):
        print(f"\n{'='*60}")
        print(f"Starting Fold {fold+1}/{k_folds}")
        print(f"{'='*60}")

        # Sampler
        train_sampler = SubsetRandomSampler(train_idx)
        val_sampler = SubsetRandomSampler(val_idx)

        train_loader = DataLoader(full_dataset, batch_size=batch_size, sampler=train_sampler)
        val_loader = DataLoader(full_dataset, batch_size=batch_size, sampler=val_sampler)

        # 新模型
        model = model_class().to(device)

        criterion = nn.MSELoss()
        mae_metric = MeanAbsoluteError().to(device)

        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, mode='min', factor=0.5, patience=10, min_lr=1e-6
        )

        model, history = train_model_cv(  
            model=model,
            train_loader=train_loader,
            valid_loader=val_loader,
            criterion=criterion,
            mae_metric=mae_metric,
            optimizer=optimizer,
            scheduler=scheduler,
            epochs=epochs,
            patience=patience,
            device=device,
            fold=fold,
            save_dir=save_dir
        )

        # 从 history 提取最佳指标（假设 history 有 'valid_mae_klw' 和 'valid_mae_mcool'）
        best_idx = np.argmin(history['valid_loss'])
        best_loss = history['valid_loss'][best_idx]
        best_mae_klw = history['valid_mae_klw'][best_idx]
        best_mae_mcool = history['valid_mae_mcool'][best_idx]

        results.append({
            'fold': fold + 1,
            'best_valid_loss': best_loss,
            'best_mae_klw': best_mae_klw,
            'best_mae_mcool': best_mae_mcool
        })

        print(f"Fold {fold+1} Best → Loss: {best_loss:.6f} | MAE α_LW: {best_mae_klw:.4f} | MAE M_cool: {best_mae_mcool:.4f}")

    # ------------------- CV 总结 -------------------
    df = pd.DataFrame(results)
    print("\n" + "="*60)
    print("CROSS VALIDATION SUMMARY")
    print("="*60)
    print(df)
    print(f"\nMAE α_LW:  {df['best_mae_klw'].mean():.4f} ± {df['best_mae_klw'].std():.4f}")
    print(f"MAE M_cool: {df['best_mae_mcool'].mean():.4f} ± {df['best_mae_mcool'].std():.4f}")
    print(f"Valid Loss: {df['best_valid_loss'].mean():.6f} ± {df['best_valid_loss'].std():.6f}")

    df.to_csv(os.path.join(save_dir, 'cv_results_summary.csv'), index=False)
    return df, results

# %%
if __name__ == "__main__":
    full_dataset = load_and_merge('train_data.pt', 'valid_data.pt')

    # 替换成你的模型类
    class YourModel(nn.Module):
        def __init__(self):
            super().__init__()
            # ... 你的模型结构
            pass
        def forward(self, x):
            # 返回 shape (B, 2) 或分别返回两个值
            pass

    df_cv = run_cross_validation(
        model_class=CNN,
        full_dataset=full_dataset,
        k_folds=5,
        batch_size=32,
        epochs=200,
        patience=25,
        lr=0.001,
        weight_decay=1e-3
    )
# Out:
# Loading train and valid .pt files...
# Train images: torch.Size([28800, 1, 20, 40]) → labels: torch.Size([28800, 2])
# Valid images: torch.Size([3600, 1, 20, 40]) → labels: torch.Size([3600, 2])
# Full dataset: images torch.Size([32400, 1, 20, 40]), labels torch.Size([32400, 2])
#
# ============================================================
# Starting Fold 1/5
# ============================================================
# Using device: cuda
# [Fold 0] Epoch   1/200 | Train Loss: 1.2423 | T-MAE klw: 0.5962 | T-MAE mcool: 0.6733 | Valid Loss: 1.1044 | V-MAE klw: 0.5549 | V-MAE mcool: 0.6446 | V-R² klw: 0.5175 | V-R² mcool: 0.3862
#   → New best model saved! (Valid Loss: 1.1044)
# [Fold 0] Epoch   2/200 | Train Loss: 1.1383 | T-MAE klw: 0.5756 | T-MAE mcool: 0.6643 | Valid Loss: 1.0943 | V-MAE klw: 0.5642 | V-MAE mcool: 0.6451 | V-R² klw: 0.5184 | V-R² mcool: 0.3952
#   → New best model saved! (Valid Loss: 1.0943)
# [Fold 0] Epoch   3/200 | Train Loss: 1.1337 | T-MAE klw: 0.5762 | T-MAE mcool: 0.6606 | Valid Loss: 1.0959 | V-MAE klw: 0.5479 | V-MAE mcool: 0.6640 | V-R² klw: 0.5219 | V-R² mcool: 0.3902
#   → New best model saved! (Valid Loss: 0.1117)
# Training history saved to: modelD/cvmodelB/training_history_fold0.csv
# Loading best model weights from modelD/cvmodelB/best_model_fold0.pt...
# Fold 1 Best → Loss: 0.111735 | MAE α_LW: 0.1831 | MAE M_cool: 0.1670
#
# ============================================================
# Starting Fold 2/5
# ============================================================
# Using device: cuda
# [Fold 1] Epoch   1/200 | Train Loss: 1.2177 | T-MAE klw: 0.5950 | T-MAE mcool: 0.6744 | Valid Loss: 1.1503 | V-MAE klw: 0.5633 | V-MAE mcool: 0.6600 | V-R² klw: 0.5114 | V-R² mcool: 0.3527
#   → New best model saved! (Valid Loss: 1.1503)
# [Fold 1] Epoch   2/200 | Train Loss: 1.1341 | T-MAE klw: 0.5733 | T-MAE mcool: 0.6619 | Valid Loss: 1.1299 | V-MAE klw: 0.5575 | V-MAE mcool: 0.6621 | V-R² klw: 0.5194 | V-R² mcool: 0.3649
#   → New best model saved! (Valid Loss: 1.1299)
# [Fold 1] Epoch   3/200 | Train Loss: 1.1292 | T-MAE klw: 0.5743 | T-MAE mcool: 0.6574 | Valid Loss: 1.1610 | V-MAE klw: 0.5944 | V-MAE mcool: 0.6492 | V-R² klw: 0.4892 | V-R² mcool: 0.3643
# [Fold 1] Epoch   4/200 | Train Loss: 1.1052 | T-MAE klw: 0.5705 | T-MAE mcool: 0.6491 | Valid Loss: 1.1201 | V-MAE klw: 0.5867 | V-MAE mcool: 0.6661 | V-R² klw: 0.5104 | V-R² mcool: 0.3834
#   → New best model saved! (Valid Loss: 1.1201)
# [Fold 1] Epoch   5/200 | Train Loss: 1.1320 | T-MAE klw: 0.5831 | T-MAE mcool: 0.6524 | Valid Loss: 1.1520 | V-MAE klw: 0.5913 | V-MAE mcool: 0.6595 | V-R² klw: 0.4900 | V-R² mcool: 0.3723
# [Fold 1] Epoch   6/200 | Train Loss: 1.0945 | T-MAE klw: 0.5700 | T-MAE mcool: 0.6411 | Valid Loss: 1.0928 | V-MAE klw: 0.5920 | V-MAE mcool: 0.6292 | V-R² klw: 0.5025 | V-R² mcool: 0.4182
#   → New best model saved! (Valid Loss: 1.0928)
# [Fold 1] Epoch   7/200 | Train Loss: 1.0270 | T-MAE klw: 0.5542 | T-MAE mcool: 0.6150 | Valid Loss: 1.0824 | V-MAE klw: 0.5862 | V-MAE mcool: 0.6223 | V-R² klw: 0.5152 | V-R² mcool: 0.4158
#   → New best model saved! (Valid Loss: 1.0824)
# [Fold 1] Epoch   8/200 | Train Loss: 0.9633 | T-MAE klw: 0.5416 | T-MAE mcool: 0.5867 | Valid Loss: 0.9588 | V-MAE klw: 0.5544 | V-MAE mcool: 0.5953 | V-R² klw: 0.5577 | V-R² mcool: 0.4952
#   → New best model saved! (Valid Loss: 0.9588)
# [Fold 1] Epoch   9/200 | Train Loss: 0.9175 | T-MAE klw: 0.5311 | T-MAE mcool: 0.5680 | Valid Loss: 0.7591 | V-MAE klw: 0.4893 | V-MAE mcool: 0.5094 | V-R² klw: 0.6287 | V-R² mcool: 0.6214
# [Fold 4] Epoch 196/200 | Train Loss: 0.1156 | T-MAE klw: 0.1704 | T-MAE mcool: 0.1878 | Valid Loss: 0.0989 | V-MAE klw: 0.1602 | V-MAE mcool: 0.1643 | V-R² klw: 0.9488 | V-R² mcool: 0.9522
#   → New best model saved! (Valid Loss: 0.0989)
# [Fold 4] Epoch 197/200 | Train Loss: 0.1158 | T-MAE klw: 0.1723 | T-MAE mcool: 0.1867 | Valid Loss: 0.0992 | V-MAE klw: 0.1694 | V-MAE mcool: 0.1631 | V-R² klw: 0.9484 | V-R² mcool: 0.9524
# [Fold 4] Epoch 198/200 | Train Loss: 0.1150 | T-MAE klw: 0.1706 | T-MAE mcool: 0.1868 | Valid Loss: 0.1039 | V-MAE klw: 0.1633 | V-MAE mcool: 0.1759 | V-R² klw: 0.9483 | V-R² mcool: 0.9477
# [Fold 4] Epoch 199/200 | Train Loss: 0.1148 | T-MAE klw: 0.1705 | T-MAE mcool: 0.1871 | Valid Loss: 0.1125 | V-MAE klw: 0.1675 | V-MAE mcool: 0.1857 | V-R² klw: 0.9428 | V-R² mcool: 0.9446
# [Fold 4] Epoch 200/200 | Train Loss: 0.1148 | T-MAE klw: 0.1699 | T-MAE mcool: 0.1871 | Valid Loss: 0.1100 | V-MAE klw: 0.1696 | V-MAE mcool: 0.1802 | V-R² klw: 0.9431 | V-R² mcool: 0.9469
# Training history saved to: modelD/cvmodelB/training_history_fold4.csv
# Loading best model weights from modelD/cvmodelB/best_model_fold4.pt...
# Fold 5 Best → Loss: 0.098914 | MAE α_LW: 0.1602 | MAE M_cool: 0.1643
#
# ============================================================
# CROSS VALIDATION SUMMARY
# ============================================================
#    fold  best_valid_loss  best_mae_klw  best_mae_mcool
# 0     1         0.111735      0.183127        0.166969
# 1     2         0.132497      0.210021        0.187313
# 2     3         0.111555      0.179940        0.166358
# 3     4         0.107776      0.170407        0.171375
# 4     5         0.098914      0.160215        0.164305
#
# MAE α_LW:  0.1807 ± 0.0187
# MAE M_cool: 0.1713 ± 0.0093
# Valid Loss: 0.112496 ± 0.012331

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# ------------------- 参数设置 -------------------
save_dir = 'modelD/cvmodelB'  # 改成你的实际目录
folds = 5
colors = plt.cm.tab10(np.linspace(0, 1, folds))  # 更鲜艳的颜色，便于区分

# ------------------- 读取所有 fold 的历史 -------------------
histories = []
max_epochs = 0
for fold in range(folds):
    csv_path = os.path.join(save_dir, f'training_history_fold{fold}.csv')
    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"找不到文件: {csv_path}")
    
    df = pd.read_csv(csv_path)
    histories.append(df)
    max_epochs = max(max_epochs, len(df))

print(f"成功读取 {folds} 个 fold，最长训练 {max_epochs} 个 epoch")

# ------------------- 对齐 epoch -------------------
valid_losses = np.full((folds, max_epochs), np.nan)
train_losses = np.full((folds, max_epochs), np.nan)
valid_mae_klw = np.full((folds, max_epochs), np.nan)
valid_mae_mcool = np.full((folds, max_epochs), np.nan)

for i, df in enumerate(histories):
    n = len(df)
    valid_losses[i, :n] = df['valid_loss'].values
    train_losses[i, :n] = df['train_loss'].values
    valid_mae_klw[i, :n] = df['valid_mae_klw'].values
    valid_mae_mcool[i, :n] = df['valid_mae_mcool'].values

epochs = np.arange(1, max_epochs + 1)

# ------------------- 绘图（1 大图 + 2 小图） -------------------
plt.figure(figsize=(14, 10))

# 1. Train Loss 和 Valid Loss 同图
plt.subplot(2, 2, (1, 2))  # 占前两格（横向大图）
# 画每个 fold 的两条线（train 实线，valid 虚线）
for i in range(folds):
    fold_epochs = epochs[:len(histories[i])]
    plt.plot(fold_epochs, histories[i]['train_loss'], 
             color=colors[i], linestyle='-', alpha=0.7, linewidth=1.5, label=f'Fold {i+1} Train' if i==0 else None)
    plt.plot(fold_epochs, histories[i]['valid_loss'], 
             color=colors[i], linestyle='--', alpha=0.7, linewidth=1.5, label=f'Fold {i+1} Valid' if i==0 else None)

# 均值曲线
mean_train = np.nanmean(train_losses, axis=0)
std_train = np.nanstd(train_losses, axis=0)
mean_valid = np.nanmean(valid_losses, axis=0)
std_valid = np.nanstd(valid_losses, axis=0)

plt.plot(epochs, mean_train, color='blue', linewidth=3, label='Mean Train')
plt.fill_between(epochs, mean_train - std_train, mean_train + std_train, color='blue', alpha=0.15)

plt.plot(epochs, mean_valid, color='red', linewidth=3, label='Mean Valid')
plt.fill_between(epochs, mean_valid - std_valid, mean_valid + std_valid, color='red', alpha=0.15)

plt.title('Train Loss vs Valid Loss across 5 Folds', fontsize=14)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.grid(True, alpha=0.3)

# 2. Valid MAE α_LW
plt.subplot(2, 2, 3)
for i in range(folds):
    plt.plot(epochs[:len(histories[i])], histories[i]['valid_mae_klw'],
             color=colors[i], alpha=0.7, linewidth=1.5)
mean_klw = np.nanmean(valid_mae_klw, axis=0)
std_klw = np.nanstd(valid_mae_klw, axis=0)
plt.plot(epochs, mean_klw, color='black', linewidth=3, label='Mean')
plt.fill_between(epochs, mean_klw - std_klw, mean_klw + std_klw, color='black', alpha=0.2)
plt.title('Valid MAE α_LW across 5 Folds')
plt.xlabel('Epoch')
plt.ylabel('MAE α_LW')
plt.legend()
plt.grid(True, alpha=0.3)

# 3. Valid MAE M_cool
plt.subplot(2, 2, 4)
for i in range(folds):
    plt.plot(epochs[:len(histories[i])], histories[i]['valid_mae_mcool'],
             color=colors[i], alpha=0.7, linewidth=1.5)
mean_mcool = np.nanmean(valid_mae_mcool, axis=0)
std_mcool = np.nanstd(valid_mae_mcool, axis=0)
plt.plot(epochs, mean_mcool, color='black', linewidth=3, label='Mean')
plt.fill_between(epochs, mean_mcool - std_mcool, mean_mcool + std_mcool, color='black', alpha=0.2)
plt.title('Valid MAE M_cool across 5 Folds')
plt.xlabel('Epoch')
plt.ylabel('MAE M_cool')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.subplots_adjust(right=0.85)  # 给右侧图例留空间
plt.savefig('modelD/crossvalidationB.png',
            dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 成功读取 5 个 fold，最长训练 200 个 epoch
